# %%
import pandas as pd

# %%
df = pd.read_excel('Dataset (Last).xlsx')

df
# Out:
#                                                     txt  label
# 0     จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรีย...    0.0
# 1     ฝากถึงท่าน​ ผอ.​ที่กล่าวในการประขุม​ ผปค. ม6 เ...    0.0
# 2     คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหาย...    0.0
# 3     ขอความกรุณาผู้ปกครองอย่า start รถ ระหว่างรอเลย...    0.0
# 4                     เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ    0.0
# ...                                                 ...    ...
# 1663               รับสมัครถึงวันไหนค่ะ ยังสมัครทันมั้ย    2.0
# 1664                 อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ    2.0
# 1665                 อยากรู้ว่าม1จะขอเข้าสมัครได้ใหม่คะ    2.0
# 1666                         เสียค่าสมัครสอบเท่าไหร่ค่ะ    2.0
# 1667                               ใบสมัครใช้อะไรบ้างคะ    2.0
#
# [1668 rows x 2 columns]

# %%
df = df.fillna(0)
df
# Out:
#                                                     txt label
# 0     จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรีย...   0.0
# 1     ฝากถึงท่าน​ ผอ.​ที่กล่าวในการประขุม​ ผปค. ม6 เ...   0.0
# 2     คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหาย...   0.0
# 3     ขอความกรุณาผู้ปกครองอย่า start รถ ระหว่างรอเลย...   0.0
# 4                     เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ   0.0
# ...                                                 ...   ...
# 1663               รับสมัครถึงวันไหนค่ะ ยังสมัครทันมั้ย   2.0
# 1664                 อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ   2.0
# 1665                 อยากรู้ว่าม1จะขอเข้าสมัครได้ใหม่คะ   2.0
# 1666                         เสียค่าสมัครสอบเท่าไหร่ค่ะ   2.0
# 1667                               ใบสมัครใช้อะไรบ้างคะ   2.0
#
# [1668 rows x 2 columns]

# %%
df = df.applymap(str)

# %%
df
# Out:
#                                                     txt label
# 0     จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรีย...   0.0
# 1     ฝากถึงท่าน​ ผอ.​ที่กล่าวในการประขุม​ ผปค. ม6 เ...   0.0
# 2     คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหาย...   0.0
# 3     ขอความกรุณาผู้ปกครองอย่า start รถ ระหว่างรอเลย...   0.0
# 4                     เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ   0.0
# ...                                                 ...   ...
# 1663               รับสมัครถึงวันไหนค่ะ ยังสมัครทันมั้ย   2.0
# 1664                 อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ   2.0
# 1665                 อยากรู้ว่าม1จะขอเข้าสมัครได้ใหม่คะ   2.0
# 1666                         เสียค่าสมัครสอบเท่าไหร่ค่ะ   2.0
# 1667                               ใบสมัครใช้อะไรบ้างคะ   2.0
#
# [1668 rows x 2 columns]

# %%
df.to_csv("Dataset (Last).csv")

# %%
df["txt"][0]
# Out:
# 'จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรียน ทำรถติด แทนที่จะจัดรถเข้า\nทางออกทาง ให้เข้าออกปะปนกันไปหมด'

# %%
df["label"]

# %%
size = df.shape[0]

# %%
data1 = []

for i in range (size):
    if(i%2==0):
        data1.append(df["txt"][i])
    else:
        data1.append(df["label"][i])

# %%
data1
# Out:
# ['จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรียน ทำรถติด แทนที่จะจัดรถเข้า\nทางออกทาง ให้เข้าออกปะปนกันไปหมด',
#  '0.0',
#  'คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหายๆค่ะ มีกระตุกๆด้วย',
#  '0.0',
#  'เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ',
#  '0.0',
#  'กฎระเบียบไม่ดี เเถมยังตีเด็กอีก',
#  '0.0',
#  'ตรงประตูระวังเชือกผูกรองเท้าด้วยนะคะ อันตราย',
#  '0.0',
#  'ผึ้งจะเปิดเรียนจะไห้จ่ายค่าเทอมเลย ควรนึกถึงพ่อกับแม่บ้างนะให้ตายเถอะ',
#  '0.0',
#  'ถามไปก็ไม่เคยมาอ่านหรือตอบ แย่มาก',
#  '0.0',
#  'ควรคืนค่าเทอมห้อง EP เพราะว่าไม่ได้เรียนที่โรงเรียน เรียนที่บ้านทั้งเทอมเลย',
#  '0.0',
#  'เป็นการช่วยเหลือที่เล็กน้อยมาก ห่วยที่สุด',
#  '0.0',
#  'ในห้องน้ำควรมีทิชชู่ ยิ่งเด็ก ผญ สำคัญเรื่องความสะอาด และเด็กบางคน\nเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ',
#  '0.0',
#  'เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่\nเหมือนกัน พิจารณาแก้ไขด้วย',
#  '0.0',
#  'เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่\nเหมือนกัน พิจารณาแก้ไขด้วย',
#  '0.0',
#  'เปิดเรียนปกติครบทุกระดับชั้นแต่ถ้าทางโรงเรียนไม่ให้ผู้ปกครองนำรถ\nเข้าโรงเรียนไปส่งเด็กๆมันคงจะแย่สำหรับผู้ปกครองหลายๆคนนะค่ะ \nรบกวน รร. ลองลงมาดูลานจอดรถใหม่ตอนเช้าตอนเย็นบ้างนะค่ะว่ารถ\nมันติดแค่ไหน',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200bเพราะถ้าเปิด\nเต็มรูปแบบรถคงติดมาก',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200bเพราะถ้าเปิด\nเต็มรูปแบบรถคงติดมาก',
#  '0.0',
#  'เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน\nแน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ \n20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี\nรถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น\nมากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้\nรับความกรุณาพิจารณาด้วย',
#  '0.0',
#  'เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน\nแน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ \n20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี\nรถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น\nมากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้\nรับความกรุณาพิจารณาด้วย',
#  '0.0',
#  'ไม่เข้าใจรรคืนเงินทีไรคนบ่นกันจัง ลูกชายคนโตเรียนโครงการพิเศษของ\nรร รัฐบาล ค่าเทอมก็เกือบสองหมื่นคืนเงินมาแค่ 1380 ไม่เห็นมี ผปค\nโพสบ่นในเพจรร แต่นี่ รร เอกชนขนาดภาคปกติยังคืนเยอะกว่ารรรัฐบาล\nอีก คนบ่นกันจัง😞',
#  '0.0',
#  'อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจน และเพียงพอด้วยครับ\u200b\nตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอดก็วนไป\u200bเรื่อยๆ ลูกก็รอไปจนกลับ\nคนสุดท้ายของห้อง\u200b เกรงใจคุณครูที่รอเราคนเดียว\u200b',
#  '0.0',
#  'จัดเวลาการเรียนการสอนน้อยเร่งรัดทุกเรื่องผลการเรียนจะเป็นอย่างไรไม่รู้\nเอาแต่จะตัดระบบให้เป็นปัจุบันในการทำงานของหน่อยงานตนเอง',
#  '0.0',
#  'กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth \nด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์\nเอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก',
#  '0.0',
#  'กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth \nด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์\nเอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก',
#  '0.0',
#  'ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม \nคลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ\nวานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก\nษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา\nบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ',
#  '0.0',
#  'ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม \nคลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ\nวานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก\nษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา\nบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ',
#  '0.0',
#  'โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย\nวิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ \nยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ',
#  '0.0',
#  'โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย\nวิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ \nยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ',
#  '0.0',
#  'สรุปเลยนะคะ การเรียนออนไลน์ระดับประถม ไม่มีการปรับปรุงให้ดีขึ้น เช่น \nเสียงจากคลิป ฟังไม่รู้เรื่อง อุปกรณ์ รร ให้คุณครูลงทุนกันเองหรอคะ เสียง\nพูดได้ยินดับๆหายๆ รร ควรลงทุนอุปกรณ์ให้คุณครูนะคะ เช่น ไมค์ในการ\nอัดคลิป เรื่องภาพก็อีกเรื่องนึง แต่เรื่องเสียงนี่สำคัญที่สุด เพราะ นร. ต้อง\nฟังที่คุณครูอธิบาย กลายเป็นว่า ทำงานซ้ำซ้อน ขอให้ รร ลงทุนอุปกรณ์\nให้ครูด้วยนะคะ',
#  '0.0',
#  'คลิปค้างและกระตุกมากค่ะเป็นเกือบทุกวิชาค่ะ ตั้งแต่เช้าจนถึงตอนนี้ค่ะ \nดูไม่รู้เรื่องเลยค่ะ',
#  '0.0',
#  'vdo กระตุกมากโหลดช้ามากดูแล้วสะดุดมาก ไม่รู้เรื่องเลยในการดูแต่ละวิชา',
#  '0.0',
#  'เว็ปโรงเรียนโหลดนานมาก พอเปิดได้คลิปกระตุกดูไม่รู้เรื่องเลยค่ะ',
#  '0.0',
#  'ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง\nเรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก\nนั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม\nที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ',
#  '0.0',
#  'ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง\nเรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก\nนั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม\nที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ',
#  '0.0',
#  'ทาง รร ควรซื้อแอพ Zoom premium ให้ครูด้วยค่ะ เวลาแค่ 40 นาทีจากแอพ\nzoom ฟรี มันไม่พอ ในกรณีสอนสดกว่าจะรอให้นักเรียนมาครบกินเวลาไปกว่า 10 \nนาทีเลย เผื่อเวลาเน็ตหลุดด้วย เสียเวลามากเรียนก็ไม่ต่อเนื่อง ไม่เต็มที่ ยิ่งเด็ก \nม.ปลายนี่ไม่ต้องพูดถึงเลย เด็กๆบ่นกันเยอะมากค่ะ',
#  '0.0',
#  'ขอโทษนะคะกดเข้าไปในวีดีโอเปิดไม่ได้ค่ะเปิดติดบ้างไม่ติดบ้างค่ะ ช่วยแก้ไข\nหน่อยค่ะ เป็นแบบนี้บ่อยๆไม่ไหวนะคะ',
#  '0.0',
#  'ช่วยแก้ไขหน่อยนะคะ เปิดไม่ได้เลยคะ ลองใช้ทั้ง WiFi และ 5G ก็เปิดไม่ได้คะ \nเปิดติดบ้างไม่ติดบ้าง เซ็งคะ',
#  '0.0',
#  'จัดซัมเมอรไปเลยคะ ดิฉันไม่ให้ลูกไปเรียนแน่นอน ถือว่าทำบุญให้ รร. คะอันตราย\nขนาดนี้ ยังคิดจะจัดสอนซัมเมอร์อีก โควิดวันนี้ คนติดเพิ่มอีกเป็นพันคน เด็กๆติดมา \nถึงหายก็ปอดหายไปครึ่งนึง อนาคตสุขภาพเด็กคงแย่',
#  '0.0',
#  'ช่วยดูด้วยค่ะวาาเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหนพลาดโอกาสหลายอย่างยัง\nต้องพลาดที่เรียนอีก',
#  '0.0',
#  'ทางโรงเรียน\u200b จะต้องเร่งแก้ไขให้นะคะ\u200b ไม่ใช่ให้เด็กนักเรียน\u200bหรือ\u200b ผู้ปกครอง\u200b จะต้อง\nเป็นคนประสานเองนะคะ\u200b เพราะได้แจ้งรายละเอียด\u200b และ\u200b ปัญหา\u200b ไว้ให้พิจารณา\nหมดแล้ว\u200b ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ***',
#  '0.0',
#  'ห้องน้ำนักเรียนอาคาร 8 อับชื้นและสกปรกมาก รบกวนตรวจด้วยนะคะ',
#  '0.0',
#  'รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้แล้วนะคะ...',
#  '0.0',
#  'กระตุกมากค่หยุดๆะ เล่นๆ ตลอดเลยค่ะ  เสียอารมณ์ค่ะ',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน ห่วยมาก',
#  '0.0',
#  'กระตุกบ่อย\u200b file ค้างมากๆๆเลยค่ะ\u200b 😅😅 เด็ก\u200bเดินหนีไปแล้วค่ะ',
#  '0.0',
#  'กระตุกทุกคลิปเลย เรียนไม่ได้เลยค่ะ แย่ที่สุด',
#  '0.0',
#  'เข้าดูไม่ได้เลยครับ ทั้งกระตุกทั้งค้างครับ 😞',
#  '0.0',
#  'กระตุกๆ ค้างๆ กว่าจะผ่านไปแต่ละวิชาใช้เวลานานมาก แย่มาก',
#  '0.0',
#  'กระตุกสะดุดตลอด ทุกวิชา ไม่สามารถเรียนได้เลยแบบนี้เด็กก็แย่สิคับ',
#  '0.0',
#  'ป.2 ป.4 เปิดเข้าดู VDO ไม่ได้เลยค่ะ ไม่ไหวนะคะแบบนี้',
#  '0.0',
#  'ยังกระตุกอยู่เลยค่ะเรียนไม่ได้เลยค่ะ เสียเวลามากค่ะ',
#  '0.0',
#  'กระตุกทุกlink. ห่วยคะ',
#  '0.0',
#  'ควบคุมการผลิตให้ดี เพิ่มโปรตีนด้วยนะครับ ไม่ใช่มีแต่ผักกับผลไม้ ห่วยมากก',
#  '0.0',
#  'เมนูก๋วยเตี๋ยวน้องผมบ่นว่ากินแต่หมี่ๆอย่างเดียว 😅',
#  '0.0',
#  'วันนี้ก็มีน้ำซุปฟักลูกบอกว่าจืดอย่างกะน้ำเปล่าเลยค่ะ ปรับปรุงด้วยค่ะ 😂😂😂',
#  '0.0',
#  'ติดป้ายลดความเร็วเพิ่มเติมน่าจะดีนะคะ ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่เพียบ',
#  '0.0',
#  'เส้นใหญ่ กะทิ เป็นสิ่งที่เสียง่าย ควรหลีกเลี่ยง มาทำอาหารให้เด็กๆ วันนี้เด็ก \nปวดท้อง ท้องเสีย หลายคนคะ',
#  '0.0',
#  'เด็กๆ บอกข้าวแข็งค่ะ เมื่อวาน',
#  '0.0',
#  'เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ',
#  '0.0',
#  'หวังว่าเปิดเทอมนี้จะได้ฟังจากลูกเรื่องรสชาติและปริมาณที่เหมาะสมนะคะ',
#  '0.0',
#  'เพิ่มปริมาณอาหารให้พอกับความต้องการด่วนเลยค่ะ ห่วยตั้งแต่เปิดเทอม!!',
#  '0.0',
#  'ผมสงสารเด็ก รร. นี้มากคือ หนึ่งเลยนะ โรงอาหาร คือเเบบว่ามันเเน่นมากๆเลยครับ',
#  '0.0',
#  'ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการ\nอาหารค่ะ',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก ควรแก้ไขนะคะ',
#  '0.0',
#  'ควรพิจารณาที่จอดรถได้แล้วนะครับ',
#  '0.0',
#  'ลานจอดใหม่ ฝุ่น เยอะมาก',
#  '0.0',
#  'เมนูกระเพราหมูวันอังคารที่ผ่านมาช่วยลดความเผ็ดลงด้วยคะ',
#  '0.0',
#  'รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ...',
#  '0.0',
#  'ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่น และดินออกบ้างน่าจะดีนะคะ ',
#  '0.0',
#  'ไม่ต้องใส่พริกน่าจะดีกว่านะคะ เด็กประถมไม่ได้ทานเผ็ดได้ทุกคนค่ะ',
#  '0.0',
#  'ทำอาหารที่เด็กทานได้ง่ายกว่านี้ค่ะ เมนูแกงสำหรับเด็กประถมยังไม่เห็นด้วยค่ะ',
#  '0.0',
#  'เช็คสหกรณ์ด้วยนะคะ หน้ากากอนามัยแพงมากค่ะ',
#  '0.0',
#  'รับทราบปัญหาบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆค่ะ',
#  '0.0',
#  'พิจารณาเรื่องความสะอาดให้เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร',
#  '0.0',
#  'กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะ',
#  '0.0',
#  'กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะแล้วก็ควรจะทำให้อาหารมีรสชาติ\nมากกว่านี้',
#  '0.0',
#  'วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด \nควรทำตามตารางนะ',
#  '0.0',
#  'ส่วนใหญ่\u200bมีแต่ของทอด ไส้กรอก ลูกชิ้น ฝากให้พิจารณา\u200bอาหารที่มีประโยชน์\u200bให้\nเด็กด้วยค่ะ',
#  '0.0',
#  'ไม่ให้รถเข้าออก แบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน',
#  '0.0',
#  'เมนูอาหารวันเสาร์ เป็นเมนูไก่ทอด เป็นอย่างอื่นบ้างก้อดีน่ะค่ะ เด็กๆ บ่นว่า \nไก่ทอดทุกเสาร์เลย',
#  '0.0',
#  'น่าจะมีมีพื้นที่พักคอยให้กับญาติ ๆ หน่อยนะค่ะ เพราะว่ารอกว่าจะสอบเสร็จก็ไม่รู้\nว่าจะเอาตัวไปอยู่ที่ไหน',
#  '0.0',
#  'กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ\nพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด\nท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้\nเด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร',
#  '0.0',
#  'กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ\nพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด\nท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้\nเด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร',
#  '0.0',
#  'ขอร้องเรียนเรื่องครูประถมหน่อยค่ะ ครู ***** ***** ตีนักเรียนเพียงเพราะนักเรียน\nไม่ยอมใส่ถุงเท้าเข้าห้องเรียน ที่จริงแล้วน้องรองเท้าเปียกมาเพราะเข้าห้องน้ำมา\nอยากให้ครูท่านนีได้รับคำตักเตือนหน่อยค่ะ',
#  '0.0',
#  'รายการอาหารวันเรียนพิเศษวันเสาร์ ไม่น่ามีคะเมนูผัดมาม่า ไม่โอเคคะ จากเส้น\nมาม่าเป็นเส้นก๋วยเตี๋ยวน่าจะดีกว่านะคะ.',
#  '0.0',
#  'ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะคะ \nลดฝุ่นละออง',
#  '0.0',
#  'ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถ เด็ก ๆ เปิดหน้าต่างห้องเรียนรับลม แต่เวลารถขับ\nผ่านฝุ่นปูนปลิวอย่างเห็นได้ชัด',
#  '0.0',
#  'ช่วยมาวัดค่าอาคาร สอง อาคารสี่ อยู่ติดกับลานจอดใหม่ ฝุ่น เยอะมาก ผบรห \nลองมานั่งเรียนกับเด็กๆหน่อย',
#  '0.0',
#  'หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆเดินก็ไกลต้องมากลัวฝุ่นอีก \nปอดไม่พังตอนนี้ก็ไม่รู้จะว่าอย่างไง วอนท่านผู้บริหารลงมาเดินดินแก้ปัญหาให้\nเด็กๆด้วยเถอะ หรือพวกท่านและคณะไม่เดือดร้อนเพราะท่านใช้อภิสิทธ์ชนจอด\nใน รร ได้หรือครับ',
#  '0.0',
#  'กับข้าวเด็กเผ็ดนะคะ (ของอิสลามค่ะ) ลูกๆ ทานตั้งแต่อนุบาล ตอนนี้ประถมแล้ว \nยังไม่ปรับปรุงเลยค่ะ',
#  '0.0',
#  'ฝากพิจารณารถตู้รับส่งนักเรียนด้วย นั่งกันแน่นมากๆเลย รู้สึกกังวลครับ',
#  '0.0',
#  'หนังสือเรียน 10 วิชาหนักมากค่ะลูกแบดไม่ไหวค่ะ บ่นปวดหลัง เดินก็ไกล \nขึ้นสะพานลอยก็จะหงายหลังตกสะพาน สงสารเด็ก',
#  '0.0',
#  'ผลไม้ที่ให้เด็กทานพวกเงาะเด็กไม่ทานกันเลยค่ะ อีกอย่างปลอกกันไม่เป็นใช้ปาก\nกัด อันตรายนะคะ ยาฆ่าแมลงทั้งนั้น',
#  '0.0',
#  'ช่วยพิจารณาเรื่องการส่งงานส่งเป็นรายอาทิตย์หรืออย่างไรก็ได้ที่ทางคุณครูสะดวก \nไม่ใช่แค่มีคลิปแล้วเรียนบอกว่าเรียนจบแล้ว',
#  '0.0',
#  'ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่\u200bมีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนม\nที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ และสังเกต\u200bว่าเทอมนี้ผลไม้ไม่มีขาย\nแล้ว ฝากให้พิจารณา\u200bอาหารที่มีประโยชน์\u200bให้เด็กด้วยค่ะ',
#  '0.0',
#  'ขออนุญาตนะคะ อาหารเด็กกลางวัน ป.1ถึง ป.6อาหารเหมือนกันหมด ควรแบ่งตาม\nความเหมาะสมเด็กเล็ก และเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ ลูกชาย\nคนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่า\nไม่อร่อยและกินไม่ได้เลยค่ะถึงจะเป็นเด็กแต่ก็มีหัวใจนะคะ ขอให้กินได้ก็พอค่ะ\nอาหารจะมีคุณภาพเราต้องใส่ใจในทุกรายละเอียดและทุกๆอย่างค่ะ ขอบคุณค่ะ',
#  '0.0',
#  'แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่าเพราะบางทีได้ไก่จ่อ 2 ชิ้น ไส้\nกรอก 2 ชิ้น ไข่ต้มกินไม่เป็นกินไข่ขาวนิดหน่อย สงสารลูกให้ห่อข้าวก็ไม่ยอม\nกลัวไม่เหมือนเพื่อน เราเสียเงินเพิ่มก็ได้นะ ขอให้ดีกว่านี้ ระวังผู้ปกครองทนไม่\nไหวแอบถ่ายออกสื่อจะดังเหมือน รร.อื่นๆนะคะ อายญาติพี่น้องว่าเราส่งลูกมา\nเรียน ที่นี่ได้งัย',
#  '0.0',
#  'ทางโรงเรียน\u200b จะต้องเร่งแก้ไขให้นะคะ\u200b ไม่ใช่ให้เด็กนักเรียน\u200bหรือ\u200b ผู้ปกครอง\u200b จะต้อง\nเป็นคนประสานเองนะคะ\u200b เพราะได้แจ้งรายละเอียด\u200b และ\u200b ปัญหา\u200b ไว้ให้พิจารณา\nหมดแล้ว\u200b ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ***',
#  '0.0',
#  'อยากจะให้ทาง รร. เพิ่มเมนูหรือเพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่า\nได้ทานหมูก้อน 1ก้อนกับซุป น้อยไปนะคะ กับมาตรฐาน กับรร.ระดับนี้ ไม่ไหวๆ',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน',
#  '0.0',
#  'เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวันไม่ดี',
#  '0.0',
#  'เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่เหมือนกัน พิจารณาแก้ไขด้วย',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ. ลองให้รถครูจอดข้างนอกแล้วเดินลุยฝนมาบ้าง',
#  '0.0',
#  'เมนูแกงสำหรับเด็กประถมยังไม่ควร ยังทานยากไป',
#  '0.0',
#  'เรียนปกติแล้วทำไมให้รถเข้าออกได้ปกติทุกคนมีความป้องกันตัวเองอยู่แล้วแบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200b เพราะถ้าเปิดเต็มรูปแบบรถคงติดมาก',
#  '0.0',
#  'นี่คือความคิดของคนภายนอกและนี่ก็คือผลงานของทางโรงเรียนทำให้คนข้างนอกเข้าใจ ผปค. ผิดจะทำยังไงก็รีบๆ ทำเถอะค่ะ ซึ่งมันไม่ใช่ความผิดของ\n ผปค. เลยนะคะ',
#  '0.0',
#  'ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่นมากสังเกตุมาหลายอาทิต\nแล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้รับความกรุณาพิจารณาด้วย',
#  '0.0',
#  'เปิดประตู3 ไม่ได้ช่วยอะไรเลย โรงเรียนจะต้องเปิด ประตู 4และ ประตู 5 เพื่อช่วยระบายรถ ที่ลานจอดรถ ในช่วงเช้า 6.00 - 8.30 น. พิจารณาแก้ไขด้วย',
#  '0.0',
#  'อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ\u200b ตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอดก็วนไป\u200bเรื่อยๆ\n ลูกก็รอไปจนกลับคนสุดท้ายของห้อง\u200b เกรงใจคุณครูที่รอเราคนเดียว\u200b',
#  '0.0',
#  'แต่ของลูกเป็นการตักรอบแรกนะคะ ถ้ามันไม่พอแสดงว่าไม่มีใครได้รอบสองแน่นอน \nช่วยพิจารณาหน่อยนะคะว่าเป็นการตักรอบแรกค่ะ',
#  '0.0',
#  'ประกาศผลสอบช้ามากจังค่ะ แต่ตังก็จะให้จ่ายก่อน งง ใจค่ะ',
#  '0.0',
#  'วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด แย่มาก',
#  '0.0',
#  'ได้ใบเกรดและใบจบช้าคะรร.อื่นเขาแจกกันตั้งแต่เดือนที่แล้ว แล้วนี่ยังคิดGPAของแต่ละกลุ่มสาระไม่เสร็จทำไมถึงทำงานช้ากันแบบนี้คะถ้านร.\nกรอกแก้ไขข้อมูลไม่ทันทำให้มีผลไม่ติดมหาลัยล่ะคะจะรับผิดชอบยังไง ทำไมถึงประกาศในcpw classroomก่อนไม่ได้คะ ห่วยสิ้นดี',
#  '0.0',
#  'แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่า',
#  '0.0',
#  'ขออนุญาตนะคะอาหารเด็กกลางวันป.1ถึงป.6อาหารเหมือนกันหมด ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ',
#  '0.0',
#  'ได้รับข้อมูลแล้ว กรุณานำไปพิจารณาด้วยนะครับไม่ใช่ขอบคุณอย่างเดียวครับ',
#  '0.0',
#  'ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่\u200bมีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนมที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ',
#  '0.0',
#  'เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ',
#  '0.0',
#  'เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ',
#  '0.0',
#  'อีกเรื่องห้องน้ำสกปรกมากๆๆครับ ร่วมถึงน้ำดื่มอีกก็ไม่เคยตรวจสอบเลยครับ จนเดียวนี้เด็กๆถึงไม่อยากเข้าห้องน้ำกับดื่มน้ำที่โรงเรียนแล้วครับ',
#  '0.0',
#  'ทางโรงเรียนเลือกตอบแค่บางคำถามหรอครับ เห็นคำถามไหนเกี่ยวกับโปรแกรม ซูม ทางโรงเรียนไม่เข้ามาตอบเลย แย่มากครับ',
#  '0.0',
#  'ไม่คิดจะคืนค่าอาหารเลยหรอค่ะ',
#  '0.0',
#  'ทางผู้ปกครองไม่สะดวกใจให้นักเรียนไปค่ายพุทธบุตรเเล้วค่ะ',
#  '0.0',
#  'โรงเรียนคะ อยากให้แก้ชื่อให้หน่อยค่ะ โพสต์ล่าสุดอ่ะค่ะพิจารณาแก้ไขด้วย',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200b',
#  '0.0',
#  'รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ...',
#  '0.0',
#  'รบกวนออกมาชี้แจ้งด้วยค่ะ',
#  '0.0',
#  'ตรงลานจอดที่ยังเป็นดิน เด็กเดินอยู่ ขับเบาๆหน่อยนะครับ ฝุ่นมันเยอะ',
#  '0.0',
#  'เพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่าได้ทานหมูก้อน 1ก้อนกับซุป \nน้อยไปนะคะ ไม่ไหวๆ',
#  '0.0',
#  'กระตุกมากค่ะ เล่นๆหยุดๆ ตลอดเลยค่ะ',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน',
#  '0.0',
#  'กระตุกทุกlink. ห่วยคะ',
#  '0.0',
#  'แย่มากกกกกกค่ะ',
#  '0.0',
#  'รสชาติอาหารแย่มาก ไม่ไหวจะเคลียร์',
#  '0.0',
#  'ใช้เดือนเดียวพังแย่ๆมากๆ',
#  '0.0',
#  'ปรับปรุงด่วน!!!! ',
#  '0.0',
#  'เสียเวลามากๆ กว่าจะทำเรื่องคืนเงินได้ ',
#  '0.0',
#  'เสียความรู้สึกค่ะ',
#  '0.0',
#  'ไม่ไหวๆเลย',
#  '0.0',
#  'ถ้าเพิ่มร้านอิสลามก็ดีนะครับ',
#  '0.0',
#  'วันนี้ล่มอีกแล้วนะคะ เติมเงินผ่านแอพไม่ได้ค่ะ',
#  '0.0',
#  'ห้องปกติคืนนิดเดียว อย่าคืนเลยค่าเน็ตยังไม่พอเลย\nช่วยเหลือ มันต้องทุกระดับชั้นทุกคน ไม่ใช่บางกรณี ห่วยมากค่ะ',
#  '0.0',
#  'จะใช้แค่มาตราการเบื้องต้น แล้วยะงเมื่อ วันอังคารที่ผ่านมาทางโรงเรียนยังจัด\nให้มีงานปัจฉิมนิเทศ อีกซึ่งเพิ่มความเสี่ยงในการติดเชื้อขึ้นไปอีก ถ้าโควิท19 \nระบาดในเด็กน่ากลัวมากนะค่ะ อันตรายต่อเด็กๆ',
#  '0.0',
#  'รร.ควรน่าจะป้องกันโดยการห้ามเด็ก นร.ที่มีบ้านอยู่ในเขตเสี่ยงงดการเรียน\nและให้เรียนออนไลน์เป็นกลุ่มพิเศษไปเพื่อเป็นการป้องกันตั้งแต่ต้น',
#  '0.0',
#  'โรงอาหาร รร กินจนเบื่อละ',
#  '0.0',
#  'ควรมีดื่มน้ำสะอาดๆ ที่กินอยู๋ตอนนี้เด็กบอกรสชาติแปลกๆ ไม่ไหวนะคะแบบนี้',
#  '0.0',
#  'พอคนเยอะไป อาจารย์ที่อยู่ริมก็ตัวขาด เพราะ Greenscreen ไม่กว้างพอครับ',
#  '0.0',
#  'ระยะภาพ มีผลต่อความรู้สึกของผู้ฟังนะครับ แนะนำใช้ Close up \nตอน ผอ.พูดบางก็ดีครับ ตอนนี้มันกว้างและแช่เกินไป',
#  '0.0',
#  'น่าจะให้ ม.ต้น ม.ปลาย สลับกันไปเรียนนะคะ',
#  '0.0',
#  'แล้วเรื่องค่าชุดละคะยังไม่เห็นได้เลย จะจบเทอมแรกแล้ว',
#  '0.0',
#  'คิวอาร์โค้ดเล็กมาก แตกด้วยแสกนไม่ได้ค่ะ',
#  '0.0',
#  'ปิดต่อไปเด็กก็งงกับการเรียน แต่ถ้าเปิดก็เสี่ยง 😰😰',
#  '0.0',
#  'โรงเเรียนควรมีนโยบายเรียนวันคู่วันคี่ค่ะ เด็กๆจะได้ไม่อันตรายต่อการเสี่ยง',
#  '0.0',
#  'ลูกเข้าห้องเรียนออนไลน์ไม่ได้ ตัวลิ้งทำไมไม่เตรียมให้พร้อมก่อน',
#  '0.0',
#  'ร้อนกะร้อนน ฝุ่นกะเยอะะ โอ๊ยยยฟรุ๊ดฟริ๊ดดโว้ยยย',
#  '0.0',
#  'น่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะ',
#  '0.0',
#  'ตอนนี้ควรบริหารจัดการ เรื่องการจราจรก่อนนะครับ ช่วงเย็นรถติดขนาดไหน\nลองออกมายืนดูบ้างครับ ติดยาวไปยันปากเกร็ด',
#  '0.0',
#  'ที่รถมันติดหนักทุกวันนี้ก็เพราะแก้ปัญหาด้วยวิธีง่อยๆแบบนี้แหละค่ะ แย่มาก',
#  '0.0',
#  'คิดราคาค่าเทอม ep..แพงกว่าธรรมดา',
#  '0.0',
#  'ที่ผ่านมาทางโรงเรียนตัดสินใจเองหมด ควรมีทางแก้ไขที่ดีกว่านี้ครับ',
#  '0.0',
#  'ควรให้เด็กเดินเข้าไปได้ก็ดีนะครับ เพราะช่วยลดเวลาไปถึงประตู 1 \nหรือลานจอดรถไปได้หลายสิบนาทีเลย',
#  '0.0',
#  'กลายเป็นว่าทุกวันนี้มีทางเดียวที่ต้องใช้ รร.คิดว่ารถกี่พันคันที่ต้องใช้ทางนี้ ห่วย!',
#  '0.0',
#  'ควรให้วนเหมือนเดิมนะคะ',
#  '0.0',
#  'ห้องน้ำสกปรกมาก รบกวนตรวจด้วยนะคะ',
#  '0.0',
#  'ทุกวันนี้รถติดกระทบยาวเลยค่ะ ควรแก้ปัญหาจุดนี้ได้แล้ว',
#  '0.0',
#  'ปัญญาอ่อนมาก ขนาดฝนตกลงมาแล้ว บอกต้องรอคำสั่งๆ',
#  '0.0',
#  'การจราจรอัมพาตมาก หางแถวยาวทุกเส้นทาง รร.ควรพิจารณานะคะ',
#  '0.0',
#  'ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น ควรมองปัญหาตรงนี้ได้แล้ว',
#  '0.0',
#  'ตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอดก็วนไป\u200bเรื่อยๆ',
#  '0.0',
#  'รปภ.ต้องเข้มงวดบ้างนะคะ เพราะหลายๆคนบ่นว่าโรงเรียนทำให้รถติด',
#  '0.0',
#  'ควรห้ามรถทุกชนิด เข้า รร. เลยดีที่สุดรวมทั้ง ครูด้วย จบ',
#  '0.0',
#  'ปีหน้าถ้ายังบริหารแย่แบบนี้อีก\u200b ผมว่าจะให้ลูกย้ายโรงเรียนดีกว่า',
#  '0.0',
#  'อย่าเอาแต่นั่งห้องแอร์\u200b ผู้ปกครองทุกคนเค้าเบื่อพวกท่านเต็มทนแล้วครับ',
#  '0.0',
#  'ปัญหาทุกๆปัญหา มีทางแก้ มีทางออก ยอมรับฟังเสียงขอ ผปค บ้าง \nไม่ใช่ เอาแต่หาเงินเข้า รร',
#  '0.0',
#  'ปัญหามันไม่ได้เกิดกับผู้ปกครองหรอกคะ ปัญหามันเกิดจากการที่พวกท่านๆ\nเพิกเฉยและเอาเปรียบมากกว่า',
#  '0.0',
#  'ให้คุณครู และอาจารณ์. เชิญออกมาจอดรถที่ลานจอดด้วยนะค่ะ วันไหนที่ฝนตก\nทั้งตอนเช้าและตอนเย็นจะได้รับรู้ถึงปัญหาของ ผปค.และนักเรียน',
#  '0.0',
#  'รบกวนเปิดตั้งแต่16.00 เหมือนเดิมค่ะ ส่วนรถผู้ปกครองที่เห็นแก่ตัว ล็อคล้อ \nจ่ายค่าเสียหายไปเลยค่ะ ไม่งั้นรถจะสา',
#  '0.0',
#  'ความเห็นแก่ตัวของคนส่วนน้อย ทำให้คนส่วนใหญ่ที่เคารพกติกาต้องมีปัญหา\nเมื่อผู้ใหญ่ยังไม่รู้จักกฏกติกา แล้วจะเอาอะไรไปสอนลูกสอนหลานล่ะ',
#  '0.0',
#  'ควรหาทางแก้ปัญหาให้ดีกว่านี้นะ เมื่อวานผมติดอยู่ในลานจอดรถ \nเกือบ 2 ชั่วโมง ผมอยู่แถวนี้มา 10 ปี ไม่เคยเจอรถติดขนาดนี้ ',
#  '0.0',
#  'ลูกชายคนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่าไม่อร่อยและกินไม่ได้เลยค่ะ',
#  '0.0',
#  'ที่ผมเลือกให้ลูกมาเรียนเอกชนสู้กับค่าเทอมที่ค่อนข้างสูง เพื่อการศึกษา\nและสภาพแวดล้อมที่ดี แต่สิ่งที่เจอตอนนี้มันไม่คุ้มค่ากับค่าใช้จ่ายที่เผมต้องเสีย',
#  '0.0',
#  'การที่ไม่แก้ปัญหา ปัญหามันจะไม่จบเมื่อมันสะสมมากๆ มันลุกลามบานปลายนะคับ',
#  '0.0',
#  'ขออนุญาตนะคะ คือตอนนี้ดิฉัน (และเชื่อว่าอีกหลายๆคน) ได้รับผลกระทบในช่วงเช้าเป็นอย่างมาก จากการจราจรที่ติดขัดในการเปิดการเรียนการสอนแบบเต็มระบบ ',
#  '0.0',
#  'ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ',
#  '0.0',
#  'ควรแก้ให้เปิดประตูทุกด้านเพราะตอนเช้ามันติดหนักมากหน้ารร.เพราะการป้องกัน\nแค่นี้ไม่ช่วยอะไรเลย',
#  '0.0',
#  'การจราจรอัมพาตมาก หางแถวยาวทุกเส้นทาง พอผ่านหน้ารร.ได้เท่านั้นแหละ โล่งเชียว รร.ควรพิจารณานะคะ ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น',
#  '0.0',
#  'แล้วคนที่ไม่ได้เรียนเสริม ก็ต้องลำบากเหมือนเดิมใช่ไหม ต้องรอเข้าประตู 5 เวลา\n17.00 น.มันใช่ไหมทุกวันนี้กว่าจะมาถึง รร.ก็เสียเวลามากพอแล้วเห็นใจกันบ้างนะ',
#  '0.0',
#  'ควรตั้งกรวยบังคับให้ออกประตู4ทางเดียวนะคะ ให้ยามมาโบกเหมือนเดิม เพราะ \nผปค.จำเป็นต้องออกประตู4ตอน4โมงอะคะ ',
#  '0.0',
#  'โรงเรียนไม่สมควรทำเป็นอย่างยิ่งค่ะ การที่มีรถแอบเข้าไปจอดควรจัดการปัญหา\nให้ รปภ. และเจ้าหน้าที่ตรวจสอบอย่างเข้มข้น เพราะมันจะกระทบกับผู้ปกครอง\nจำนวนมากค่ะ',
#  '0.0',
#  'ผู้ปกครองทำผิดกฎ 1 ท่านแต่ทางโรงเรียนตัดสินทุกท่าน\u200b ปัญหารถตืดเป็นชั่วโมง\nรอบโรงเรียนมีวิธีแก้ไม่ควรปล่อยเป็นภาระผู้ปกครองต่อไป',
#  '0.0',
#  'ผลงานที่ยอดแย่ 8:32 ผู้ปกครองยังวุ่นวายวนจอดรถเพื่อเดินไปส่งลูก สุดยอดมัยคะ รถติดแออัดสะสมยันสะพานพระราม4จร้า',
#  '0.0',
#  'ณ.เวลานี้วันนี้ รร.เปิดทุกระดับชั้นเพราะวันที่ 8-9 กย รร ยังมีการสอบนักเรียน\nม.ปลายกับ ม.ต้นยังสลับกันมาก็ยังไม่เต็มรูปแบบ แต่วันนี้รถติดมากเป็นผลมาจาก \nรร.ชลประทานเปิดเรียนเต็มทุกระดับชั้นต้องพิจารณานะคะว่าควรจะทำยังไง',
#  '0.0',
#  'ขณะนี้เวลานี้ยังติดกันอยู่ในลานจอดรถแบบขยับไม่ได้เลย เสียเวลามากมาย',
#  '0.0',
#  'รบกวนทาง รร. ใส่ใจปัญหานี้ก่อนจะลามไปเรื่องอื่นค่ะ ควรปรับปรุงแนวทางการ\nจราจรใน รร. ถ้ามันไม่เวิร์ค ก็ปรับปรุง ',
#  '0.0',
#  'แย่มาก\nบ้านอยู่แค่ใน ซ. รร.อัมพรไพศาลออกบ้าน 6.00 น. จะส่งลูกให้ทันเรียนเสริมเช้า 7.30 น.ยังสาย',
#  '0.0',
#  'ตอนเย็นก็มี ผปค เห็นแก่ตัวจอดรถปิดหน้ารถที่จอดในช่อง แล้วไม่ใส่เกียร์ว่าง\nเราต้องรอนานมากกว่านางจะมา แล้วจอดกัน2ด้านเลย รถที่วิ่งออกไปลำบากมาก ',
#  '0.0',
#  'เกินไปแล้ว ค่าเทอมขึ้นตลอดโต๊ะเรียนปรับปรุงหน่อยคะเก่ามาก',
#  '0.0',
#  'ไม่ต้องอ้างฝุ่นเพาะตึกเรียนข้างลานจอดรถใหม่เด็กกินฝุ่นเข้าไปเต็มๆ',
#  '0.0',
#  'ห้องเรียน ห้องนำ้ ภาชนะที่ใส่อาหารเด็ก ผู้บริหารควรจะมาดูแลเอาใจใส่เรื่องนี้มั่งนะคะ. ยอดแย่ลงทุกวันคะ.',
#  '0.0',
#  'ควรจะเปิดให้รถผู้ปกครองเข้าไปรับส่งเด็กได้นะคะ',
#  '0.0',
#  'ตอนนี้เดือดร้อนมาก ลูกเรียนอนุบาล 2 กับ ป.1 วนรถกว่าหาที่จอด \nเข้าไปส่งใน รร.ได้ เสียเวลาเป็นชั่วโมง',
#  '0.0',
#  'รร.ปรับปรุงเรื่องที่จอดรถไม่ใช่ว่าจะทำให้เหตุการณ์รถติดดีขึ้น ที่ไม่โวยวาย\nเพราะต้องทน ถ้ายังเป็นอยู่อย่างนี้',
#  '0.0',
#  'รถติดมากคะไม่สมควรปิดประตู4ติดทั้งเช้าเย็นไม่เฉพาะแต่ผู้ปกครองรถทั่วไปก็พลอยติดไปด้วยเพราะไม่มีทางระบายรถผู้บริหารควรมาดูความเป็นจริงบางนะคะแย่มากช่วงนี้',
#  '0.0',
#  'ลานจอดรถก็ไม่เพียงพอ พิจารณาแก้ไขด้วย !!',
#  '0.0',
#  'ทาง รร. ควรทำมาตรการเด็ดขาดไปเลยค่ะว่าไม่ให้จอด ให้ขับรับแล้วออกเลย',
#  '0.0',
#  'สงสารเด็กๆที่ต้องเดินไกล และผู้ปกครองในตอนเช้าก็ต้องรีบไปทำงานด้วยค่ะ',
#  '0.0',
#  'ถ้าทุกคนปฎิบัติตามกฎและระเบียบที่ทางโรงเรียนวางไว้ก็คงไม่วุ่นวายมากแบบนี้\nแต่มีคนบางกลุ่มที่เห็นแก่ตัว และเห็นแก่ความสะดวกสบายของตัวเอง ทำให้เกิด\nความวุ่นวายและยุ่งยากแบบนี้...เห็นหลายรอบแล้ว ',
#  '0.0',
#  'ควรจัดยาม รร.มาโบกรถที่ซอยต้นสนหลัง รร.หน่อยค่ะ รถติดแย่งกันไปแย่งกัน\nมาทำให้ไปทำงานไป รร.ไม่ทันค่ะ',
#  '0.0',
#  'ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ การเห็นแก่ตัวของคนส่วนน้อย แต่สร้างปัญหาให้คนส่วนมาก อันนี้ไม่ถูกต้องนะครับ ',
#  '0.0',
#  'ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ การเห็นแก่ตัวของคนส่วนน้อย แต่สร้างปัญหาให้คนส่วนมาก อันนี้ไม่ถูกต้องนะครับ ',
#  '0.0',
#  'ฝากพิจารณารถตู้ รับ-ส่ง นักเรียนด้วยนะครับ พอเริ่มเรียนเต็ม รถตู้แน่นมากๆนะครับ ',
#  '0.0',
#  'รถติดทั้งเช้าทั้งเย็น รร ควรเปลี่ยนวิธีและรีบแก้ไขคะ',
#  '0.0',
#  'การจราจรหน้ารร.ติดขัดไปไกล ควรเกรงใจผู้ใช้ถนนคนอื่นด้วยค่ะ',
#  '0.0',
#  'มีปัญญาแก้ไขปัญหาเพียงแค่นี้แล้วจะไปสอนอะไรเด็กๆ',
#  '0.0',
#  'ทุกวันนี้ก็ติดโครตๆแล้ว ไม่เห็นมีการพัฒนาเลย',
#  '0.0',
#  'เมื่อวานลูกเปียกมาเลยคะนั่งหนาวในรถตู้กว่าจะถึงบ้าน\u200b เค้ามีร่มมีเสื้อกันฝนแต่\nเด็กน้อยยังไงก็มีเปียกคะ\u200b วันหนัยไปรับเองก็วนรถจนท้อคะ\u200b ปรับปรุงหน่อยนะคะ',
#  '0.0',
#  'ไม่เข้าใจแค่ให้ขับรถวนเข้าไปส่งนักเรียนแค่นี้มันจะแย่อะไรนักหนา ดูข้างหน้า \nรร รถติดมาก',
#  '0.0',
#  'ติดหนักมากคะด้านนอก แบบนี้ไม่ไหวนะคะ ติดเช้า/เย็นเห็นใจ ผปค.บ้างคะ',
#  '0.0',
#  'ควรปรับปรุงแก้ไข้อลุ้มอร่วยบ้างกรณีฝนฟ้าตก ฝากไว้ให้คิดด้วยคับ',
#  '0.0',
#  'เจอปัญหารถติด ก็พอทน แต่น้ำท่วมในรร.ขนาดนี้ บอกเลยว่าขอบาย สงสารลูก \nหากต้องเดินลุยน้ำเรียน ไม่ไหวจริงๆ',
#  '0.0',
#  'คิดได้แย่มากให้รถเข้าออกทางเดียว รถทางตรงเขาก็ไปไม่ได้ ติดรถ ผปค. รอเลี้ยวเขาซอยข้างสนามกอล์ฟ แทนที่จะเปิดอีกประตูด้านวัด ให้เข้าออกได้อีกทาง\n',
#  '0.0',
#  'ที่จอดรถที่ทำอยู่ไม่เพียงพอแน่นอน ติดสนั่นทั้งอำเภอปากเกร็ดแน่ๆ พิจารณา\nอีกทีค่ะ !!',
#  '0.0',
#  'พวกเขาอยู่เเต่ห้องเเอร์รอเงินอย่างเดียวละครับพวกนี้ไม่เคยลงมาดูอะไรสักอย่าง',
#  '0.0',
#  'อย่าเอาแต่นั่งห้องแอร์\u200b ผู้ปกครองทุกคนเค้าเบื่อพวกท่านเต็มทนแล้วครับ',
#  '0.0',
#  'รถมันก็ติดเป็นคอขวดเลยครับ บริหารจัดการแย่มาก',
#  '0.0',
#  'ได้รับผลกระทบในช่วงเช้าเป็นอย่างมาก แก้ไขปัญหาบ้างครับ',
#  '0.0',
#  'พยายามปรับเปลี่ยนเวลาในการออกไปทำงานให้เร็วขึ้นเพื่อเลี่ยงการจราจรแล้ว \nแต่ก็ยังได้รับผลกระทบอยู่เหมือนเดิม รร ควรจะแก้ไขการจราจรได้แล้ว',
#  '0.0',
#  'ผปค บางคนวิ่งส่วนย้อนทางออกทำให้รถคันอื่นติดยาวที่จอดข้างใน \nควต้องปรับปรุงรการจราจร และนิสัยผู้ปกครองด้วย',
#  '0.0',
#  'ผู้ปกครองบางคนก็เห็นแก่ตัว ไม่เตรียมตัวพร้องลงลืมของลืมกระเป๋ารองเท้าบ้าง \nจอดรอลูกไปซื้อของห้องสหกรณ์รถติดยาว',
#  '0.0',
#  'รร.ควรพิจารณานะคะ ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น ',
#  '0.0',
#  'ดีจัง ลูกเราย้ายมาเรียนหอวังนนท์แล้ว มาอ่านแล้วเหมือนย้อนกลับไป ที่ต้องทน\nมา 6ปี ที่แล้ว ปัญหาที่แก้ไข ไม่ได้ 🤭🤭',
#  '0.0',
#  'รบกวนเปิดตั้งแต่16.00 เหมือนเดิมค่ะ ส่วนรถผู้ปกครองที่เห็นแก่ตัว ล็อคล้อ \nจ่ายค่าเสียหายไปเลยค่ะ ไม่งั้นรถจะสาหัสมาก',
#  '0.0',
#  'ความเห็นแก่ตัวของคนส่วนน้อยทำให้คนส่วนใหญ่ที่เคารพกติกาต้องมีปัญหาแย่ๆ',
#  '0.0',
#  'เมื่อวานผมติดอยู่ในลานจอดรถ เกือบ 3 ชั่วโมง ควรหาทางแก้ปัญหานะ ',
#  '0.0',
#  'ห้ามนำรถเข้าไปจอดในโรงเรียนผมเห็นด้วยนะคับ แต่ถ้าห้ามเข้าไปเลยปัญหา\nก็เป็นแบบนี้ ควรหาวิธีแก้ด้วยครับ',
#  '0.0',
#  'เพจโรงเรียนเลี่ยงที่จะตอบคำถามทางผู้ปกครอง ผมนั่งดูย้อนหลังไปน้อยมากที่จะ\nมาตอบปัญหาที่มีการสอบถามเรื่องการจราจร ห่วยไปนะครับบบ',
#  '0.0',
#  'ควรเปิดช่องประตูเล็กเพื่อให้ผู้ปกครองเดินไปส่งได้นะ',
#  '0.0',
#  'ครูใส่รองเท้าที่เดินข้างนอกเหยียบพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย \nรบกวนทาง รร พิจารณาเรื่องความสะอาดให้เด็กๆด้วย',
#  '0.0',
#  'เด็กๆ บางคนไม่ชอบ มักกะโรนี ควรมีอะไรแทนบ้างนะคะ',
#  '0.0',
#  'ควรปรับปรุงเรื่องรสชาติบ้างนะค ต้มจืดก็จืดมาก',
#  '0.0',
#  'หมูก็ให้มาแค่ชิ้นน้อยๆ ควรพิจารณาปรับปรุงค่ะ',
#  '0.0',
#  'หวังว่าจะปรับปรุงเรื่องรสชาติและปริมาณที่เหมาะสมนะ',
#  '0.0',
#  'เด็กต้องแบกกระเป๋าหนัก และเดินไกลมากฝากปัญหานี้ให้ผู้บริหารด้วยค่ะ',
#  '0.0',
#  'จยย.ที่ขับเข้ามาแล้วเด็กต้องเดินหลบรถอันตรายมาก',
#  '0.0',
#  'กับข้าวของลูกๆอิสลาม ยังไม่ได้รับการปรับปรุงเลยค่ะ',
#  '0.0',
#  'หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆ',
#  '0.0',
#  'ลานจอดใหม่ ฝุ่น เยอะมาก',
#  '0.0',
#  'ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถทีครับ เยอะมากสงสารสุขภาพลูก',
#  '0.0',
#  'ถนนข้างสนามกอล์ฟฝุ่นฝุ่นเยอะมาก ควรแก้ไขตรงนี้ด่วนๆค่ะ',
#  '0.0',
#  'ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่สงสารเด็กๆมาก',
#  '0.0',
#  'ถ้าโรงเรียนไม่มีศักยภาพในการจัดสรรระบบการจอดรถ การจราจรพอ ควรจะเปิดให้รถผู้ปกครองเข้าไปรับส่งเด็กได้นะคะ',
#  '0.0',
#  'อิดออดในการคืนเงินมาก หรือต้องให้คำนวนให้ แย่มาก',
#  '0.0',
#  'เพจโรงเรียนเลี่ยงที่จะตอบคำถามทางผู้ปกครองผมนั่งดูย้อนหลังไปน้อยมากที่จะมาตอบปัญหาที่มีการสอบถามเรื่องการจราจร การที่ไม่แก้ปัญหา\n ปัญหามันจะไม่จบเมื่อมันสะสมมากๆ มันลุกลามบานปลายนะคับ',
#  '0.0',
#  'รร. ปรับปรุงเรื่องที่จอดรถไม่ใช่ว่าจะทำให้เหตุการณ์รถติดดีขึ้น ที่ไม่โวยวายเพราะต้องทน ถ้ายังเป็นอยู่อย่างนี้คงต้องหา รร.ใหม่ให้ลูกค่ะ ตอนนี้เสียสุขภาพจิตมาก',
#  '0.0',
#  'ช่วยดูด้วยค่ะว่าเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหน',
#  '0.0',
#  'รบกวนออกมาชี้แจ้งด้วยค่ะ',
#  '0.0',
#  'ก๋วยเตี๋ยวหมูน้ำตก หมูน้อยไปนะควรเพิ่มอีกนิดค่ะ !!',
#  '0.0',
#  'แกงคั่วฟักทอง คิดว่าเด็กๆไม่น่าชอบนะคะ ควรเปลี่ยนจากแกงบ้าง',
#  '0.0',
#  'ยำหมูยอลดความเผ็ดลงหน่อยคะ่หนูทานไม่ได้',
#  '0.0',
#  'แอปเปิ้ลช้ำไปหน่อยค่ะ ช่วยปรังปรุงอีกนิดนะคะ',
#  '0.0',
#  'ทอดมันมันมากกก ลูกกินไม่ได้ปรังปรุงด่วนค่ะ',
#  '0.0',
#  'ทั้ังประชาชนทั้ง ผปค ด่าไปผู้บริหารไม่เคยเข้ามาดูไม่เคยแก้ไขปัญหาตรงนี้เลย',
#  '0.0',
#  'แกงขั่วฟักเขียว แค่ชื่อเด็กๆไม่ทานแล้ว เด็กๆคงเบื่อแกงแล้วค่ะ ',
#  '0.0',
#  'ควรเพิ่มปริมาณข้าวสวยอีกนิดค่ะ ลูกทานไม่อิ่ม',
#  '0.0',
#  'ไข่เจียวจืดมาก ปรังปรุงรสชาติหน่อยก็ดีนะครู',
#  '0.0',
#  'ข้าวผัดกุนเชียง แต่กุนเชียงได้น้อยมาก ปรังปรุงด้วยค่ะหลายรอบแล้วนะคะ ',
#  '0.0',
#  'ก๋วยเตี๋ยวเปลี่ยนจากเส้นหมี่เป็นบะหมี่บ้างนะคะ ไม่ได้เรื่องเลย',
#  '0.0',
#  'ก๋วยเตี๋ยวเส้นหมี่อีกแล้ว ลองมากินเองมั้ยคะจะได้รู้ว่ามันน่าเบื่อ',
#  '0.0',
#  'ห้องน้ำสกปรกมาก ตรวจด้วยค่ะ !!!',
#  '0.0',
#  'รบกวนออกมาชี้แจ้งเรื่องคืนค่าเทอมด้วยค่ะ',
#  '0.0',
#  'ห้องน้ำยังคงสกปรกเหมือนเดิม',
#  '0.0',
#  'ตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอด',
#  '0.0',
#  'ต้มจืดลูกบอกจืดสมชื่อมาก พิจาณาด้วยค่ะ',
#  '0.0',
#  'ปรับปรุงเรื่องที่จอดรถด้วยค่ะ ตอนนี้เสียสุขภาพจิตมาก',
#  '0.0',
#  'โรงอาหารมีหนู สกปรกไปนะแก้ไขด่วนค่ะะะะะ',
#  '0.0',
#  'ควรจัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ\u200b ไม่ไหวๆ',
#  '0.0',
#  'ภาพกิจกรรมสอนเสริมวันเสาร์เทควันโด สวยมากเลยค่ะ',
#  '1.0',
#  'ขอบคุณมากๆเลยค่าสำหรับอาหารของเด็กอนุบาลที่ไม่ใส่พริกแกง ',
#  '1.0',
#  'โรงเรียน update ข่าวสารรวดเร็ว ทันใจผู้ปกครองมากค่ะ สุดยอดค่ะ',
#  '1.0',
#  'เด็กๆได้รับทั้งความรู้และสนุกสนาน แถมได้กระชับมิตรกับเพื่อน\nใหม่ในกลุ่ม ดีมากๆค่ะ',
#  '1.0',
#  'ในที่สุด 😆😆😆😆 เพจจะกลับมาเหมือนปกติแล้วเย้ๆ',
#  '1.0',
#  'เด็กดีเราต้องชื่นชมเป็นกำลังใจให้สุดยอดเลยจ้า',
#  '1.0',
#  'ชื่นชมในความมีวินัยมานะบากบั่นในการฝึกซ้อมจนได้รับรางวัล\nขอให้ประสพความสำเร็จยิ่งยิ่งขึ้นไปค่ะ ขอแสดงความยินดีด้วยนะคะ',
#  '1.0',
#  'เด็กๆเก่งมากค่ะ ❤❤',
#  '1.0',
#  'ขอบคุณมากเรยค่ะที่ตอบคำถามคุณแม่ ส่วนใหญ่ ผปค.มีผลกระ\nทบช่วงเช้ามากกว่าช่วงเย็นค่ะคุณครู ตอนเช้าวนเข้า รอรถออก\nนานมากเลยค่ะ',
#  '1.0',
#  'ขอบคุณทาง รร ค่ะ ส่วนหนึ่งก็เห็นใจที่ รร จะต้องใช้เงินบริหารจัด\nการบุคคลากรใน รร เพื่อให้ รร อยู่รอดเพราะเป็น ร.รเอกชน',
#  '1.0',
#  'อาหารใช้ได้ค่ะ ลูกบอกว่าอร่อย บางวันก็ถุกปาก ปากวันก็ไม่ถุก\nปาก สลับๆกันไปค่ะ แต่อย่างว่าแต่ละคนชอบไม่เหมือนกีน รวมๆ\nแล้ว ดีค่ะ',
#  '1.0',
#  'ในสถานการณ์เเบบนี้การบริหารการจัดการไม่ใช่เรื่องง่าย \nเป็นกำลังใจให้นะครับสู้ๆครับ..\n',
#  '1.0',
#  'ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่\nจะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้\nมากเลยครับ',
#  '1.0',
#  'ขอบคุณสำหรับการทำคลิปที่ภาพสวย เสียงชัดนะคะ \nครูและทีมคงต้องเหนื่อยและตั้งใจกันมาก ',
#  '1.0',
#  'CPW Classroom ดูง่ายขึ้น สะดวกมากขึ้น ขอบคุณนะคะ',
#  '1.0',
#  'ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ',
#  '1.0',
#  'ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจ\nขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ',
#  '1.0',
#  'ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจ\nขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ',
#  '1.0',
#  'ขอบคุณทางรร. ที่รับฟัง และนำเอาคำติชมของผปค. ทุกท่านไป\nปรับเปลี่ยนเมนู ให้สอดคล้องกับเด็กประถมเล็กๆ ด้วยนะคะ 🙏🏻',
#  '1.0',
#  'เรียนออนไลน์แล้วนักเรียนได้เกรดดีมากเลยค่ะ',
#  '1.0',
#  'ขอให้แก้ปัญหาได้นะคะ สู้ๆค่ะเป็นกำลังใจให้นะคะ',
#  '1.0',
#  'ขอขอบคุณนักเรียนจิตอาสาของโรงเรียนด้วยนะครับที่เข้ามาทำ\nความสะอาดที่วัด',
#  '1.0',
#  'คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ',
#  '1.0',
#  'ขอบคุณนะคะ จะได้ไปบอกลูกเค้าอยากดูมากเลย 🙂',
#  '1.0',
#  'หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ ชอบอาหารที่ ร.ร',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ช่วงบ่ายดูได้ปกติแล้วครับ..ขอบคุณมากๆครับ..',
#  '1.0',
#  'ขอบคุณผอ.ด้วยนะคะ วันนี้เห็นผอ.ไปช่วยดูแลเด็กๆข้ามถนน',
#  '1.0',
#  'เมื่อเช้าเห็นท่าน ผอ.ออกมายืนรับเด็กๆตรงไฟแดงเอง\nท่านน่ารักมากๆ',
#  '1.0',
#  'ขอแสดงความยินดีแด่คุณครูทุกๆท่านเป็นอย่างยิ่งครับ',
#  '1.0',
#  'เยี่ยมมากๆ...นี่แหละคนรุ่นใหม่และหลายๆคน ในร.ร.\nจะมาสร้างฝันและดูแลชลประทานให้ยิ่งใหญ่ๆต่อไป',
#  '1.0',
#  'เยี่ยมมากๆ...นี่แหละคนรุ่นใหม่และหลายๆคน ในร.ร.\nจะมาสร้างฝันและดูแลชลประทานให้ยิ่งใหญ่ๆต่อไป',
#  '1.0',
#  'ศิษย์เก่งมาจากครูที่เก่งด้วยค่ะ ขอชื่นชมค่ะ\n',
#  '1.0',
#  'ยินดีกับคุณครูอีกครั้งหนึ่งครับเหมาะสมมากๆครับ',
#  '1.0',
#  'ขอบคุณคุณครูและบุคลากรที่ รร.ทุกท่านที่คอยดูแลเอาใจใส่ นร.ค่ะ\n',
#  '1.0',
#  'ชอบมากเลยคะโรงเรียนนี้..เคยเข้าไปติดต่อจะพาลูกเข้าเรียนตอน\nม.4เจ้าหน้าที่พูดจาดีมากๆ ',
#  '1.0',
#  'ชอบมากเลยคะโรงเรียนนี้..เคยเข้าไปติดต่อจะพาลูกเข้าเรียนตอน\nม.4เจ้าหน้าที่พูดจาดีมากๆ ',
#  '1.0',
#  'ขอบคุณมากๆ เลยนะคะ ขอบคุณมากจริง ๆ ค่ะ',
#  '1.0',
#  'ขอขอบคุณโรงเรียนชลประทานวิทยา อาจารย์ทุกท่านที่ให้การ\nสนับสนุนหนูทั้งเวลาเรียน และเวลาซ้อมค่ะ 🙏',
#  '1.0',
#  'ขอบคุณมากเลยค่ะที่ตอบคำถามคุณแม่ สบายใจมากขึ้นเลยค่ะ',
#  '1.0',
#  'ขอบคุณที่ปรับปริมาณอาหารให้กับเด็กนะคะ ขอบคุณมากจริงๆค่ะ',
#  '1.0',
#  'ขอบคุณที่ปรับปริมาณอาหารให้กับเด็กนะคะ ขอบคุณมากจริงๆค่ะ',
#  '1.0',
#  'ลูกบอกว่าอาหารวันนี้อร่อยมากค่ะ ปริมาณอาหารกำลังดีด้วยค่ะ',
#  '1.0',
#  'ลูกบอกว่าอาหารวันนี้อร่อยมากค่ะ ปริมาณอาหารกำลังดีด้วยค่ะ',
#  '1.0',
#  'แกงเขียวหวานอร่อยมากค่ะ ลูกติดใจอยากใก้ทำอีกค่ะ',
#  '1.0',
#  'วันนี้การจรจารในโรงเรียนไหลลื่นมากค่ะ ขอบคุณที่ รปภ และ\nทาง รร นะคะ',
#  '1.0',
#  'ต้มเลือดหมูวันนี้เครื่องแน่มาก ลูกบอกว่ากินจนอิ่มเลยค่ะ \nอร่อยมากๆค่ะ',
#  '1.0',
#  'ขากลับวันนี้รถไม่ค่อยติด ขอบคุณทาง รร นะคะ',
#  '1.0',
#  'อาหารวันนี้อร่อยมากค่ะ ขอบคุณทางฝ่ายโภชนาการและ รร มากๆเ\nลยนะคะ',
#  '1.0',
#  'อาหารวันนี้อร่อยมากค่ะ ขอบคุณทางฝ่ายโภชนาการและ รร มากๆเ\nลยนะคะ',
#  '1.0',
#  'ขอบคุณที่่ลดปริมาณพริกลงนะคะ ขอบคุณมากๆค่าาา',
#  '1.0',
#  'ขอบคุณที่่ลดปริมาณพริกลงนะคะ ขอบคุณมากๆค่าาา',
#  '1.0',
#  'ศิษย์เก่งมาจากครูที่เก่งด้วยค่ะ ขอชื่นชมค่ะ\n',
#  '1.0',
#  'เป๊ะมากครับ สุดยอดเด็กๆ เก่งจังเลย',
#  '1.0',
#  'เป๊ะมากครับ สุดยอดเด็กๆ เก่งจังเลย',
#  '1.0',
#  'อาหารถูกหลักโภชนาการ ขอชื่นชมครับ',
#  '1.0',
#  'ขอบคุณมากค่ะ ฝากด้วยค่ะ',
#  '1.0',
#  'ออกแบบได้ สวยงาม น่าสวมใส่',
#  '1.0',
#  'ออกแบบได้สวยงามมากครับ',
#  '1.0',
#  'ขอบคุณนะคะ 🥰🥰',
#  '1.0',
#  'เว็บ รร.ออกแบบได้สวยเลยครับ',
#  '1.0',
#  'thank',
#  '1.0',
#  'Thank you',
#  '1.0',
#  'good',
#  '1.0',
#  'เมนูวันนี้อร่อยมากค่ะ',
#  '1.0',
#  'คุณครูดูแลดีมากจริงๆค่ะ',
#  '1.0',
#  'คุณครูดูแลดีมากจริงๆค่ะ',
#  '1.0',
#  'well done ',
#  '1.0',
#  'well done ',
#  '1.0',
#  'เว็บ รร.ออกแบบได้สวยเลยครับ',
#  '1.0',
#  'thank',
#  '1.0',
#  'Thank you',
#  '1.0',
#  'good',
#  '1.0',
#  'ขอบคุณนะคะ 🥰🥰',
#  '1.0',
#  'Thank',
#  '1.0',
#  'thank you',
#  '1.0',
#  'Good',
#  '1.0',
#  'Good job',
#  '1.0',
#  'Congratulations',
#  '1.0',
#  'congratulations',
#  '1.0',
#  'Fantastic',
#  '1.0',
#  'Congratulations',
#  '1.0',
#  'congratulations',
#  '1.0',
#  'Fantastic',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ😊💐',
#  '1.0',
#  'Thank',
#  '1.0',
#  'thank you',
#  '1.0',
#  'Good',
#  '1.0',
#  'Good job',
#  '1.0',
#  'Congratulation',
#  '1.0',
#  'congratulation',
#  '1.0',
#  'fantastic',
#  '1.0',
#  'well done ',
#  '1.0',
#  'well done ',
#  '1.0',
#  'Thank',
#  '1.0',
#  'thank you',
#  '1.0',
#  'Good',
#  '1.0',
#  'คิดถึงตอนลูกสาวอยู่ ปฐมวัย ได้รับการดูแลเอาใจใส่ จากครูเจี้ยบ (ครูไพลิน เกษียณแล้ว) ครูจอย และครูวีณา\nลูกสาวคือดื้อมาก กลางวันไม่ยอมนอน ได้ครูวีณา คอยเล่นด้วยมาตลอด\nขอบคุณมากๆ\nตอนนี้อยู่ประถม 3/16 แล้วครับ ยังคิดถึงครูทั้ง 3 ท่านอยู่เสมอ',
#  '1.0',
#  'คิดถึงตอนลูกสาวอยู่ ปฐมวัย ได้รับการดูแลเอาใจใส่ จากครูเจี้ยบ (ครูไพลิน เกษียณแล้ว) ครูจอย และครูวีณา\nลูกสาวคือดื้อมาก กลางวันไม่ยอมนอน ได้ครูวีณา คอยเล่นด้วยมาตลอด\nขอบคุณมากๆ\nตอนนี้อยู่ประถม 3/16 แล้วครับ ยังคิดถึงครูทั้ง 3 ท่านอยู่เสมอ',
#  '1.0',
#  'ภูมิใจเสมอที่ได้เรียกตัวเองว่าเป็นศิษย์โรงเรียนนี้',
#  '1.0',
#  'ในสถานการณ์เเบบนี้การบริหารการจัดการไม่ใช่เรื่องง่าย... เป็นกำลังใจให้นะครับสู้ๆครับ..',
#  '1.0',
#  'ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่จะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้มากเลยครับ',
#  '1.0',
#  'ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่จะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้มากเลยครับ',
#  '1.0',
#  'CPW Classroom ดูง่ายขึ้น สะดวกมากขึ้น ขอบคุณนะคะ',
#  '1.0',
#  'ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ',
#  '1.0',
#  'ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ',
#  '1.0',
#  'ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ        ',
#  '1.0',
#  'เดินทางกลับมาโดยสวัสดิภาพ\nทุกคณะครู นักเรียนทุกท่านค่ะ\nเทพเทวดา เจ้าที่เจ้าทางเปิดทาง\nสะดวกสบายราบรื่นนะค่ะ😇😇',
#  '1.0',
#  'เดินทางกลับมาโดยสวัสดิภาพ\nทุกคณะครู นักเรียนทุกท่านค่ะ\nเทพเทวดา เจ้าที่เจ้าทางเปิดทาง\nสะดวกสบายราบรื่นนะค่ะ 😇😇',
#  '1.0',
#  'ขอขอบคุณนักเรียนจิตอาสาของโรงเรียนด้วยนะครับที่เข้ามาทำความสะอาดที่วัด',
#  '1.0',
#  'ขอบคุณที่รับฟังค่ะ',
#  '1.0',
#  'รายการอาหารดีมาก',
#  '1.0',
#  'หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ...ชอบอาหารที่ร.ร.',
#  '1.0',
#  'หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ...ชอบอาหารที่ร.ร.',
#  '1.0',
#  'คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ',
#  '1.0',
#  'รู้สึกประทับใจมากเลย',
#  '1.0',
#  'รู้สึกประทับใจมากเลย',
#  '1.0',
#  'น่านับถือ',
#  '1.0',
#  'เรียบร้อยแล้ว ไวมาก ขอบคุณทางเจ้าหน้าที่ทุกท่าน ด้วยครับ',
#  '1.0',
#  'ขอบคุณ\u200bค่ะ\u200b สำหรับเมนู\u200bอาหาร\u200bกลางวัน\u200bของเด็กๆค่ะ\u200b ที่ส่งมาให้ผู้ปกครอง\u200bทราบค่ะ',
#  '1.0',
#  'เยี่ยมเลยคะ',
#  '1.0',
#  'ขอชื่นชมทางรร.นะค่ะที่มีการปรับปรุง',
#  '1.0',
#  'รู้สึกดีใจมากที่ส่งลูกมาเรียนรร.นี้',
#  '1.0',
#  'คุณครูดูแลเอาใจใส่เด็กๆได้เป็นอย่างดี',
#  '1.0',
#  'คุณครูดูแลเอาใจใส่เด็กๆได้เป็นอย่างดีมาก',
#  '1.0',
#  'ขอบใจมากจ่ะ',
#  '1.0',
#  'ขอบคุณมากเรยค่ะที่ตอบคำถามคุณแม่',
#  '1.0',
#  'เรียบร้อยแล้ว ไวมาก ขอบคุณทางเจ้าหน้าที่ทุกท่าน ด้วยครับ',
#  '1.0',
#  'ได้แล้วค่ะ ขอบคุณค่ะ',
#  '1.0',
#  'ลูกบอกข้าวผัดเมื่อวานอร่อยมากๆเลยค่ะ',
#  '1.0',
#  'คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ',
#  '1.0',
#  'มีครูคอยดูแลระหว่างการเดินขึ้นลงบันไดหมดความกังวลเรื่องความ\nสะอาดเลยค่ะ ขอบคุณนะคะที่คอยใส่ใจในรายละเอียดเล็กๆน้อยๆ',
#  '1.0',
#  'กับข้าววันนี้ได้เยอะและอร่อยมากค่ะลูกบอกวันนี้ทานหมดเกลี้ยงเลย',
#  '1.0',
#  'อาหารวันนี้ดีมากคะ ขอบคุณนะคะ',
#  '1.0',
#  'ลูกถ่ายรูปผลไม้ของวันนี้มาให้ดูผลไม้สด และหวานกำลังพอดีเลยค่ะ',
#  '1.0',
#  'อาหารกลางวันพรุ่งนี้ถ้าเปลี่ยนเป็นถ้าเปลี่ยนเป็นหมูตุ๋นๆ \nน่าจะชอบทานมากกว่านะคะ',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆ วงโยธวาทิต ด้วยครับ',
#  '1.0',
#  'ขอแสดงความยินดีกับเด็กๆที่ได้รับรางวัลด้วยนะคะ เก่งมากค่ะ',
#  '1.0',
#  'ยอดเยี่ยมค่ะ ราคาเหมาะสม',
#  '1.0',
#  'กระเป๋า รร สวยค่ะ เหมือนในรูปเลย ชอบค่ะ',
#  '1.0',
#  'ราคาโบว์กับคุณภาพมีความเหมาะสมกันแล้ว ขอบคุณนะคะ',
#  '1.0',
#  'รายการอาหารอาทิตย์นี้ดีมากๆเด็กๆน่าจะรับประทานกันอร่อยนะครับ',
#  '1.0',
#  'เก่งมากๆ คับลูกๆ ทั้ง2😍👍',
#  '1.0',
#  'ยินดีด้วยครับ',
#  '1.0',
#  'ดีใจกับน้องดิวด้วยนะครับ ขอให้ประสบความสำเร็จในคณะศึกษาอยู่',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ขอบคุณผอ.ด้วยนะครับ วันนี้เห็นผอ.ไปช่วยดูแลเด็กๆข้ามถนน',
#  '1.0',
#  'ขอบคุณผอ.นะคะ ที่ตอนเช้าช่วยดูลูกๆข้ามถนนครับ',
#  '1.0',
#  'ไป ๆ ดีลชอบ ๆๆ',
#  '1.0',
#  'เก่งมากค่ะ',
#  '1.0',
#  'สวยงาม เก่งมากจ๊ะ สร้างชื่อเสียงให้รร.และประเทศชาติ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะเก่งมากๆ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'เก่งมากค่ะ',
#  '1.0',
#  'ยินดีด้วยครับ ❤',
#  '1.0',
#  'คว้าเหรัยญทองกลับมานะครับ เชียร์ๆ',
#  '1.0',
#  'สุดเลยค่าน้องแตะเตี้ยม ยินดีกับคุณพ่อคุณแม่ด้วยค่า สุดยอดดด',
#  '1.0',
#  'ส่งใจไปเชียร์ค่ะ\n',
#  '1.0',
#  'ยินดีด้วยนะคะ ยอดเยี่ยมมากๆ เลยค่ะ',
#  '1.0',
#  'เก่งมากๆเลย ปลื้มจัง ครูจะขอเป็นกำลังใจให้และชื่นชมกับ\nความสำเร็จในทุกขั้นของพวกหนูนะคะ 🥰❤️',
#  '1.0',
#  'ขอแสดงความยินดีด้วยยอดเยี่ยมมากค่ะ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยครับเก่งมากๆครับ',
#  '1.0',
#  'เก่งทุกคนเลยค่ะ',
#  '1.0',
#  'เก่งมากจร้าาา',
#  '1.0',
#  'ขอแสดงความยินดีกับทุกๆคนด้วยนะครับเก่งมากๆ',
#  '1.0',
#  'ยินดีด้วยนะคะ เก่งมากๆ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยนะคะ ',
#  '1.0',
#  'เก่งมากค่ะยินดีด้วย ขอให้ชนะเลิศกลับมานะคะ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ\n',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยค่ะ',
#  '1.0',
#  'ชอบทุกๆกิจกรรมของชมรมเลย ติดตามและสนับสนุนนะคะ ❤️',
#  '1.0',
#  'ยินดีด้วยนะคะ',
#  '1.0',
#  'เด็กดีเป็นศรีต่อตัวเอง ครอบครัว คนรอบข้างและของชาติจริงๆ \nยินดีด้วยนะคะ',
#  '1.0',
#  'ภาพสวยมากๆเลยค่าาา',
#  '1.0',
#  'สวยมากครับ',
#  '1.0',
#  'เด็กๆเก่งมากค่ะ ยินดีกับน้องด้วยนะคะ\n',
#  '1.0',
#  'ภาพสวยมากครับ❤️\n',
#  '1.0',
#  'เก่งมากๆครับ ยินดีด้วยครับ',
#  '1.0',
#  'สวยมากค่ะ ขอแสดงความยินดีด้วย',
#  '1.0',
#  'ขอร่วมแสดงความยินดีและภาคภูมิใจกับความสำเร็จของน้องด้วย\nนะครับ',
#  '1.0',
#  'เป็นกำลังใจให้ครับ ^^',
#  '1.0',
#  'ขอให้โชคดี เก็บเกี่ยวประสบการณ์ดีๆ เกินทางปลอดภัยนะคะ',
#  '1.0',
#  'ขอขอบคุณ โรงเรียนชลประทานวิทยา คณาจารย์ เจ้าหน้าที่ \nศิษย์รุ่นพี่ เพื่อนและทุกหน่วยงาน ที่เมตตาอบรม สั่งสอน ส่งเสริม \nสนับสนุน ให้น้องได้ค่อยๆก้าวเดินมาถึงจุดนี้และยังเป็นต้นทุนที่ดี\nงามในการเดินทางเพื่อความฝันต่อๆไปด้วยค่ะ',
#  '1.0',
#  'ขอบแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยนะคะ',
#  '1.0',
#  'ชื่นชมยินดีเด็กเก่งค่ะ',
#  '1.0',
#  'เด็กๆสุดยอดจริงๆชื่นชมและดีใจด้วยค่ะ',
#  '1.0',
#  'ขอบคุณค่ะ ดีต่อใจ🥰',
#  '1.0',
#  'งดงาม ดูกี่ปีกี่ปีก็งดงาม',
#  '1.0',
#  'เป็นอีกหนึ่งความภูมิใจ สุดยอดมาก',
#  '1.0',
#  'ขอแสดงความยินดีกับเด็กๆด้วยนะคะ',
#  '1.0',
#  'ยินดีด้วยค่ะ เด็กๆเก่งมากๆค่ะ\n',
#  '1.0',
#  'ยินดีด้วยนะคะคุณครูทุกท่าน',
#  '1.0',
#  'ยินดีด้วยค่ะ เก่งมากๆค่ะ',
#  '1.0',
#  'Congratulations กับเด็กๆ ทุกคนด้วยค้าบ',
#  '1.0',
#  'ยินดีกับน้องๆทุกๆคนด้วยจ้า',
#  '1.0',
#  'เด็กๆชลประทานเก่งมากค่ะ',
#  '1.0',
#  'ยินดีด้วยกับลูกชลประทานทุกคน\nขอให้ประสบความสำเร็จ * ชาติ ศาสนา พระมหากษัตริย์ *💗',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆทุกคนนะครับ',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆทุกท่านนะครับ',
#  '1.0',
#  'ยินดีกับทุกท่านด้วยค่ะ',
#  '1.0',
#  'สวยมากเลยต้องมงแล้วค่ะ😅🤗',
#  '1.0',
#  'เก่งมากลูกเก่งด้วยหล่อด้วย',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยค่ะ ส่งกำลังใจ นร ชลประทานค่า',
#  '1.0',
#  'ยินดีกับเด็กๆและผู้ปกครองนะคะนึกถึงวันที่ประกาศผลของลูกสาว\nเลยค่ะ',
#  '1.0',
#  'ขอบคุณค่ะ ฝากลูกชายในรั้ว CPW ด้วยค่ะ',
#  '1.0',
#  'ลูกสาวสมหวังแล้วค่ะ  ดีใจสุดๆ',
#  '1.0',
#  'เข้าใจความรู้สึกค่ะ ยินดีด้วยนะค่ะ 👏👏💐💐',
#  '1.0',
#  'ขอแสดงความยินดีกับน้อง ๆ และครอบครัวด้วยคะ \nทุกคนยอดเยี่ยมมาก ๆ คะ',
#  '1.0',
#  'ยินดีกับเด็กๆ ด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยนะค่ะทุกคน',
#  '1.0',
#  'ยินดีกับเด็กๆทุกคนและครอบครัว คุณพ่อคุณแม่ หายเหนื่อยเลย',
#  '1.0',
#  'ยินดีกับน้องๆทุกคนนะครับ',
#  '1.0',
#  'ทุกคนยอดเยี่ยมมาก ๆ คะขอบคุณมากค่ะ ยินดีกับทุกท่านด้วยค่ะ \nยังตื่นเต้นอยู่เลยค่ะ แม่ดีใจอาการออกกว่าลูกอีก',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆและครอบครัวด้วยครับ',
#  '1.0',
#  'ขอแสดงความยินดีกับเด็กๆที่สอบผ่านทุกคนนะคะ และเป็นกำลังใจ\nต่อให้กับเด็กๆที่ยังไม่สมหวังกับสนามนี้ แต่สนามต่อไปต้องเป็นของ\nเราแน่นอนเลยค่ะ ✌️♥️',
#  '1.0',
#  'ยินดีกับน้องๆทุกบ้านที่สอบติดค่ะ',
#  '1.0',
#  'ขอแสดงความยินดีกับทุกๆคนค่ะ💕💕💕',
#  '1.0',
#  ...]

# %%
from pythainlp.util import normalize
from pythainlp import word_tokenize
import string
import re
import csv
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from stop_words import get_stop_words
from pythainlp.util import normalize
import pandas as pd
th_stop_origin = tuple(thai_stopwords())
# append tuple thai stop word
th_stop = (th_stop_origin + ("สวัสดี", "ค่ะ", "เลย", "เรย","ๆ", "สุด", "นะคะ", "นะค่ะ", "ค่า", "อีกแล้ว","‼","⁉"))
en_stop = tuple(get_stop_words('en'))
def split_word(text):
    tokens = word_tokenize(text, engine='deepcut')  # แบ่งคำภาษาไทย

    # Remove stop words ภาษาไทย และภาษาอังกฤษ
    tokens = [i for i in tokens if not i in th_stop and not i in en_stop]

    # ลบช่องว่าง
    tokens = [i for i in tokens if not ' ' in i]

    return tokens

def clean_msg(msg):
    # ลบ text ที่อยู่ในวงเล็บ <> ทั้งหมด
    msg = re.sub(r'<.*?>', '', msg)
    # ลบ hashtag
    msg = re.sub(r'#', '', msg)
    # ลบ เครื่องหมายคำพูด (punctuation)
    for c in string.punctuation:
        msg = re.sub(r'\{}'.format(c), '', msg)
    # ทำให้ทุกคำต่อกัน
    msg = ' '.join(msg.split())
    # ลบ link https
    msg = re.sub(r'http\S+', '', msg)

    return msg
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def cleanning(text):
    return clean_msg(normalize(remove_emoji(text)))
def add_data_to_csv_with_deepcut(text,label):
    data=[]
    flag=0

    clean_text = cleanning(text)
    list_of_word = split_word(clean_text)
        
    temp_data=[list_of_word,str(label)]
    data.append(temp_data)
    with open('data.csv', 'a',encoding="UTF8") as file:
        header = ['txt','label']
        writer = csv.writer(file)
        # if(flag == 0):
        #     flag=1
        #     writer.writerow(header)
        writer.writerows(data)

# %%
for i in range (0,size,2):
# for i in range (1):
    print(f"{data1[i]} , {data1[i+1]}")
    add_data_to_csv_with_deepcut(data1[i],data1[i+1])
# Out:
# จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรียน ทำรถติด แทนที่จะจัดรถเข้า
# ทางออกทาง ให้เข้าออกปะปนกันไปหมด , 0.0
# 4/4 [==============================] - 0s 4ms/step
# คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหายๆค่ะ มีกระตุกๆด้วย , 0.0
# 2/2 [==============================] - 0s 6ms/step
# เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ , 0.0
# 2/2 [==============================] - 0s 3ms/step
# กฎระเบียบไม่ดี เเถมยังตีเด็กอีก , 0.0
# 1/1 [==============================] - 0s 19ms/step
# ตรงประตูระวังเชือกผูกรองเท้าด้วยนะคะ อันตราย , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ผึ้งจะเปิดเรียนจะไห้จ่ายค่าเทอมเลย ควรนึกถึงพ่อกับแม่บ้างนะให้ตายเถอะ , 0.0
# 3/3 [==============================] - 0s 4ms/step
# ถามไปก็ไม่เคยมาอ่านหรือตอบ แย่มาก , 0.0
# 2/2 [==============================] - 0s 3ms/step
# ควรคืนค่าเทอมห้อง EP เพราะว่าไม่ได้เรียนที่โรงเรียน เรียนที่บ้านทั้งเทอมเลย , 0.0
# 3/3 [==============================] - 0s 4ms/step
# เป็นการช่วยเหลือที่เล็กน้อยมาก ห่วยที่สุด , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ในห้องน้ำควรมีทิชชู่ ยิ่งเด็ก ผญ สำคัญเรื่องความสะอาด และเด็กบางคน
# เห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0.0
# 4/4 [==============================] - 0s 5ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่
# เหมือนกัน พิจารณาแก้ไขด้วย , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่
# เหมือนกัน พิจารณาแก้ไขด้วย , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เปิดเรียนปกติครบทุกระดับชั้นแต่ถ้าทางโรงเรียนไม่ให้ผู้ปกครองนำรถ
# เข้าโรงเรียนไปส่งเด็กๆมันคงจะแย่สำหรับผู้ปกครองหลายๆคนนะค่ะ
# รบกวน รร. ลองลงมาดูลานจอดรถใหม่ตอนเช้าตอนเย็นบ้างนะค่ะว่ารถ
# มันติดแค่ไหน , 0.0
# 7/7 [==============================] - 0s 5ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​เพราะถ้าเปิด
# เต็มรูปแบบรถคงติดมาก , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​เพราะถ้าเปิด
# เต็มรูปแบบรถคงติดมาก , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน
# แน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ
# 20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี
# รถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น
# มากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้
# รับความกรุณาพิจารณาด้วย , 0.0
# 12/12 [==============================] - 0s 5ms/step
# เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน
# แน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ
# 20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี
# รถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น
# มากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้
# รับความกรุณาพิจารณาด้วย , 0.0
# 12/12 [==============================] - 0s 5ms/step
# ไม่เข้าใจรรคืนเงินทีไรคนบ่นกันจัง ลูกชายคนโตเรียนโครงการพิเศษของ
# รร รัฐบาล ค่าเทอมก็เกือบสองหมื่นคืนเงินมาแค่ 1380 ไม่เห็นมี ผปค
# โพสบ่นในเพจรร แต่นี่ รร เอกชนขนาดภาคปกติยังคืนเยอะกว่ารรรัฐบาล
# อีก คนบ่นกันจัง😞 , 0.0
# 7/7 [==============================] - 0s 5ms/step
# อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจน และเพียงพอด้วยครับ​
# ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ ลูกก็รอไปจนกลับ
# คนสุดท้ายของห้อง​ เกรงใจคุณครูที่รอเราคนเดียว​ , 0.0
# 6/6 [==============================] - 0s 5ms/step
# จัดเวลาการเรียนการสอนน้อยเร่งรัดทุกเรื่องผลการเรียนจะเป็นอย่างไรไม่รู้
# เอาแต่จะตัดระบบให้เป็นปัจุบันในการทำงานของหน่อยงานตนเอง , 0.0
# 4/4 [==============================] - 0s 5ms/step
# กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth
# ด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์
# เอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก , 0.0
# 7/7 [==============================] - 0s 5ms/step
# กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth
# ด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์
# เอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก , 0.0
# 7/7 [==============================] - 0s 5ms/step
# ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม
# คลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ
# วานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก
# ษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา
# บ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ , 0.0
# 10/10 [==============================] - 0s 5ms/step
# ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม
# คลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ
# วานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก
# ษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา
# บ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ , 0.0
# 10/10 [==============================] - 0s 5ms/step
# โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย
# วิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ
# ยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ , 0.0
# 6/6 [==============================] - 0s 5ms/step
# โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย
# วิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ
# ยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ , 0.0
# 6/6 [==============================] - 0s 5ms/step
# สรุปเลยนะคะ การเรียนออนไลน์ระดับประถม ไม่มีการปรับปรุงให้ดีขึ้น เช่น
# เสียงจากคลิป ฟังไม่รู้เรื่อง อุปกรณ์ รร ให้คุณครูลงทุนกันเองหรอคะ เสียง
# พูดได้ยินดับๆหายๆ รร ควรลงทุนอุปกรณ์ให้คุณครูนะคะ เช่น ไมค์ในการ
# อัดคลิป เรื่องภาพก็อีกเรื่องนึง แต่เรื่องเสียงนี่สำคัญที่สุด เพราะ นร. ต้อง
# ฟังที่คุณครูอธิบาย กลายเป็นว่า ทำงานซ้ำซ้อน ขอให้ รร ลงทุนอุปกรณ์
# ให้ครูด้วยนะคะ , 0.0
# 12/12 [==============================] - 0s 6ms/step
# คลิปค้างและกระตุกมากค่ะเป็นเกือบทุกวิชาค่ะ ตั้งแต่เช้าจนถึงตอนนี้ค่ะ
# ดูไม่รู้เรื่องเลยค่ะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# vdo กระตุกมากโหลดช้ามากดูแล้วสะดุดมาก ไม่รู้เรื่องเลยในการดูแต่ละวิชา , 0.0
# 3/3 [==============================] - 0s 4ms/step
# เว็ปโรงเรียนโหลดนานมาก พอเปิดได้คลิปกระตุกดูไม่รู้เรื่องเลยค่ะ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง
# เรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก
# นั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม
# ที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ , 0.0
# 9/9 [==============================] - 0s 5ms/step
# ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง
# เรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก
# นั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม
# ที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ , 0.0
# 9/9 [==============================] - 0s 5ms/step
# ทาง รร ควรซื้อแอพ Zoom premium ให้ครูด้วยค่ะ เวลาแค่ 40 นาทีจากแอพ
# zoom ฟรี มันไม่พอ ในกรณีสอนสดกว่าจะรอให้นักเรียนมาครบกินเวลาไปกว่า 10
# นาทีเลย เผื่อเวลาเน็ตหลุดด้วย เสียเวลามากเรียนก็ไม่ต่อเนื่อง ไม่เต็มที่ ยิ่งเด็ก
# ม.ปลายนี่ไม่ต้องพูดถึงเลย เด็กๆบ่นกันเยอะมากค่ะ , 0.0
# 9/9 [==============================] - 0s 5ms/step
# ขอโทษนะคะกดเข้าไปในวีดีโอเปิดไม่ได้ค่ะเปิดติดบ้างไม่ติดบ้างค่ะ ช่วยแก้ไข
# หน่อยค่ะ เป็นแบบนี้บ่อยๆไม่ไหวนะคะ , 0.0
# 4/4 [==============================] - 0s 5ms/step
# ช่วยแก้ไขหน่อยนะคะ เปิดไม่ได้เลยคะ ลองใช้ทั้ง WiFi และ 5G ก็เปิดไม่ได้คะ
# เปิดติดบ้างไม่ติดบ้าง เซ็งคะ , 0.0
# 4/4 [==============================] - 0s 5ms/step
# จัดซัมเมอรไปเลยคะ ดิฉันไม่ให้ลูกไปเรียนแน่นอน ถือว่าทำบุญให้ รร. คะอันตราย
# ขนาดนี้ ยังคิดจะจัดสอนซัมเมอร์อีก โควิดวันนี้ คนติดเพิ่มอีกเป็นพันคน เด็กๆติดมา
# ถึงหายก็ปอดหายไปครึ่งนึง อนาคตสุขภาพเด็กคงแย่ , 0.0
# 7/7 [==============================] - 0s 5ms/step
# ช่วยดูด้วยค่ะวาาเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหนพลาดโอกาสหลายอย่างยัง
# ต้องพลาดที่เรียนอีก , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ทางโรงเรียน​ จะต้องเร่งแก้ไขให้นะคะ​ ไม่ใช่ให้เด็กนักเรียน​หรือ​ ผู้ปกครอง​ จะต้อง
# เป็นคนประสานเองนะคะ​ เพราะได้แจ้งรายละเอียด​ และ​ ปัญหา​ ไว้ให้พิจารณา
# หมดแล้ว​ ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ*** , 0.0
# 7/7 [==============================] - 0s 5ms/step
# ห้องน้ำนักเรียนอาคาร 8 อับชื้นและสกปรกมาก รบกวนตรวจด้วยนะคะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้แล้วนะคะ... , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกมากค่หยุดๆะ เล่นๆ ตลอดเลยค่ะ  เสียอารมณ์ค่ะ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน ห่วยมาก , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกบ่อย​ file ค้างมากๆๆเลยค่ะ​ 😅😅 เด็ก​เดินหนีไปแล้วค่ะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกทุกคลิปเลย เรียนไม่ได้เลยค่ะ แย่ที่สุด , 0.0
# 2/2 [==============================] - 0s 5ms/step
# เข้าดูไม่ได้เลยครับ ทั้งกระตุกทั้งค้างครับ 😞 , 0.0
# 2/2 [==============================] - 0s 5ms/step
# กระตุกๆ ค้างๆ กว่าจะผ่านไปแต่ละวิชาใช้เวลานานมาก แย่มาก , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกสะดุดตลอด ทุกวิชา ไม่สามารถเรียนได้เลยแบบนี้เด็กก็แย่สิคับ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ป.2 ป.4 เปิดเข้าดู VDO ไม่ได้เลยค่ะ ไม่ไหวนะคะแบบนี้ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ยังกระตุกอยู่เลยค่ะเรียนไม่ได้เลยค่ะ เสียเวลามากค่ะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกทุกlink. ห่วยคะ , 0.0
# 1/1 [==============================] - 0s 21ms/step
# ควบคุมการผลิตให้ดี เพิ่มโปรตีนด้วยนะครับ ไม่ใช่มีแต่ผักกับผลไม้ ห่วยมากก , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เมนูก๋วยเตี๋ยวน้องผมบ่นว่ากินแต่หมี่ๆอย่างเดียว 😅 , 0.0
# 2/2 [==============================] - 0s 5ms/step
# วันนี้ก็มีน้ำซุปฟักลูกบอกว่าจืดอย่างกะน้ำเปล่าเลยค่ะ ปรับปรุงด้วยค่ะ 😂😂😂 , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ติดป้ายลดความเร็วเพิ่มเติมน่าจะดีนะคะ ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่เพียบ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เส้นใหญ่ กะทิ เป็นสิ่งที่เสียง่าย ควรหลีกเลี่ยง มาทำอาหารให้เด็กๆ วันนี้เด็ก
# ปวดท้อง ท้องเสีย หลายคนคะ , 0.0
# 4/4 [==============================] - 0s 5ms/step
# เด็กๆ บอกข้าวแข็งค่ะ เมื่อวาน , 0.0
# 1/1 [==============================] - 0s 23ms/step
# เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# หวังว่าเปิดเทอมนี้จะได้ฟังจากลูกเรื่องรสชาติและปริมาณที่เหมาะสมนะคะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เพิ่มปริมาณอาหารให้พอกับความต้องการด่วนเลยค่ะ ห่วยตั้งแต่เปิดเทอม!! , 0.0
# 3/3 [==============================] - 0s 4ms/step
# ผมสงสารเด็ก รร. นี้มากคือ หนึ่งเลยนะ โรงอาหาร คือเเบบว่ามันเเน่นมากๆเลยครับ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการ
# อาหารค่ะ , 0.0
# 3/3 [==============================] - 0s 4ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ฝนตกส่งลูกลำบากมาก ควรแก้ไขนะคะ , 0.0
# 1/1 [==============================] - 0s 19ms/step
# ควรพิจารณาที่จอดรถได้แล้วนะครับ , 0.0
# 1/1 [==============================] - 0s 20ms/step
# ลานจอดใหม่ ฝุ่น เยอะมาก , 0.0
# 1/1 [==============================] - 0s 23ms/step
# เมนูกระเพราหมูวันอังคารที่ผ่านมาช่วยลดความเผ็ดลงด้วยคะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ... , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่น และดินออกบ้างน่าจะดีนะคะ  , 0.0
# 3/3 [==============================] - 0s 7ms/step
# ไม่ต้องใส่พริกน่าจะดีกว่านะคะ เด็กประถมไม่ได้ทานเผ็ดได้ทุกคนค่ะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ทำอาหารที่เด็กทานได้ง่ายกว่านี้ค่ะ เมนูแกงสำหรับเด็กประถมยังไม่เห็นด้วยค่ะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เช็คสหกรณ์ด้วยนะคะ หน้ากากอนามัยแพงมากค่ะ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# รับทราบปัญหาบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆค่ะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# พิจารณาเรื่องความสะอาดให้เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0.0
# 3/3 [==============================] - 0s 5ms/step
# กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะแล้วก็ควรจะทำให้อาหารมีรสชาติ
# มากกว่านี้ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด
# ควรทำตามตารางนะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ฝากให้พิจารณา​อาหารที่มีประโยชน์​ให้
# เด็กด้วยค่ะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ไม่ให้รถเข้าออก แบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เมนูอาหารวันเสาร์ เป็นเมนูไก่ทอด เป็นอย่างอื่นบ้างก้อดีน่ะค่ะ เด็กๆ บ่นว่า
# ไก่ทอดทุกเสาร์เลย , 0.0
# 3/3 [==============================] - 0s 6ms/step
# น่าจะมีมีพื้นที่พักคอยให้กับญาติ ๆ หน่อยนะค่ะ เพราะว่ารอกว่าจะสอบเสร็จก็ไม่รู้
# ว่าจะเอาตัวไปอยู่ที่ไหน , 0.0
# 4/4 [==============================] - 0s 5ms/step
# กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ
# พื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด
# ท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้
# เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0.0
# 9/9 [==============================] - 0s 5ms/step
# กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ
# พื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด
# ท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้
# เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0.0
# 9/9 [==============================] - 0s 5ms/step
# ขอร้องเรียนเรื่องครูประถมหน่อยค่ะ ครู ***** ***** ตีนักเรียนเพียงเพราะนักเรียน
# ไม่ยอมใส่ถุงเท้าเข้าห้องเรียน ที่จริงแล้วน้องรองเท้าเปียกมาเพราะเข้าห้องน้ำมา
# อยากให้ครูท่านนีได้รับคำตักเตือนหน่อยค่ะ , 0.0
# 6/6 [==============================] - 0s 5ms/step
# รายการอาหารวันเรียนพิเศษวันเสาร์ ไม่น่ามีคะเมนูผัดมาม่า ไม่โอเคคะ จากเส้น
# มาม่าเป็นเส้นก๋วยเตี๋ยวน่าจะดีกว่านะคะ. , 0.0
# 4/4 [==============================] - 0s 5ms/step
# ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะคะ
# ลดฝุ่นละออง , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถ เด็ก ๆ เปิดหน้าต่างห้องเรียนรับลม แต่เวลารถขับ
# ผ่านฝุ่นปูนปลิวอย่างเห็นได้ชัด , 0.0
# 4/4 [==============================] - 0s 5ms/step
# ช่วยมาวัดค่าอาคาร สอง อาคารสี่ อยู่ติดกับลานจอดใหม่ ฝุ่น เยอะมาก ผบรห
# ลองมานั่งเรียนกับเด็กๆหน่อย , 0.0
# 4/4 [==============================] - 0s 4ms/step
# หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆเดินก็ไกลต้องมากลัวฝุ่นอีก
# ปอดไม่พังตอนนี้ก็ไม่รู้จะว่าอย่างไง วอนท่านผู้บริหารลงมาเดินดินแก้ปัญหาให้
# เด็กๆด้วยเถอะ หรือพวกท่านและคณะไม่เดือดร้อนเพราะท่านใช้อภิสิทธ์ชนจอด
# ใน รร ได้หรือครับ , 0.0
# 8/8 [==============================] - 0s 5ms/step
# กับข้าวเด็กเผ็ดนะคะ (ของอิสลามค่ะ) ลูกๆ ทานตั้งแต่อนุบาล ตอนนี้ประถมแล้ว
# ยังไม่ปรับปรุงเลยค่ะ , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ฝากพิจารณารถตู้รับส่งนักเรียนด้วย นั่งกันแน่นมากๆเลย รู้สึกกังวลครับ , 0.0
# 3/3 [==============================] - 0s 4ms/step
# หนังสือเรียน 10 วิชาหนักมากค่ะลูกแบดไม่ไหวค่ะ บ่นปวดหลัง เดินก็ไกล
# ขึ้นสะพานลอยก็จะหงายหลังตกสะพาน สงสารเด็ก , 0.0
# 4/4 [==============================] - 0s 5ms/step
# ผลไม้ที่ให้เด็กทานพวกเงาะเด็กไม่ทานกันเลยค่ะ อีกอย่างปลอกกันไม่เป็นใช้ปาก
# กัด อันตรายนะคะ ยาฆ่าแมลงทั้งนั้น , 0.0
# 4/4 [==============================] - 0s 5ms/step
# ช่วยพิจารณาเรื่องการส่งงานส่งเป็นรายอาทิตย์หรืออย่างไรก็ได้ที่ทางคุณครูสะดวก
# ไม่ใช่แค่มีคลิปแล้วเรียนบอกว่าเรียนจบแล้ว , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนม
# ที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ และสังเกต​ว่าเทอมนี้ผลไม้ไม่มีขาย
# แล้ว ฝากให้พิจารณา​อาหารที่มีประโยชน์​ให้เด็กด้วยค่ะ , 0.0
# 7/7 [==============================] - 0s 5ms/step
# ขออนุญาตนะคะ อาหารเด็กกลางวัน ป.1ถึง ป.6อาหารเหมือนกันหมด ควรแบ่งตาม
# ความเหมาะสมเด็กเล็ก และเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ ลูกชาย
# คนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่า
# ไม่อร่อยและกินไม่ได้เลยค่ะถึงจะเป็นเด็กแต่ก็มีหัวใจนะคะ ขอให้กินได้ก็พอค่ะ
# อาหารจะมีคุณภาพเราต้องใส่ใจในทุกรายละเอียดและทุกๆอย่างค่ะ ขอบคุณค่ะ , 0.0
# 11/11 [==============================] - 0s 5ms/step
# แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่าเพราะบางทีได้ไก่จ่อ 2 ชิ้น ไส้
# กรอก 2 ชิ้น ไข่ต้มกินไม่เป็นกินไข่ขาวนิดหน่อย สงสารลูกให้ห่อข้าวก็ไม่ยอม
# กลัวไม่เหมือนเพื่อน เราเสียเงินเพิ่มก็ได้นะ ขอให้ดีกว่านี้ ระวังผู้ปกครองทนไม่
# ไหวแอบถ่ายออกสื่อจะดังเหมือน รร.อื่นๆนะคะ อายญาติพี่น้องว่าเราส่งลูกมา
# เรียน ที่นี่ได้งัย , 0.0
# 10/10 [==============================] - 0s 5ms/step
# ทางโรงเรียน​ จะต้องเร่งแก้ไขให้นะคะ​ ไม่ใช่ให้เด็กนักเรียน​หรือ​ ผู้ปกครอง​ จะต้อง
# เป็นคนประสานเองนะคะ​ เพราะได้แจ้งรายละเอียด​ และ​ ปัญหา​ ไว้ให้พิจารณา
# หมดแล้ว​ ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ*** , 0.0
# 7/7 [==============================] - 0s 5ms/step
# อยากจะให้ทาง รร. เพิ่มเมนูหรือเพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่า
# ได้ทานหมูก้อน 1ก้อนกับซุป น้อยไปนะคะ กับมาตรฐาน กับรร.ระดับนี้ ไม่ไหวๆ , 0.0
# 5/5 [==============================] - 0s 5ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0.0
# 2/2 [==============================] - 0s 5ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0.0
# 2/2 [==============================] - 0s 5ms/step
# เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวันไม่ดี , 0.0
# 3/3 [==============================] - 0s 4ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่เหมือนกัน พิจารณาแก้ไขด้วย , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ. ลองให้รถครูจอดข้างนอกแล้วเดินลุยฝนมาบ้าง , 0.0
# 3/3 [==============================] - 0s 6ms/step
# เมนูแกงสำหรับเด็กประถมยังไม่ควร ยังทานยากไป , 0.0
# 2/2 [==============================] - 0s 5ms/step
# เรียนปกติแล้วทำไมให้รถเข้าออกได้ปกติทุกคนมีความป้องกันตัวเองอยู่แล้วแบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน , 0.0
# 5/5 [==============================] - 0s 5ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​ เพราะถ้าเปิดเต็มรูปแบบรถคงติดมาก , 0.0
# 3/3 [==============================] - 0s 6ms/step
# นี่คือความคิดของคนภายนอกและนี่ก็คือผลงานของทางโรงเรียนทำให้คนข้างนอกเข้าใจ ผปค. ผิดจะทำยังไงก็รีบๆ ทำเถอะค่ะ ซึ่งมันไม่ใช่ความผิดของ
#  ผปค. เลยนะคะ , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่นมากสังเกตุมาหลายอาทิต
# แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้รับความกรุณาพิจารณาด้วย , 0.0
# 4/4 [==============================] - 0s 6ms/step
# เปิดประตู3 ไม่ได้ช่วยอะไรเลย โรงเรียนจะต้องเปิด ประตู 4และ ประตู 5 เพื่อช่วยระบายรถ ที่ลานจอดรถ ในช่วงเช้า 6.00 - 8.30 น. พิจารณาแก้ไขด้วย , 0.0
# 5/5 [==============================] - 0s 5ms/step
# อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ​ ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ
#  ลูกก็รอไปจนกลับคนสุดท้ายของห้อง​ เกรงใจคุณครูที่รอเราคนเดียว​ , 0.0
# 6/6 [==============================] - 0s 6ms/step
# แต่ของลูกเป็นการตักรอบแรกนะคะ ถ้ามันไม่พอแสดงว่าไม่มีใครได้รอบสองแน่นอน
# ช่วยพิจารณาหน่อยนะคะว่าเป็นการตักรอบแรกค่ะ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ประกาศผลสอบช้ามากจังค่ะ แต่ตังก็จะให้จ่ายก่อน งง ใจค่ะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด แย่มาก , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ได้ใบเกรดและใบจบช้าคะรร.อื่นเขาแจกกันตั้งแต่เดือนที่แล้ว แล้วนี่ยังคิดGPAของแต่ละกลุ่มสาระไม่เสร็จทำไมถึงทำงานช้ากันแบบนี้คะถ้านร.
# กรอกแก้ไขข้อมูลไม่ทันทำให้มีผลไม่ติดมหาลัยล่ะคะจะรับผิดชอบยังไง ทำไมถึงประกาศในcpw classroomก่อนไม่ได้คะ ห่วยสิ้นดี , 0.0
# 8/8 [==============================] - 0s 6ms/step
# แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่า , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ขออนุญาตนะคะอาหารเด็กกลางวันป.1ถึงป.6อาหารเหมือนกันหมด ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ , 0.0
# 4/4 [==============================] - 0s 7ms/step
# ได้รับข้อมูลแล้ว กรุณานำไปพิจารณาด้วยนะครับไม่ใช่ขอบคุณอย่างเดียวครับ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนมที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ , 0.0
# 7/7 [==============================] - 0s 6ms/step
# เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ , 0.0
# 7/7 [==============================] - 0s 5ms/step
# อีกเรื่องห้องน้ำสกปรกมากๆๆครับ ร่วมถึงน้ำดื่มอีกก็ไม่เคยตรวจสอบเลยครับ จนเดียวนี้เด็กๆถึงไม่อยากเข้าห้องน้ำกับดื่มน้ำที่โรงเรียนแล้วครับ , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ทางโรงเรียนเลือกตอบแค่บางคำถามหรอครับ เห็นคำถามไหนเกี่ยวกับโปรแกรม ซูม ทางโรงเรียนไม่เข้ามาตอบเลย แย่มากครับ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ไม่คิดจะคืนค่าอาหารเลยหรอค่ะ , 0.0
# 1/1 [==============================] - 0s 21ms/step
# ทางผู้ปกครองไม่สะดวกใจให้นักเรียนไปค่ายพุทธบุตรเเล้วค่ะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# โรงเรียนคะ อยากให้แก้ชื่อให้หน่อยค่ะ โพสต์ล่าสุดอ่ะค่ะพิจารณาแก้ไขด้วย , 0.0
# 3/3 [==============================] - 0s 7ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ... , 0.0
# 2/2 [==============================] - 0s 7ms/step
# รบกวนออกมาชี้แจ้งด้วยค่ะ , 0.0
# 1/1 [==============================] - 0s 24ms/step
# ตรงลานจอดที่ยังเป็นดิน เด็กเดินอยู่ ขับเบาๆหน่อยนะครับ ฝุ่นมันเยอะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# เพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่าได้ทานหมูก้อน 1ก้อนกับซุป
# น้อยไปนะคะ ไม่ไหวๆ , 0.0
# 3/3 [==============================] - 0s 7ms/step
# กระตุกมากค่ะ เล่นๆหยุดๆ ตลอดเลยค่ะ , 0.0
# 2/2 [==============================] - 0s 4ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0.0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกทุกlink. ห่วยคะ , 0.0
# 1/1 [==============================] - 0s 24ms/step
# แย่มากกกกกกค่ะ , 0.0
# 1/1 [==============================] - 0s 24ms/step
# รสชาติอาหารแย่มาก ไม่ไหวจะเคลียร์ , 0.0
# 2/2 [==============================] - 0s 3ms/step
# ใช้เดือนเดียวพังแย่ๆมากๆ , 0.0
# 1/1 [==============================] - 0s 25ms/step
# ปรับปรุงด่วน!!!!  , 0.0
# 1/1 [==============================] - 0s 40ms/step
# เสียเวลามากๆ กว่าจะทำเรื่องคืนเงินได้  , 0.0
# 2/2 [==============================] - 0s 4ms/step
# เสียความรู้สึกค่ะ , 0.0
# 1/1 [==============================] - 0s 21ms/step
# ไม่ไหวๆเลย , 0.0
# 1/1 [==============================] - 0s 22ms/step
# ถ้าเพิ่มร้านอิสลามก็ดีนะครับ , 0.0
# 1/1 [==============================] - 0s 22ms/step
# วันนี้ล่มอีกแล้วนะคะ เติมเงินผ่านแอพไม่ได้ค่ะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ห้องปกติคืนนิดเดียว อย่าคืนเลยค่าเน็ตยังไม่พอเลย
# ช่วยเหลือ มันต้องทุกระดับชั้นทุกคน ไม่ใช่บางกรณี ห่วยมากค่ะ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# จะใช้แค่มาตราการเบื้องต้น แล้วยะงเมื่อ วันอังคารที่ผ่านมาทางโรงเรียนยังจัด
# ให้มีงานปัจฉิมนิเทศ อีกซึ่งเพิ่มความเสี่ยงในการติดเชื้อขึ้นไปอีก ถ้าโควิท19
# ระบาดในเด็กน่ากลัวมากนะค่ะ อันตรายต่อเด็กๆ , 0.0
# 7/7 [==============================] - 0s 5ms/step
# รร.ควรน่าจะป้องกันโดยการห้ามเด็ก นร.ที่มีบ้านอยู่ในเขตเสี่ยงงดการเรียน
# และให้เรียนออนไลน์เป็นกลุ่มพิเศษไปเพื่อเป็นการป้องกันตั้งแต่ต้น , 0.0
# 5/5 [==============================] - 0s 5ms/step
# โรงอาหาร รร กินจนเบื่อละ , 0.0
# 1/1 [==============================] - 0s 22ms/step
# ควรมีดื่มน้ำสะอาดๆ ที่กินอยู๋ตอนนี้เด็กบอกรสชาติแปลกๆ ไม่ไหวนะคะแบบนี้ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# พอคนเยอะไป อาจารย์ที่อยู่ริมก็ตัวขาด เพราะ Greenscreen ไม่กว้างพอครับ , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ระยะภาพ มีผลต่อความรู้สึกของผู้ฟังนะครับ แนะนำใช้ Close up
# ตอน ผอ.พูดบางก็ดีครับ ตอนนี้มันกว้างและแช่เกินไป , 0.0
# 4/4 [==============================] - 0s 6ms/step
# น่าจะให้ ม.ต้น ม.ปลาย สลับกันไปเรียนนะคะ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# แล้วเรื่องค่าชุดละคะยังไม่เห็นได้เลย จะจบเทอมแรกแล้ว , 0.0
# 2/2 [==============================] - 0s 6ms/step
# คิวอาร์โค้ดเล็กมาก แตกด้วยแสกนไม่ได้ค่ะ , 0.0
# 2/2 [==============================] - 0s 4ms/step
# ปิดต่อไปเด็กก็งงกับการเรียน แต่ถ้าเปิดก็เสี่ยง 😰😰 , 0.0
# 2/2 [==============================] - 0s 6ms/step
# โรงเเรียนควรมีนโยบายเรียนวันคู่วันคี่ค่ะ เด็กๆจะได้ไม่อันตรายต่อการเสี่ยง , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ลูกเข้าห้องเรียนออนไลน์ไม่ได้ ตัวลิ้งทำไมไม่เตรียมให้พร้อมก่อน , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ร้อนกะร้อนน ฝุ่นกะเยอะะ โอ๊ยยยฟรุ๊ดฟริ๊ดดโว้ยยย , 0.0
# 2/2 [==============================] - 0s 7ms/step
# น่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะ , 0.0
# 2/2 [==============================] - 0s 8ms/step
# ตอนนี้ควรบริหารจัดการ เรื่องการจราจรก่อนนะครับ ช่วงเย็นรถติดขนาดไหน
# ลองออกมายืนดูบ้างครับ ติดยาวไปยันปากเกร็ด , 0.0
# 4/4 [==============================] - 0s 8ms/step
# ที่รถมันติดหนักทุกวันนี้ก็เพราะแก้ปัญหาด้วยวิธีง่อยๆแบบนี้แหละค่ะ แย่มาก , 0.0
# 3/3 [==============================] - 0s 6ms/step
# คิดราคาค่าเทอม ep..แพงกว่าธรรมดา , 0.0
# 1/1 [==============================] - 0s 28ms/step
# ที่ผ่านมาทางโรงเรียนตัดสินใจเองหมด ควรมีทางแก้ไขที่ดีกว่านี้ครับ , 0.0
# 2/2 [==============================] - 0s 9ms/step
# ควรให้เด็กเดินเข้าไปได้ก็ดีนะครับ เพราะช่วยลดเวลาไปถึงประตู 1
# หรือลานจอดรถไปได้หลายสิบนาทีเลย , 0.0
# 3/3 [==============================] - 0s 7ms/step
# กลายเป็นว่าทุกวันนี้มีทางเดียวที่ต้องใช้ รร.คิดว่ารถกี่พันคันที่ต้องใช้ทางนี้ ห่วย! , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ควรให้วนเหมือนเดิมนะคะ , 0.0
# 1/1 [==============================] - 0s 23ms/step
# ห้องน้ำสกปรกมาก รบกวนตรวจด้วยนะคะ , 0.0
# 2/2 [==============================] - 0s 4ms/step
# ทุกวันนี้รถติดกระทบยาวเลยค่ะ ควรแก้ปัญหาจุดนี้ได้แล้ว , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ปัญญาอ่อนมาก ขนาดฝนตกลงมาแล้ว บอกต้องรอคำสั่งๆ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# การจราจรอัมพาตมาก หางแถวยาวทุกเส้นทาง รร.ควรพิจารณานะคะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น ควรมองปัญหาตรงนี้ได้แล้ว , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# รปภ.ต้องเข้มงวดบ้างนะคะ เพราะหลายๆคนบ่นว่าโรงเรียนทำให้รถติด , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ควรห้ามรถทุกชนิด เข้า รร. เลยดีที่สุดรวมทั้ง ครูด้วย จบ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ปีหน้าถ้ายังบริหารแย่แบบนี้อีก​ ผมว่าจะให้ลูกย้ายโรงเรียนดีกว่า , 0.0
# 2/2 [==============================] - 0s 7ms/step
# อย่าเอาแต่นั่งห้องแอร์​ ผู้ปกครองทุกคนเค้าเบื่อพวกท่านเต็มทนแล้วครับ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ปัญหาทุกๆปัญหา มีทางแก้ มีทางออก ยอมรับฟังเสียงขอ ผปค บ้าง
# ไม่ใช่ เอาแต่หาเงินเข้า รร , 0.0
# 3/3 [==============================] - 0s 7ms/step
# ปัญหามันไม่ได้เกิดกับผู้ปกครองหรอกคะ ปัญหามันเกิดจากการที่พวกท่านๆ
# เพิกเฉยและเอาเปรียบมากกว่า , 0.0
# 3/3 [==============================] - 0s 7ms/step
# ให้คุณครู และอาจารณ์. เชิญออกมาจอดรถที่ลานจอดด้วยนะค่ะ วันไหนที่ฝนตก
# ทั้งตอนเช้าและตอนเย็นจะได้รับรู้ถึงปัญหาของ ผปค.และนักเรียน , 0.0
# 4/4 [==============================] - 0s 6ms/step
# รบกวนเปิดตั้งแต่16.00 เหมือนเดิมค่ะ ส่วนรถผู้ปกครองที่เห็นแก่ตัว ล็อคล้อ
# จ่ายค่าเสียหายไปเลยค่ะ ไม่งั้นรถจะสา , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ความเห็นแก่ตัวของคนส่วนน้อย ทำให้คนส่วนใหญ่ที่เคารพกติกาต้องมีปัญหา
# เมื่อผู้ใหญ่ยังไม่รู้จักกฏกติกา แล้วจะเอาอะไรไปสอนลูกสอนหลานล่ะ , 0.0
# 5/5 [==============================] - 0s 5ms/step
# ควรหาทางแก้ปัญหาให้ดีกว่านี้นะ เมื่อวานผมติดอยู่ในลานจอดรถ
# เกือบ 2 ชั่วโมง ผมอยู่แถวนี้มา 10 ปี ไม่เคยเจอรถติดขนาดนี้  , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ลูกชายคนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่าไม่อร่อยและกินไม่ได้เลยค่ะ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ที่ผมเลือกให้ลูกมาเรียนเอกชนสู้กับค่าเทอมที่ค่อนข้างสูง เพื่อการศึกษา
# และสภาพแวดล้อมที่ดี แต่สิ่งที่เจอตอนนี้มันไม่คุ้มค่ากับค่าใช้จ่ายที่เผมต้องเสีย , 0.0
# 5/5 [==============================] - 0s 7ms/step
# การที่ไม่แก้ปัญหา ปัญหามันจะไม่จบเมื่อมันสะสมมากๆ มันลุกลามบานปลายนะคับ , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ขออนุญาตนะคะ คือตอนนี้ดิฉัน (และเชื่อว่าอีกหลายๆคน) ได้รับผลกระทบในช่วงเช้าเป็นอย่างมาก จากการจราจรที่ติดขัดในการเปิดการเรียนการสอนแบบเต็มระบบ  , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ , 0.0
# 2/2 [==============================] - 0s 10ms/step
# ควรแก้ให้เปิดประตูทุกด้านเพราะตอนเช้ามันติดหนักมากหน้ารร.เพราะการป้องกัน
# แค่นี้ไม่ช่วยอะไรเลย , 0.0
# 3/3 [==============================] - 0s 7ms/step
# การจราจรอัมพาตมาก หางแถวยาวทุกเส้นทาง พอผ่านหน้ารร.ได้เท่านั้นแหละ โล่งเชียว รร.ควรพิจารณานะคะ ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น , 0.0
# 5/5 [==============================] - 0s 6ms/step
# แล้วคนที่ไม่ได้เรียนเสริม ก็ต้องลำบากเหมือนเดิมใช่ไหม ต้องรอเข้าประตู 5 เวลา
# 17.00 น.มันใช่ไหมทุกวันนี้กว่าจะมาถึง รร.ก็เสียเวลามากพอแล้วเห็นใจกันบ้างนะ , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ควรตั้งกรวยบังคับให้ออกประตู4ทางเดียวนะคะ ให้ยามมาโบกเหมือนเดิม เพราะ
# ผปค.จำเป็นต้องออกประตู4ตอน4โมงอะคะ  , 0.0
# 4/4 [==============================] - 0s 5ms/step
# โรงเรียนไม่สมควรทำเป็นอย่างยิ่งค่ะ การที่มีรถแอบเข้าไปจอดควรจัดการปัญหา
# ให้ รปภ. และเจ้าหน้าที่ตรวจสอบอย่างเข้มข้น เพราะมันจะกระทบกับผู้ปกครอง
# จำนวนมากค่ะ , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ผู้ปกครองทำผิดกฎ 1 ท่านแต่ทางโรงเรียนตัดสินทุกท่าน​ ปัญหารถตืดเป็นชั่วโมง
# รอบโรงเรียนมีวิธีแก้ไม่ควรปล่อยเป็นภาระผู้ปกครองต่อไป , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ผลงานที่ยอดแย่ 8:32 ผู้ปกครองยังวุ่นวายวนจอดรถเพื่อเดินไปส่งลูก สุดยอดมัยคะ รถติดแออัดสะสมยันสะพานพระราม4จร้า , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ณ.เวลานี้วันนี้ รร.เปิดทุกระดับชั้นเพราะวันที่ 8-9 กย รร ยังมีการสอบนักเรียน
# ม.ปลายกับ ม.ต้นยังสลับกันมาก็ยังไม่เต็มรูปแบบ แต่วันนี้รถติดมากเป็นผลมาจาก
# รร.ชลประทานเปิดเรียนเต็มทุกระดับชั้นต้องพิจารณานะคะว่าควรจะทำยังไง , 0.0
# 7/7 [==============================] - 0s 6ms/step
# ขณะนี้เวลานี้ยังติดกันอยู่ในลานจอดรถแบบขยับไม่ได้เลย เสียเวลามากมาย , 0.0
# 3/3 [==============================] - 0s 6ms/step
# รบกวนทาง รร. ใส่ใจปัญหานี้ก่อนจะลามไปเรื่องอื่นค่ะ ควรปรับปรุงแนวทางการ
# จราจรใน รร. ถ้ามันไม่เวิร์ค ก็ปรับปรุง  , 0.0
# 4/4 [==============================] - 0s 6ms/step
# แย่มาก
# บ้านอยู่แค่ใน ซ. รร.อัมพรไพศาลออกบ้าน 6.00 น. จะส่งลูกให้ทันเรียนเสริมเช้า 7.30 น.ยังสาย , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ตอนเย็นก็มี ผปค เห็นแก่ตัวจอดรถปิดหน้ารถที่จอดในช่อง แล้วไม่ใส่เกียร์ว่าง
# เราต้องรอนานมากกว่านางจะมา แล้วจอดกัน2ด้านเลย รถที่วิ่งออกไปลำบากมาก  , 0.0
# 5/5 [==============================] - 0s 5ms/step
# เกินไปแล้ว ค่าเทอมขึ้นตลอดโต๊ะเรียนปรับปรุงหน่อยคะเก่ามาก , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ไม่ต้องอ้างฝุ่นเพาะตึกเรียนข้างลานจอดรถใหม่เด็กกินฝุ่นเข้าไปเต็มๆ , 0.0
# 3/3 [==============================] - 0s 4ms/step
# ห้องเรียน ห้องนำ้ ภาชนะที่ใส่อาหารเด็ก ผู้บริหารควรจะมาดูแลเอาใจใส่เรื่องนี้มั่งนะคะ. ยอดแย่ลงทุกวันคะ. , 0.0
# 4/4 [==============================] - 0s 5ms/step
# ควรจะเปิดให้รถผู้ปกครองเข้าไปรับส่งเด็กได้นะคะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ตอนนี้เดือดร้อนมาก ลูกเรียนอนุบาล 2 กับ ป.1 วนรถกว่าหาที่จอด
# เข้าไปส่งใน รร.ได้ เสียเวลาเป็นชั่วโมง , 0.0
# 4/4 [==============================] - 0s 5ms/step
# รร.ปรับปรุงเรื่องที่จอดรถไม่ใช่ว่าจะทำให้เหตุการณ์รถติดดีขึ้น ที่ไม่โวยวาย
# เพราะต้องทน ถ้ายังเป็นอยู่อย่างนี้ , 0.0
# 4/4 [==============================] - 0s 5ms/step
# รถติดมากคะไม่สมควรปิดประตู4ติดทั้งเช้าเย็นไม่เฉพาะแต่ผู้ปกครองรถทั่วไปก็พลอยติดไปด้วยเพราะไม่มีทางระบายรถผู้บริหารควรมาดูความเป็นจริงบางนะคะแย่มากช่วงนี้ , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ลานจอดรถก็ไม่เพียงพอ พิจารณาแก้ไขด้วย !! , 0.0
# 2/2 [==============================] - 0s 4ms/step
# ทาง รร. ควรทำมาตรการเด็ดขาดไปเลยค่ะว่าไม่ให้จอด ให้ขับรับแล้วออกเลย , 0.0
# 3/3 [==============================] - 0s 5ms/step
# สงสารเด็กๆที่ต้องเดินไกล และผู้ปกครองในตอนเช้าก็ต้องรีบไปทำงานด้วยค่ะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ถ้าทุกคนปฎิบัติตามกฎและระเบียบที่ทางโรงเรียนวางไว้ก็คงไม่วุ่นวายมากแบบนี้
# แต่มีคนบางกลุ่มที่เห็นแก่ตัว และเห็นแก่ความสะดวกสบายของตัวเอง ทำให้เกิด
# ความวุ่นวายและยุ่งยากแบบนี้...เห็นหลายรอบแล้ว  , 0.0
# 6/6 [==============================] - 0s 6ms/step
# ควรจัดยาม รร.มาโบกรถที่ซอยต้นสนหลัง รร.หน่อยค่ะ รถติดแย่งกันไปแย่งกัน
# มาทำให้ไปทำงานไป รร.ไม่ทันค่ะ , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ การเห็นแก่ตัวของคนส่วนน้อย แต่สร้างปัญหาให้คนส่วนมาก อันนี้ไม่ถูกต้องนะครับ  , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ การเห็นแก่ตัวของคนส่วนน้อย แต่สร้างปัญหาให้คนส่วนมาก อันนี้ไม่ถูกต้องนะครับ  , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ฝากพิจารณารถตู้ รับ-ส่ง นักเรียนด้วยนะครับ พอเริ่มเรียนเต็ม รถตู้แน่นมากๆนะครับ  , 0.0
# 3/3 [==============================] - 0s 6ms/step
# รถติดทั้งเช้าทั้งเย็น รร ควรเปลี่ยนวิธีและรีบแก้ไขคะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# การจราจรหน้ารร.ติดขัดไปไกล ควรเกรงใจผู้ใช้ถนนคนอื่นด้วยค่ะ , 0.0
# 2/2 [==============================] - 0s 8ms/step
# มีปัญญาแก้ไขปัญหาเพียงแค่นี้แล้วจะไปสอนอะไรเด็กๆ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ทุกวันนี้ก็ติดโครตๆแล้ว ไม่เห็นมีการพัฒนาเลย , 0.0
# 2/2 [==============================] - 0s 6ms/step
# เมื่อวานลูกเปียกมาเลยคะนั่งหนาวในรถตู้กว่าจะถึงบ้าน​ เค้ามีร่มมีเสื้อกันฝนแต่
# เด็กน้อยยังไงก็มีเปียกคะ​ วันหนัยไปรับเองก็วนรถจนท้อคะ​ ปรับปรุงหน่อยนะคะ , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ไม่เข้าใจแค่ให้ขับรถวนเข้าไปส่งนักเรียนแค่นี้มันจะแย่อะไรนักหนา ดูข้างหน้า
# รร รถติดมาก , 0.0
# 3/3 [==============================] - 0s 6ms/step
# ติดหนักมากคะด้านนอก แบบนี้ไม่ไหวนะคะ ติดเช้า/เย็นเห็นใจ ผปค.บ้างคะ , 0.0
# 2/2 [==============================] - 0s 8ms/step
# ควรปรับปรุงแก้ไข้อลุ้มอร่วยบ้างกรณีฝนฟ้าตก ฝากไว้ให้คิดด้วยคับ , 0.0
# 2/2 [==============================] - 0s 8ms/step
# เจอปัญหารถติด ก็พอทน แต่น้ำท่วมในรร.ขนาดนี้ บอกเลยว่าขอบาย สงสารลูก
# หากต้องเดินลุยน้ำเรียน ไม่ไหวจริงๆ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# คิดได้แย่มากให้รถเข้าออกทางเดียว รถทางตรงเขาก็ไปไม่ได้ ติดรถ ผปค. รอเลี้ยวเขาซอยข้างสนามกอล์ฟ แทนที่จะเปิดอีกประตูด้านวัด ให้เข้าออกได้อีกทาง
#  , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ที่จอดรถที่ทำอยู่ไม่เพียงพอแน่นอน ติดสนั่นทั้งอำเภอปากเกร็ดแน่ๆ พิจารณา
# อีกทีค่ะ !! , 0.0
# 3/3 [==============================] - 0s 6ms/step
# พวกเขาอยู่เเต่ห้องเเอร์รอเงินอย่างเดียวละครับพวกนี้ไม่เคยลงมาดูอะไรสักอย่าง , 0.0
# 3/3 [==============================] - 0s 6ms/step
# อย่าเอาแต่นั่งห้องแอร์​ ผู้ปกครองทุกคนเค้าเบื่อพวกท่านเต็มทนแล้วครับ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# รถมันก็ติดเป็นคอขวดเลยครับ บริหารจัดการแย่มาก , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ได้รับผลกระทบในช่วงเช้าเป็นอย่างมาก แก้ไขปัญหาบ้างครับ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# พยายามปรับเปลี่ยนเวลาในการออกไปทำงานให้เร็วขึ้นเพื่อเลี่ยงการจราจรแล้ว
# แต่ก็ยังได้รับผลกระทบอยู่เหมือนเดิม รร ควรจะแก้ไขการจราจรได้แล้ว , 0.0
# 5/5 [==============================] - 0s 6ms/step
# ผปค บางคนวิ่งส่วนย้อนทางออกทำให้รถคันอื่นติดยาวที่จอดข้างใน
# ควต้องปรับปรุงรการจราจร และนิสัยผู้ปกครองด้วย , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ผู้ปกครองบางคนก็เห็นแก่ตัว ไม่เตรียมตัวพร้องลงลืมของลืมกระเป๋ารองเท้าบ้าง
# จอดรอลูกไปซื้อของห้องสหกรณ์รถติดยาว , 0.0
# 4/4 [==============================] - 0s 6ms/step
# รร.ควรพิจารณานะคะ ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น  , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ดีจัง ลูกเราย้ายมาเรียนหอวังนนท์แล้ว มาอ่านแล้วเหมือนย้อนกลับไป ที่ต้องทน
# มา 6ปี ที่แล้ว ปัญหาที่แก้ไข ไม่ได้ 🤭🤭 , 0.0
# 4/4 [==============================] - 0s 6ms/step
# รบกวนเปิดตั้งแต่16.00 เหมือนเดิมค่ะ ส่วนรถผู้ปกครองที่เห็นแก่ตัว ล็อคล้อ
# จ่ายค่าเสียหายไปเลยค่ะ ไม่งั้นรถจะสาหัสมาก , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ความเห็นแก่ตัวของคนส่วนน้อยทำให้คนส่วนใหญ่ที่เคารพกติกาต้องมีปัญหาแย่ๆ , 0.0
# 3/3 [==============================] - 0s 6ms/step
# เมื่อวานผมติดอยู่ในลานจอดรถ เกือบ 3 ชั่วโมง ควรหาทางแก้ปัญหานะ  , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ห้ามนำรถเข้าไปจอดในโรงเรียนผมเห็นด้วยนะคับ แต่ถ้าห้ามเข้าไปเลยปัญหา
# ก็เป็นแบบนี้ ควรหาวิธีแก้ด้วยครับ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# เพจโรงเรียนเลี่ยงที่จะตอบคำถามทางผู้ปกครอง ผมนั่งดูย้อนหลังไปน้อยมากที่จะ
# มาตอบปัญหาที่มีการสอบถามเรื่องการจราจร ห่วยไปนะครับบบ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# ควรเปิดช่องประตูเล็กเพื่อให้ผู้ปกครองเดินไปส่งได้นะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ครูใส่รองเท้าที่เดินข้างนอกเหยียบพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย
# รบกวนทาง รร พิจารณาเรื่องความสะอาดให้เด็กๆด้วย , 0.0
# 4/4 [==============================] - 0s 6ms/step
# เด็กๆ บางคนไม่ชอบ มักกะโรนี ควรมีอะไรแทนบ้างนะคะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ควรปรับปรุงเรื่องรสชาติบ้างนะค ต้มจืดก็จืดมาก , 0.0
# 2/2 [==============================] - 0s 7ms/step
# หมูก็ให้มาแค่ชิ้นน้อยๆ ควรพิจารณาปรับปรุงค่ะ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# หวังว่าจะปรับปรุงเรื่องรสชาติและปริมาณที่เหมาะสมนะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# เด็กต้องแบกกระเป๋าหนัก และเดินไกลมากฝากปัญหานี้ให้ผู้บริหารด้วยค่ะ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# จยย.ที่ขับเข้ามาแล้วเด็กต้องเดินหลบรถอันตรายมาก , 0.0
# 2/2 [==============================] - 0s 7ms/step
# กับข้าวของลูกๆอิสลาม ยังไม่ได้รับการปรับปรุงเลยค่ะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ลานจอดใหม่ ฝุ่น เยอะมาก , 0.0
# 1/1 [==============================] - 0s 22ms/step
# ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถทีครับ เยอะมากสงสารสุขภาพลูก , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ถนนข้างสนามกอล์ฟฝุ่นฝุ่นเยอะมาก ควรแก้ไขตรงนี้ด่วนๆค่ะ , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่สงสารเด็กๆมาก , 0.0
# 2/2 [==============================] - 0s 8ms/step
# ถ้าโรงเรียนไม่มีศักยภาพในการจัดสรรระบบการจอดรถ การจราจรพอ ควรจะเปิดให้รถผู้ปกครองเข้าไปรับส่งเด็กได้นะคะ , 0.0
# 4/4 [==============================] - 0s 6ms/step
# อิดออดในการคืนเงินมาก หรือต้องให้คำนวนให้ แย่มาก , 0.0
# 2/2 [==============================] - 0s 7ms/step
# เพจโรงเรียนเลี่ยงที่จะตอบคำถามทางผู้ปกครองผมนั่งดูย้อนหลังไปน้อยมากที่จะมาตอบปัญหาที่มีการสอบถามเรื่องการจราจร การที่ไม่แก้ปัญหา
#  ปัญหามันจะไม่จบเมื่อมันสะสมมากๆ มันลุกลามบานปลายนะคับ , 0.0
# 6/6 [==============================] - 0s 8ms/step
# รร. ปรับปรุงเรื่องที่จอดรถไม่ใช่ว่าจะทำให้เหตุการณ์รถติดดีขึ้น ที่ไม่โวยวายเพราะต้องทน ถ้ายังเป็นอยู่อย่างนี้คงต้องหา รร.ใหม่ให้ลูกค่ะ ตอนนี้เสียสุขภาพจิตมาก , 0.0
# 5/5 [==============================] - 0s 7ms/step
# ช่วยดูด้วยค่ะว่าเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหน , 0.0
# 2/2 [==============================] - 0s 7ms/step
# รบกวนออกมาชี้แจ้งด้วยค่ะ , 0.0
# 1/1 [==============================] - 0s 22ms/step
# ก๋วยเตี๋ยวหมูน้ำตก หมูน้อยไปนะควรเพิ่มอีกนิดค่ะ !! , 0.0
# 2/2 [==============================] - 0s 6ms/step
# แกงคั่วฟักทอง คิดว่าเด็กๆไม่น่าชอบนะคะ ควรเปลี่ยนจากแกงบ้าง , 0.0
# 2/2 [==============================] - 0s 7ms/step
# ยำหมูยอลดความเผ็ดลงหน่อยคะ่หนูทานไม่ได้ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# แอปเปิ้ลช้ำไปหน่อยค่ะ ช่วยปรังปรุงอีกนิดนะคะ , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ทอดมันมันมากกก ลูกกินไม่ได้ปรังปรุงด่วนค่ะ , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ทั้ังประชาชนทั้ง ผปค ด่าไปผู้บริหารไม่เคยเข้ามาดูไม่เคยแก้ไขปัญหาตรงนี้เลย , 0.0
# 3/3 [==============================] - 0s 6ms/step
# แกงขั่วฟักเขียว แค่ชื่อเด็กๆไม่ทานแล้ว เด็กๆคงเบื่อแกงแล้วค่ะ  , 0.0
# 2/2 [==============================] - 0s 8ms/step
# ควรเพิ่มปริมาณข้าวสวยอีกนิดค่ะ ลูกทานไม่อิ่ม , 0.0
# 2/2 [==============================] - 0s 6ms/step
# ไข่เจียวจืดมาก ปรังปรุงรสชาติหน่อยก็ดีนะครู , 0.0
# 2/2 [==============================] - 0s 5ms/step
# ข้าวผัดกุนเชียง แต่กุนเชียงได้น้อยมาก ปรังปรุงด้วยค่ะหลายรอบแล้วนะคะ  , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ก๋วยเตี๋ยวเปลี่ยนจากเส้นหมี่เป็นบะหมี่บ้างนะคะ ไม่ได้เรื่องเลย , 0.0
# 2/2 [==============================] - 0s 8ms/step
# ก๋วยเตี๋ยวเส้นหมี่อีกแล้ว ลองมากินเองมั้ยคะจะได้รู้ว่ามันน่าเบื่อ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ห้องน้ำสกปรกมาก ตรวจด้วยค่ะ !!! , 0.0
# 1/1 [==============================] - 0s 21ms/step
# รบกวนออกมาชี้แจ้งเรื่องคืนค่าเทอมด้วยค่ะ , 0.0
# 2/2 [==============================] - 0s 9ms/step
# ห้องน้ำยังคงสกปรกเหมือนเดิม , 0.0
# 1/1 [==============================] - 0s 24ms/step
# ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอด , 0.0
# 2/2 [==============================] - 0s 4ms/step
# ต้มจืดลูกบอกจืดสมชื่อมาก พิจาณาด้วยค่ะ , 0.0
# 2/2 [==============================] - 0s 4ms/step
# ปรับปรุงเรื่องที่จอดรถด้วยค่ะ ตอนนี้เสียสุขภาพจิตมาก , 0.0
# 2/2 [==============================] - 0s 7ms/step
# โรงอาหารมีหนู สกปรกไปนะแก้ไขด่วนค่ะะะะะ , 0.0
# 2/2 [==============================] - 0s 4ms/step
# ควรจัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ​ ไม่ไหวๆ , 0.0
# 3/3 [==============================] - 0s 5ms/step
# ภาพกิจกรรมสอนเสริมวันเสาร์เทควันโด สวยมากเลยค่ะ , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ขอบคุณมากๆเลยค่าสำหรับอาหารของเด็กอนุบาลที่ไม่ใส่พริกแกง  , 1.0
# 2/2 [==============================] - 0s 7ms/step
# โรงเรียน update ข่าวสารรวดเร็ว ทันใจผู้ปกครองมากค่ะ สุดยอดค่ะ , 1.0
# 2/2 [==============================] - 0s 7ms/step
# เด็กๆได้รับทั้งความรู้และสนุกสนาน แถมได้กระชับมิตรกับเพื่อน
# ใหม่ในกลุ่ม ดีมากๆค่ะ , 1.0
# 3/3 [==============================] - 0s 7ms/step
# ในที่สุด 😆😆😆😆 เพจจะกลับมาเหมือนปกติแล้วเย้ๆ , 1.0
# 2/2 [==============================] - 0s 4ms/step
# เด็กดีเราต้องชื่นชมเป็นกำลังใจให้สุดยอดเลยจ้า , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ชื่นชมในความมีวินัยมานะบากบั่นในการฝึกซ้อมจนได้รับรางวัล
# ขอให้ประสพความสำเร็จยิ่งยิ่งขึ้นไปค่ะ ขอแสดงความยินดีด้วยนะคะ , 1.0
# 4/4 [==============================] - 0s 7ms/step
# เด็กๆเก่งมากค่ะ ❤❤ , 1.0
# 1/1 [==============================] - 0s 22ms/step
# ขอบคุณมากเรยค่ะที่ตอบคำถามคุณแม่ ส่วนใหญ่ ผปค.มีผลกระ
# ทบช่วงเช้ามากกว่าช่วงเย็นค่ะคุณครู ตอนเช้าวนเข้า รอรถออก
# นานมากเลยค่ะ , 1.0
# 4/4 [==============================] - 0s 8ms/step
# ขอบคุณทาง รร ค่ะ ส่วนหนึ่งก็เห็นใจที่ รร จะต้องใช้เงินบริหารจัด
# การบุคคลากรใน รร เพื่อให้ รร อยู่รอดเพราะเป็น ร.รเอกชน , 1.0
# 4/4 [==============================] - 0s 7ms/step
# อาหารใช้ได้ค่ะ ลูกบอกว่าอร่อย บางวันก็ถุกปาก ปากวันก็ไม่ถุก
# ปาก สลับๆกันไปค่ะ แต่อย่างว่าแต่ละคนชอบไม่เหมือนกีน รวมๆ
# แล้ว ดีค่ะ , 1.0
# 4/4 [==============================] - 0s 7ms/step
# ในสถานการณ์เเบบนี้การบริหารการจัดการไม่ใช่เรื่องง่าย
# เป็นกำลังใจให้นะครับสู้ๆครับ..
#  , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่
# จะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้
# มากเลยครับ , 1.0
# 4/4 [==============================] - 0s 7ms/step
# ขอบคุณสำหรับการทำคลิปที่ภาพสวย เสียงชัดนะคะ
# ครูและทีมคงต้องเหนื่อยและตั้งใจกันมาก  , 1.0
# 3/3 [==============================] - 0s 7ms/step
# CPW Classroom ดูง่ายขึ้น สะดวกมากขึ้น ขอบคุณนะคะ , 1.0
# 2/2 [==============================] - 0s 8ms/step
# ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ , 1.0
# 2/2 [==============================] - 0s 4ms/step
# ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจ
# ขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ , 1.0
# 4/4 [==============================] - 0s 6ms/step
# ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจ
# ขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ , 1.0
# 4/4 [==============================] - 0s 6ms/step
# ขอบคุณทางรร. ที่รับฟัง และนำเอาคำติชมของผปค. ทุกท่านไป
# ปรับเปลี่ยนเมนู ให้สอดคล้องกับเด็กประถมเล็กๆ ด้วยนะคะ 🙏🏻 , 1.0
# 4/4 [==============================] - 0s 7ms/step
# เรียนออนไลน์แล้วนักเรียนได้เกรดดีมากเลยค่ะ , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ขอให้แก้ปัญหาได้นะคะ สู้ๆค่ะเป็นกำลังใจให้นะคะ , 1.0
# 2/2 [==============================] - 0s 7ms/step
# ขอขอบคุณนักเรียนจิตอาสาของโรงเรียนด้วยนะครับที่เข้ามาทำ
# ความสะอาดที่วัด , 1.0
# 3/3 [==============================] - 0s 5ms/step
# คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ , 1.0
# 2/2 [==============================] - 0s 7ms/step
# ขอบคุณนะคะ จะได้ไปบอกลูกเค้าอยากดูมากเลย 🙂 , 1.0
# 2/2 [==============================] - 0s 6ms/step
# หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ ชอบอาหารที่ ร.ร , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน
# ทุกๆท่าน สู้นะค่ะ , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน
# ทุกๆท่าน สู้นะค่ะ , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ช่วงบ่ายดูได้ปกติแล้วครับ..ขอบคุณมากๆครับ.. , 1.0
# 2/2 [==============================] - 0s 5ms/step
# ขอบคุณผอ.ด้วยนะคะ วันนี้เห็นผอ.ไปช่วยดูแลเด็กๆข้ามถนน , 1.0
# 2/2 [==============================] - 0s 7ms/step
# เมื่อเช้าเห็นท่าน ผอ.ออกมายืนรับเด็กๆตรงไฟแดงเอง
# ท่านน่ารักมากๆ , 1.0
# 2/2 [==============================] - 0s 12ms/step
# ขอแสดงความยินดีแด่คุณครูทุกๆท่านเป็นอย่างยิ่งครับ , 1.0
# 2/2 [==============================] - 0s 6ms/step
# เยี่ยมมากๆ...นี่แหละคนรุ่นใหม่และหลายๆคน ในร.ร.
# จะมาสร้างฝันและดูแลชลประทานให้ยิ่งใหญ่ๆต่อไป , 1.0
# 3/3 [==============================] - 0s 6ms/step
# เยี่ยมมากๆ...นี่แหละคนรุ่นใหม่และหลายๆคน ในร.ร.
# จะมาสร้างฝันและดูแลชลประทานให้ยิ่งใหญ่ๆต่อไป , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ศิษย์เก่งมาจากครูที่เก่งด้วยค่ะ ขอชื่นชมค่ะ
#  , 1.0
# 2/2 [==============================] - 0s 5ms/step
# ยินดีกับคุณครูอีกครั้งหนึ่งครับเหมาะสมมากๆครับ , 1.0
# 2/2 [==============================] - 0s 7ms/step
# ขอบคุณคุณครูและบุคลากรที่ รร.ทุกท่านที่คอยดูแลเอาใจใส่ นร.ค่ะ
#  , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ชอบมากเลยคะโรงเรียนนี้..เคยเข้าไปติดต่อจะพาลูกเข้าเรียนตอน
# ม.4เจ้าหน้าที่พูดจาดีมากๆ  , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ชอบมากเลยคะโรงเรียนนี้..เคยเข้าไปติดต่อจะพาลูกเข้าเรียนตอน
# ม.4เจ้าหน้าที่พูดจาดีมากๆ  , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ขอบคุณมากๆ เลยนะคะ ขอบคุณมากจริง ๆ ค่ะ , 1.0
# 2/2 [==============================] - 0s 5ms/step
# ขอขอบคุณโรงเรียนชลประทานวิทยา อาจารย์ทุกท่านที่ให้การ
# สนับสนุนหนูทั้งเวลาเรียน และเวลาซ้อมค่ะ 🙏 , 1.0
# 3/3 [==============================] - 0s 6ms/step
# ขอบคุณมากเลยค่ะที่ตอบคำถามคุณแม่ สบายใจมากขึ้นเลยค่ะ , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ขอบคุณที่ปรับปริมาณอาหารให้กับเด็กนะคะ ขอบคุณมากจริงๆค่ะ , 1.0
# 2/2 [==============================] - 0s 7ms/step
# ขอบคุณที่ปรับปริมาณอาหารให้กับเด็กนะคะ ขอบคุณมากจริงๆค่ะ , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ลูกบอกว่าอาหารวันนี้อร่อยมากค่ะ ปริมาณอาหารกำลังดีด้วยค่ะ , 1.0
# 2/2 [==============================] - 0s 6ms/step
# ลูกบอกว่าอาหารวันนี้อร่อยมากค่ะ ปริมาณอาหารกำลังดีด้วยค่ะ , 1.0
# 2/2 [==============================] - 0s 8ms/step
# แกงเขียวหวานอร่อยมากค่ะ ลูกติดใจอยากใก้ทำอีกค่ะ , 1.0
# 2/2 [==============================] - 0s 7ms/step
# วันนี้การจรจารในโรงเรียนไหลลื่นมากค่ะ ขอบคุณที่ รปภ และ
# ทาง รร นะคะ , 1.0
# ...
# 2/2 [==============================] - 0s 9ms/step
# สอบถามอนุบาล1รับกี่ขวบ และจะสมัครได้วันไหน , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ขอย้ายเข้าตอนป.3 ต้องทำยังไงบ้างครับ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# ปิดรับสมัครนักเรียนเมื่อไหร่ครับ , 2.0
# 1/1 [==============================] - 0s 27ms/step
# ราคาใบสมัครสสวทกับepกี่บาทคะ , 2.0
# 1/1 [==============================] - 0s 41ms/step
# โรงเรียนร ชปว. ไม่มี esmp เหรอค่ะ , 2.0
# 1/1 [==============================] - 0s 27ms/step
# สอบถามครับ​ นักเรียนภายนอก​จบป.6 จะเข้าชั้นมัธยมปีที่1​ มีเฉพาะ
# ห้องEP เหรอครับ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# รับสมัครเด็ก อ.2 เมื่อไหร่คะ , 2.0
# 1/1 [==============================] - 0s 26ms/step
# น้องเกิดตุลา 63 ต้องสมัครปีไหนคะ ต้องโทรไปจองสิทธิ์ตั้งแต่เมื่อไหร่คะ
# ขอบคุณค่ะ , 2.0
# 3/3 [==============================] - 0s 11ms/step
# สอบถามค่ะ ถ้าน้องเรียน อนุบาล 1 มาแล้ว จะเข้าอนุบาล 2 สามารถ
# เข้าได้ไหมคะ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# ศิษย์เก่าสามารถเข้าโรงเรียนได้ไหมคะ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# ขอสอบถามรายละเอียดการรับสมัครครูหน่อยครับ  , 2.0
# 2/2 [==============================] - 0s 7ms/step
# ขออนุญาตสอบถามครับ เห็นลูกผมบอกว่าอาหารอิสลามเป็นเมนูเดียวกัน
# กับอาหารทั่วไปเลยอะครับ มีการเปลี่ยนวัตถุดิบบ้างไหมครับ , 2.0
# 4/4 [==============================] - 0s 9ms/step
# ขออนุญาตสอบถามครับ เห็นลูกผมบอกว่าอาหารอิสลามเป็นเมนูเดียวกัน
# กับอาหารทั่วไปเลยอะครับ มีการเปลี่ยนวัตถุดิบบ้างไหมครับ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# สวัสดีครับ ขอสอบถามหน่อยนะครับว่าวันเปิดเทอมคือวันที่เท่าไรหรอครับ , 2.0
# 3/3 [==============================] - 0s 8ms/step
# สวัสดีครับ ขอสอบถามหน่อยนะครับว่าวันเปิดเทอมคือวันที่เท่าไรหรอครับ , 2.0
# 3/3 [==============================] - 0s 7ms/step
# ขอสอบถามหน่อยนะคะ วันเปิดเทอมวันแรกจะต้องเตรียมอะไรไปในห้อง
# เรียนบ้างหรอคะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# ขอสอบถามหน่อยนะคะ วันเปิดเทอมวันแรกจะต้องเตรียมอะไรไปในห้อง
# เรียนบ้างหรอคะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# สวัสดีครับ ผมชื่อ ด.ช.ณัฐพงศ์ พงศ์เจริญ ผมทำบัตรนักเรียนหัก ต้องทำ
# ยังไงดีครับ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# สวัสดีครับผมขอสอบถามหน่อยนะครับ วันแรกของการเปิดภาคเรียนนี่นัก
# เรียนชายยังต้องตัดผมเกรียนมาเรียนอยู่อีกมั้ยครับ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# สวัสดีครับผมขอสอบถามหน่อยนะครับ วันแรกของการเปิดภาคเรียนนี่นัก
# เรียนชายยังต้องตัดผมเกรียนมาเรียนอยู่อีกมั้ยครับ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# สวัสดีครับผมขอสอบถามหน่อยนะครับ วันแรกของการเปิดภาคเรียนนี่นัก
# เรียนชายยังต้องตัดผมเกรียนมาเรียนอยู่อีกมั้ยครับ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# ดิฉันขอสอบถามหน่อยนะคะ วันเปิดเทอมวันแรกร้านสหกรณ์เปิดมั้ยคะ? , 2.0
# 2/2 [==============================] - 0s 11ms/step
# สามารถจ่ายค่าเทอมแบบออนไลน์ได้มั้ยครับ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# ขอสอบถามหน่อยค่ะ ปักชื่อย่อของโรงเรียนนี้ต้องปักด้านซ้ายหรือด้าน
# ขวาของเสื้อหรอคะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# ขอสอบถามหน่อยค่ะ ปักชื่อย่อของโรงเรียนนี้ต้องปักด้านซ้ายหรือด้าน
# ขวาของเสื้อหรอคะ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# สวัสดีครับ ผมขอทำเรื่องผ่อนผันการจ่ายค่าเทอมได้ที่ไหนหรอครับ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# สวัสดีครับ ผมขอทำเรื่องผ่อนผันการจ่ายค่าเทอมได้ที่ไหนหรอครับ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ขอสอบถามหน่อยครับ.... , 2.0
# 1/1 [==============================] - 0s 23ms/step
# พอดีว่าลูกผมเขากลัวครูปกครองคนนึงอยู่น่ะครับ พอจะช่วยบอกครูคนนั้น
# ให้ลดความดุลงจะได้มั้ยครับ , 2.0
# 3/3 [==============================] - 0s 10ms/step
#  สวัสดีค่ะ ไม่ทราบว่าทางโรงเรียนจะมีขายชุดนักเรียนวันไหนหรอคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
#  สวัสดีค่ะ ไม่ทราบว่าทางโรงเรียนจะมีขายชุดนักเรียนวันไหนหรอคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ขอสอบถามเกี่ยวกับกิจกรรมประชุมผู้ปกครองในวันเปิดภาคเรียนหน่อย
# นะคะ คือช่วงนี้พ่อแม่หนูไปต่างประเทศกันหมด เหลือแต่พี่ชายของหนู
# คือวันประชุมสามารถให้พี่ชายไปเป็นผู้ปกครองของหนูได้มั้ยคะ , 2.0
# 6/6 [==============================] - 0s 10ms/step
# ขอสอบถามเกี่ยวกับกิจกรรมประชุมผู้ปกครองในวันเปิดภาคเรียนหน่อย
# นะคะ คือช่วงนี้พ่อแม่หนูไปต่างประเทศกันหมด เหลือแต่พี่ชายของหนู
# คือวันประชุมสามารถให้พี่ชายไปเป็นผู้ปกครองของหนูได้มั้ยคะ , 2.0
# 6/6 [==============================] - 0s 10ms/step
# ขอสอบถามเกี่ยวกับกิจกรรมประชุมผู้ปกครองในวันเปิดภาคเรียนหน่อย
# นะคะ คือช่วงนี้พ่อแม่หนูไปต่างประเทศกันหมด เหลือแต่พี่ชายของหนู
# คือวันประชุมสามารถให้พี่ชายไปเป็นผู้ปกครองของหนูได้มั้ยคะ , 2.0
# 6/6 [==============================] - 0s 9ms/step
# สวัสดีงับ ผมขอสอบถามเกี่ยวกับการย้ายแผนการเรียนหน่อยงับว่าผมควร
# จะทำยังไง , 2.0
# 3/3 [==============================] - 0s 9ms/step
# สวัสดีงับ ผมขอสอบถามเกี่ยวกับการย้ายแผนการเรียนหน่อยงับว่าผมควร
# จะทำยังไง , 2.0
# 3/3 [==============================] - 0s 8ms/step
# สวัสดีครับ อยากทราบว่าผมจะทำขอทำเรื่องจ่ายค่าเทอมล่าช้าได้ยังไง
# บ้างหรอครับ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# แล้วจะรู้ได้ยังไงว่าทางโรงเรียนได้รับเงินยอดที่โอนหรือยังอ่ะคะ , 2.0
# 2/2 [==============================] - 0s 13ms/step
# สวัสดีค่ะ พอดีช่วงอาทิตย์แรกของการเปิดเทอมหนูยังไม่สามารถมาเรียน
# ได้เนื่องจากยังติดปัญหาของทางบ้านอยู่ พอจะมีใบลาออนไลน์ให้กรอก
# มั้ยคะ? , 2.0
# 5/5 [==============================] - 0s 9ms/step
# ขอสอบถามหน่อยค่ะ เสื้อพละจะมีมาขายในวันไหนหรอคะ , 2.0
# 2/2 [==============================] - 0s 9ms/step
# ขอสอบถามหน่อยค่ะ เสื้อพละจะมีมาขายในวันไหนหรอคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ขอสอบถามหน่อยค่ะ เสื้อพละจะมีมาขายในวันไหนหรอคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ครูคะ หนูขอสอบถามเกี่ยวกับการย้ายโรงเรียนหน่อยค่ะ คือหนูจะย้ายไป
# เรียนที่ สกน หนูต้องเรื่องอะไรบื่นให้ที่โรงเรียนบ้างมั้ยคะ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# ขอสอบถามหน่อยครับ สีกางเกงของโรงเรียนเขาเรียกว่าสีอะไรนะครับ
# พอดีจะซื้อไปให้หลานแต่ไม่แน่ใจว่าเรียกสีนี้ว่าอะไร , 2.0
# 4/4 [==============================] - 0s 10ms/step
# ขอสอบถามหน่อยครับ สีกางเกงของโรงเรียนเขาเรียกว่าสีอะไรนะครับ
# พอดีจะซื้อไปให้หลานแต่ไม่แน่ใจว่าเรียกสีนี้ว่าอะไร , 2.0
# 4/4 [==============================] - 0s 9ms/step
# สระว่ายน้ำเปิดให้บริการวันไหนหรอครับ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# สอบถามหน่อยค่ะ หลักสูตรภาษาอังกฤษ สอนโดยครูต่างชาติหรือเปล่าคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# สอบถามหน่อยค่ะ หลักสูตรภาษาอังกฤษ สอนโดยครูต่างชาติหรือเปล่าคะ , 2.0
# 2/2 [==============================] - 0s 9ms/step
# ค่าเทอม ป.1 พอจะประมาณราคาให้หน่อยได้ไหมครับ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# จะเดินทางมาโรงเรียนชลประทานได้อย่างไร , 2.0
# 2/2 [==============================] - 0s 6ms/step
# ชุดลูกเสื้อที่ถูกระเบียบมันต้องเป็นสีกากีไม่ใช่เหรอครับ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ชุดลูกเสื้อที่ถูกระเบียบมันต้องเป็นสีกากีไม่ใช่เหรอครับ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ตอนนี้ที่สหกรณ์โรงเรียนมีขายไหมครับ หรือต้องไปซื้อจากข้างนอก
# พอดีวันที่ซื้อชุดนักเรียนไม่ได้ซื้อเอาไว้ครับ เเล้วราคาท่าไหร่ครับ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# ขอสอบถามเพิ่มเติมเกี่ยวการสมัครครูแนะแนว พอดีเคยเป็นครูแนะแนวคะ
# มีใบประกอบ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# แล้วจะรู้ได้ยังไงว่าทางโรงเรียนได้รับเงินยอดที่โอนหรือยังอ่ะคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ตรวจสุขภาพนักเรียนที่โรงพยาบาลหรือ โรงเรียนคะ , 2.0
# 2/2 [==============================] - 0s 9ms/step
# เช็ครายชื่อ ดญ.ชุติกาญจน์ จิวระ ชั้นม.2 สอบวิชาวิทยาศาสตร์ แต่ไม่พบ
# รายชื่อน้องค่ะ ต้องทำอย่างไรค่ะ , 2.0
# 4/4 [==============================] - 0s 8ms/step
# สมัครสอบแต่ไม่มีรายชื่อ ต้องทำอย่างไรคะ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# ปิดปลายภาควันที่เท่าไรค่ะ , 2.0
# 1/1 [==============================] - 0s 25ms/step
# ปิดปลายภาควันที่เท่าไรคับ , 2.0
# 1/1 [==============================] - 0s 31ms/step
# ปิดปลายภาควันที่เท่าไรคับ , 2.0
# 1/1 [==============================] - 0s 25ms/step
# ฝนตกหนัก นำรถเข้ารับเด็กในร.ร. ได้ไหม , 2.0
# 2/2 [==============================] - 0s 5ms/step
# สอบถามครับ ศิษย์เก่าสามารถเข้าไปภายในโรงเรียนได้มั้ยครับ
#  , 2.0
# 2/2 [==============================] - 0s 10ms/step
# สอบถามครับ ศิษย์เก่าสามารถเข้าไปภายในโรงเรียนได้มั้ยครับ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ตารางเรียน จะแจกให้ใหม่ หรือ Download ได้วันไหนคะ
#  , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ป.6 ค่าเทอม ประมาณเท่าไรค่ะ , 2.0
# 1/1 [==============================] - 0s 27ms/step
# จะมีการคืนค่าเทอมไหมคะ เหมือนจำได้ว่าเคยแจ้งไปในคอมเม้นว่าจะมี
# การคืนค่าเทอมปลายเทอมนี้ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
# มาเบิกค่ะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
# มาเบิกค่ะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# ส่งเอกสารยืนยันไปแล้วยังไม่เห็นโอนคืนค่าเทอมมาเลยครับ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ชำระเกินไปแล้วต้องทำอย่างไรคะ , 2.0
# 1/1 [==============================] - 0s 29ms/step
# วันอาทิตย์โรงเรียนเปิดไหมครับ , 2.0
# 1/1 [==============================] - 0s 27ms/step
# รับสมัคร อนุบาล 1 ต้องมีอายุเท่าไหร่คะ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# ขอสอบถามค่ะ แผนก ITP เรียนตึกไหนคะ , 2.0
# 2/2 [==============================] - 0s 5ms/step
# ขอสอบถามค่ะ แผนก ITP เรียนตึกไหนคะ , 2.0
# 2/2 [==============================] - 0s 4ms/step
# ยังมีตรวจสุขภาพประจำปีของนักเรียนอยู่มั้ยคะ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# ผลการเรียนของน้องอนุบาลดูได้ที่ไหนหรอค่ะ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# เกรดออกตอนไหนค่ะ เปิดเข้าไปไม่มีค่ะ , 2.0
# 2/2 [==============================] - 0s 5ms/step
# ชำระค่าเทอมของแอปโรงเรียนอยู่ไหนครับ , 2.0
# 2/2 [==============================] - 0s 5ms/step
# ชำระค่าเทอมของแอปโรงเรียนอยู่ไหนครับ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# ดูเกรดเฉลี่ยยังไงค่ะ , 2.0
# 1/1 [==============================] - 0s 24ms/step
# ถ้าของหายที่โรงเรียนนักเรียนต้องไปแจ้งของหายได้จากไหนคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# อยากทราบว่า รองเท้าพละต้องเป็นสีขาวเท่านั้นมั้ยครับ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# วันอาทิตย์สหกรณ์โรงเรียนเปิดไหมครับ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# จะสอบถามเรื่องส่งน้องเข้าเรียน เตรียมอนุบาลอ่ะคะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ภาษาจีนเริ่มเรียนชั้นไหนค่ะ , 2.0
# 1/1 [==============================] - 0s 30ms/step
# หลักสูตรการบินรับสมัครนักเรียนชั้นไหนคะ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# EP ป.1ค่าเทอมเท่าไหรค่ะ , 2.0
# 1/1 [==============================] - 0s 28ms/step
# ใช้บัตรกสิกร ผ่อน 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 2.0
# 2/2 [==============================] - 0s 15ms/step
# ใช้บัตรกสิกร ผ่อน 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 2.0
# 2/2 [==============================] - 0s 12ms/step
# ชำระค่าเทอมสามารถชำระโดยใช้บัตรเครดิต tmb ได้ไหมคะ
# แล้วไปชำระที่ไหนคะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# ถ้าไปจ่ายค่าเทอมต้องไปจ่ายตึกไหนค่ะ เปิดปิดถึงเวลากี่โมงค่ะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ถ้าไปจ่ายค่าเทอมต้องไปจ่ายตึกไหนค่ะ เปิดปิดถึงเวลากี่โมงค่ะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# สามารถเข้าไปติดต่อเพื่อชำระค่าเทอมล่วงหน้าที่ห้องการเงินได้เลยใช่
# ไหมครับเปิดรับชำระได้เลยใช่นะครับ , 2.0
# 4/4 [==============================] - 0s 10ms/step
# เข้าไปจ่ายค่าเทอมก่อนได้มั้ยคะ​ ไม่ถนัดกับการโอน , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ชำระผ่านโมบายแบงค์กิ้งไปแล้วจะได้รับใบเสร็จอย่างไรคะ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ชำระผ่านโมบายแบงค์กิ้งไปแล้วจะได้รับใบเสร็จอย่างไรคะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# จ่ายบัตรเครดิตมีค่าธรรมเนียมไหมคะ , 2.0
# 2/2 [==============================] - 0s 5ms/step
# จ่ายบัตรเครดิตมีค่าธรรมเนียมไหมคะ , 2.0
# 2/2 [==============================] - 0s 5ms/step
# ถ้าชำระผ่าน mobile banking จะได้รับใบเสร็จยังไงคะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# เตรียมอนุบาลรับสมัครกี่ขวบคะ , 2.0
# 1/1 [==============================] - 0s 30ms/step
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2.0
# 2/2 [==============================] - 0s 9ms/step
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2.0
# 2/2 [==============================] - 0s 9ms/step
# สวัสดีค่ะ สมัครป.1 ไปแล้ว แต่ไม่สามารถโอนเงินค่าสมัครได้ค่ะ
# ต้องทำอย่างไรคะ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# สวัสดีค่ะ สมัครป.1 ไปแล้ว แต่ไม่สามารถโอนเงินค่าสมัครได้ค่ะ
# ต้องทำอย่างไรคะ , 2.0
# 3/3 [==============================] - 0s 9ms/step
# สมัครป1 ep ค่ะ ค่าเทอมเท่าไหร่ค่ะ , 2.0
# 2/2 [==============================] - 0s 5ms/step
# อ.1ค่าเทอมเท่ารัยคะ , 2.0
# 1/1 [==============================] - 0s 26ms/step
# เข้าไปสมัครอนุบาลนี่ไปได้ทุกวันหรือเว้นวันหยุดราชการคะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# รูปสมัครเรียนน้องอนุบาล 1 ก็ต้องใส่ชุดนักเรียนถ่ายรูปเหรอคะ , 2.0
# 2/2 [==============================] - 0s 12ms/step
# สมัครเตรียมเตรียมอนุบาลต้องเตรียมอะไรบ้างคะ , 2.0
# 2/2 [==============================] - 0s 8ms/step
# สหกรณ์โรงเรียนเปิดไหมค่ะในช่วงนี้ , 2.0
# 2/2 [==============================] - 0s 4ms/step
# สหกรณ์โรงเรียนเปิดไหมค่ะในช่วงนี้ , 2.0
# 2/2 [==============================] - 0s 4ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี ต้องจ่ายอะไรเท่าไหร่บ้างคะ , 2.0
# 2/2 [==============================] - 0s 12ms/step
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 2.0
# 2/2 [==============================] - 0s 12ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี เท่าไหร่ครับ
# และต้องเตรียมอะไรไปบ้างครับ , 2.0
# 3/3 [==============================] - 0s 10ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี เท่าไหร่ครับ
# และต้องเตรียมอะไรไปบ้างครับ , 2.0
# 3/3 [==============================] - 0s 11ms/step
# มอบตัวต้องไปตรงไหนของ รร.คะ , 2.0
# 1/1 [==============================] - 0s 29ms/step
# เอกสารการเขียนคําร้องมีอะไรบ้างคะ , 2.0
# 1/1 [==============================] - 0s 27ms/step
# เอกสารการเขียนคําร้องต้องใช้รูปถ่ายขนาดเท่าไหร่ครับ , 2.0
# 2/2 [==============================] - 0s 14ms/step
# สอบถามหน่อยค่ะ ECP ค่าเทอมเท่าไหร่คะ  , 2.0
# 2/2 [==============================] - 0s 6ms/step
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ  , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ  , 2.0
# 2/2 [==============================] - 0s 11ms/step
# กรอกรายละเอียดใบมอบตัวได้จากที่ไหนครับ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# การทดสอบวัดระดับภาษาอังกฤษ CEFR มีค่าสมัครสอบไหมคะ , 2.0
# 2/2 [==============================] - 0s 13ms/step
# ชุดนักเรียน วันเสาร์-อาทิตย์ซื้อได้มั้ยครับ , 2.0
# 2/2 [==============================] - 0s 10ms/step
# ถ้าจะสั่งตัดชุด รด ติดต่อได้ที่ไหนคะ , 2.0
# 2/2 [==============================] - 0s 7ms/step
# ถ้าจะสั่งตัดชุด รด ติดต่อได้ที่ไหนคะ , 2.0
# 2/2 [==============================] - 0s 6ms/step
# เดือนหน้าจะมีการเปิดสอนว่ายน้ำแล้วใช่ไหมคะ , 2.0
# 2/2 [==============================] - 0s 11ms/step
# ท้องฟ้าจำลองเปิดอีกทีเมื่อไหร่เหรอครับ , 2.0
# 2/2 [==============================] - 0s 9ms/step
# สอบถามเรื่องเรียนว่ายน้ำหน่อยค่ะ , 2.0
# 1/1 [==============================] - 0s 26ms/step
# ขอสอบถามรายละเอียดการรับสมัครครูหน่อยครับ  , 2.0
# 2/2 [==============================] - 0s 9ms/step
# ราคาใบสมัครสสวทกับepกี่บาทคะ , 2.0
# 1/1 [==============================] - 0s 26ms/step
# รบกวนสอบถามค่ะ ป. English program กับ Gifted English
# ต่างกันอย่างไรคะ , 2.0
# 3/3 [==============================] - 0s 8ms/step
# ชุด นร. มีจำหน่ายไหมคะ ถ้ามีจำหน่ายวันไหน , 2.0
# 2/2 [==============================] - 0s 9ms/step
# อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ , 2.0
# 1/1 [==============================] - 0s 25ms/step
# เสียค่าสมัครสอบเท่าไหร่ค่ะ , 2.0
# 1/1 [==============================] - 0s 26ms/step
