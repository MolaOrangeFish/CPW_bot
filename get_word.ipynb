# %%
import pandas as pd

# %%
df = pd.read_excel('dataset หน่วยงานชลประธานวิทยา.xlsx')

df.drop('Unnamed: 2',
  axis='columns', inplace=True)
df.drop('Unnamed: 3',
  axis='columns', inplace=True)
df
# Out:
#                                                    txt  label
# 0    ไม่ทราบว่า ตารางเรียที่จะเรียน ออนไลน์ วันที่ ...      1
# 1                            ขอตารางเรียน ป.6 หน่อยค่ะ      1
# 2                     เรียนทักษะว่ายเด็กโตเปิดสอนไหมคะ      7
# 3               ทักษะว่ายเปิดสอนกลุ่มเด็กม.ต้นมั้ยครับ      7
# 4         ทางโรงเรียนมีเปิดรับสมัครเข้ ป. 1รอบ 2มั้ยคะ      7
# ..                                                 ...    ...
# 801      ชำระค่าเทอมในวันที่ไปซื้อหนังสือได้มั้ยครับ ?      1
# 802                                     สมุดเปิดไหมค่ะ      3
# 803                จำหน่ายหนังสือนี่รวม EP ด้วยไหมครับ      3
# 804  ม.3ดูวิชาวิทย์ชั่วโมงสรุปสายใยอาหารและแบบทดสอบ...      1
# 805                 วันนี้เข้าไปซื้อสมุดได้ถึงกี่โมงคะ      3
#
# [806 rows x 2 columns]

# %%
df = df.fillna(0)
df
# Out:
#                                                    txt  label
# 0    ไม่ทราบว่า ตารางเรียที่จะเรียน ออนไลน์ วันที่ ...      1
# 1                            ขอตารางเรียน ป.6 หน่อยค่ะ      1
# 2                     เรียนทักษะว่ายเด็กโตเปิดสอนไหมคะ      7
# 3               ทักษะว่ายเปิดสอนกลุ่มเด็กม.ต้นมั้ยครับ      7
# 4         ทางโรงเรียนมีเปิดรับสมัครเข้ ป. 1รอบ 2มั้ยคะ      7
# ..                                                 ...    ...
# 801      ชำระค่าเทอมในวันที่ไปซื้อหนังสือได้มั้ยครับ ?      1
# 802                                     สมุดเปิดไหมค่ะ      3
# 803                จำหน่ายหนังสือนี่รวม EP ด้วยไหมครับ      3
# 804  ม.3ดูวิชาวิทย์ชั่วโมงสรุปสายใยอาหารและแบบทดสอบ...      1
# 805                 วันนี้เข้าไปซื้อสมุดได้ถึงกี่โมงคะ      3
#
# [806 rows x 2 columns]

# %%
df = df.applymap(str)

# %%
df
# Out:
#                                                    txt label
# 0    ไม่ทราบว่า ตารางเรียที่จะเรียน ออนไลน์ วันที่ ...     1
# 1                            ขอตารางเรียน ป.6 หน่อยค่ะ     1
# 2                     เรียนทักษะว่ายเด็กโตเปิดสอนไหมคะ     7
# 3               ทักษะว่ายเปิดสอนกลุ่มเด็กม.ต้นมั้ยครับ     7
# 4         ทางโรงเรียนมีเปิดรับสมัครเข้ ป. 1รอบ 2มั้ยคะ     7
# ..                                                 ...   ...
# 801      ชำระค่าเทอมในวันที่ไปซื้อหนังสือได้มั้ยครับ ?     1
# 802                                     สมุดเปิดไหมค่ะ     3
# 803                จำหน่ายหนังสือนี่รวม EP ด้วยไหมครับ     3
# 804  ม.3ดูวิชาวิทย์ชั่วโมงสรุปสายใยอาหารและแบบทดสอบ...     1
# 805                 วันนี้เข้าไปซื้อสมุดได้ถึงกี่โมงคะ     3
#
# [806 rows x 2 columns]

# %%
df.to_csv("Dataset (Last).csv")

# %%
df["txt"][0]
# Out:
# 'ไม่ทราบว่า ตารางเรียที่จะเรียน ออนไลน์ วันที่ 17 นี้ ดูได้จากที่ไหนคะ'

# %%
df["label"].unique()
# Out:
# array(['1', '7', '5', '0', '3', '2', '4', '6', '8', '9'], dtype=object)

# %%
size = df.shape[0]

# %%
data1 = []

for i in range (size):
    if(i%2==0):
        data1.append(df["txt"][i])
    else:
        data1.append(df["label"][i])

# %%
data1
# Out:
# ['จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรียน ทำรถติด แทนที่จะจัดรถเข้า\nทางออกทาง ให้เข้าออกปะปนกันไปหมด',
#  '0.0',
#  'คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหายๆค่ะ มีกระตุกๆด้วย',
#  '0.0',
#  'เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ',
#  '0.0',
#  'กฎระเบียบไม่ดี เเถมยังตีเด็กอีก',
#  '0.0',
#  'ตรงประตูระวังเชือกผูกรองเท้าด้วยนะคะ อันตราย',
#  '0.0',
#  'ผึ้งจะเปิดเรียนจะไห้จ่ายค่าเทอมเลย ควรนึกถึงพ่อกับแม่บ้างนะให้ตายเถอะ',
#  '0.0',
#  'ถามไปก็ไม่เคยมาอ่านหรือตอบ แย่มาก',
#  '0.0',
#  'ควรคืนค่าเทอมห้อง EP เพราะว่าไม่ได้เรียนที่โรงเรียน เรียนที่บ้านทั้งเทอมเลย',
#  '0.0',
#  'เป็นการช่วยเหลือที่เล็กน้อยมาก ห่วยที่สุด',
#  '0.0',
#  'ในห้องน้ำควรมีทิชชู่ ยิ่งเด็ก ผญ สำคัญเรื่องความสะอาด และเด็กบางคน\nเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ',
#  '0.0',
#  'เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่\nเหมือนกัน พิจารณาแก้ไขด้วย',
#  '0.0',
#  'เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่\nเหมือนกัน พิจารณาแก้ไขด้วย',
#  '0.0',
#  'เปิดเรียนปกติครบทุกระดับชั้นแต่ถ้าทางโรงเรียนไม่ให้ผู้ปกครองนำรถ\nเข้าโรงเรียนไปส่งเด็กๆมันคงจะแย่สำหรับผู้ปกครองหลายๆคนนะค่ะ \nรบกวน รร. ลองลงมาดูลานจอดรถใหม่ตอนเช้าตอนเย็นบ้างนะค่ะว่ารถ\nมันติดแค่ไหน',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200bเพราะถ้าเปิด\nเต็มรูปแบบรถคงติดมาก',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200bเพราะถ้าเปิด\nเต็มรูปแบบรถคงติดมาก',
#  '0.0',
#  'เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน\nแน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ \n20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี\nรถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น\nมากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้\nรับความกรุณาพิจารณาด้วย',
#  '0.0',
#  'เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน\nแน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ \n20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี\nรถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น\nมากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้\nรับความกรุณาพิจารณาด้วย',
#  '0.0',
#  'ไม่เข้าใจรรคืนเงินทีไรคนบ่นกันจัง ลูกชายคนโตเรียนโครงการพิเศษของ\nรร รัฐบาล ค่าเทอมก็เกือบสองหมื่นคืนเงินมาแค่ 1380 ไม่เห็นมี ผปค\nโพสบ่นในเพจรร แต่นี่ รร เอกชนขนาดภาคปกติยังคืนเยอะกว่ารรรัฐบาล\nอีก คนบ่นกันจัง😞',
#  '0.0',
#  'อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจน และเพียงพอด้วยครับ\u200b\nตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอดก็วนไป\u200bเรื่อยๆ ลูกก็รอไปจนกลับ\nคนสุดท้ายของห้อง\u200b เกรงใจคุณครูที่รอเราคนเดียว\u200b',
#  '0.0',
#  'จัดเวลาการเรียนการสอนน้อยเร่งรัดทุกเรื่องผลการเรียนจะเป็นอย่างไรไม่รู้\nเอาแต่จะตัดระบบให้เป็นปัจุบันในการทำงานของหน่อยงานตนเอง',
#  '0.0',
#  'กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth \nด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์\nเอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก',
#  '0.0',
#  'กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth \nด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์\nเอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก',
#  '0.0',
#  'ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม \nคลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ\nวานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก\nษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา\nบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ',
#  '0.0',
#  'ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม \nคลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ\nวานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก\nษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา\nบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ',
#  '0.0',
#  'โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย\nวิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ \nยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ',
#  '0.0',
#  'โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย\nวิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ \nยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ',
#  '0.0',
#  'สรุปเลยนะคะ การเรียนออนไลน์ระดับประถม ไม่มีการปรับปรุงให้ดีขึ้น เช่น \nเสียงจากคลิป ฟังไม่รู้เรื่อง อุปกรณ์ รร ให้คุณครูลงทุนกันเองหรอคะ เสียง\nพูดได้ยินดับๆหายๆ รร ควรลงทุนอุปกรณ์ให้คุณครูนะคะ เช่น ไมค์ในการ\nอัดคลิป เรื่องภาพก็อีกเรื่องนึง แต่เรื่องเสียงนี่สำคัญที่สุด เพราะ นร. ต้อง\nฟังที่คุณครูอธิบาย กลายเป็นว่า ทำงานซ้ำซ้อน ขอให้ รร ลงทุนอุปกรณ์\nให้ครูด้วยนะคะ',
#  '0.0',
#  'คลิปค้างและกระตุกมากค่ะเป็นเกือบทุกวิชาค่ะ ตั้งแต่เช้าจนถึงตอนนี้ค่ะ \nดูไม่รู้เรื่องเลยค่ะ',
#  '0.0',
#  'vdo กระตุกมากโหลดช้ามากดูแล้วสะดุดมาก ไม่รู้เรื่องเลยในการดูแต่ละวิชา',
#  '0.0',
#  'เว็ปโรงเรียนโหลดนานมาก พอเปิดได้คลิปกระตุกดูไม่รู้เรื่องเลยค่ะ',
#  '0.0',
#  'ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง\nเรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก\nนั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม\nที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ',
#  '0.0',
#  'ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง\nเรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก\nนั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม\nที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ',
#  '0.0',
#  'ทาง รร ควรซื้อแอพ Zoom premium ให้ครูด้วยค่ะ เวลาแค่ 40 นาทีจากแอพ\nzoom ฟรี มันไม่พอ ในกรณีสอนสดกว่าจะรอให้นักเรียนมาครบกินเวลาไปกว่า 10 \nนาทีเลย เผื่อเวลาเน็ตหลุดด้วย เสียเวลามากเรียนก็ไม่ต่อเนื่อง ไม่เต็มที่ ยิ่งเด็ก \nม.ปลายนี่ไม่ต้องพูดถึงเลย เด็กๆบ่นกันเยอะมากค่ะ',
#  '0.0',
#  'ขอโทษนะคะกดเข้าไปในวีดีโอเปิดไม่ได้ค่ะเปิดติดบ้างไม่ติดบ้างค่ะ ช่วยแก้ไข\nหน่อยค่ะ เป็นแบบนี้บ่อยๆไม่ไหวนะคะ',
#  '0.0',
#  'ช่วยแก้ไขหน่อยนะคะ เปิดไม่ได้เลยคะ ลองใช้ทั้ง WiFi และ 5G ก็เปิดไม่ได้คะ \nเปิดติดบ้างไม่ติดบ้าง เซ็งคะ',
#  '0.0',
#  'จัดซัมเมอรไปเลยคะ ดิฉันไม่ให้ลูกไปเรียนแน่นอน ถือว่าทำบุญให้ รร. คะอันตราย\nขนาดนี้ ยังคิดจะจัดสอนซัมเมอร์อีก โควิดวันนี้ คนติดเพิ่มอีกเป็นพันคน เด็กๆติดมา \nถึงหายก็ปอดหายไปครึ่งนึง อนาคตสุขภาพเด็กคงแย่',
#  '0.0',
#  'ช่วยดูด้วยค่ะวาาเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหนพลาดโอกาสหลายอย่างยัง\nต้องพลาดที่เรียนอีก',
#  '0.0',
#  'ทางโรงเรียน\u200b จะต้องเร่งแก้ไขให้นะคะ\u200b ไม่ใช่ให้เด็กนักเรียน\u200bหรือ\u200b ผู้ปกครอง\u200b จะต้อง\nเป็นคนประสานเองนะคะ\u200b เพราะได้แจ้งรายละเอียด\u200b และ\u200b ปัญหา\u200b ไว้ให้พิจารณา\nหมดแล้ว\u200b ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ***',
#  '0.0',
#  'ห้องน้ำนักเรียนอาคาร 8 อับชื้นและสกปรกมาก รบกวนตรวจด้วยนะคะ',
#  '0.0',
#  'รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้แล้วนะคะ...',
#  '0.0',
#  'กระตุกมากค่หยุดๆะ เล่นๆ ตลอดเลยค่ะ  เสียอารมณ์ค่ะ',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน ห่วยมาก',
#  '0.0',
#  'กระตุกบ่อย\u200b file ค้างมากๆๆเลยค่ะ\u200b 😅😅 เด็ก\u200bเดินหนีไปแล้วค่ะ',
#  '0.0',
#  'กระตุกทุกคลิปเลย เรียนไม่ได้เลยค่ะ แย่ที่สุด',
#  '0.0',
#  'เข้าดูไม่ได้เลยครับ ทั้งกระตุกทั้งค้างครับ 😞',
#  '0.0',
#  'กระตุกๆ ค้างๆ กว่าจะผ่านไปแต่ละวิชาใช้เวลานานมาก แย่มาก',
#  '0.0',
#  'กระตุกสะดุดตลอด ทุกวิชา ไม่สามารถเรียนได้เลยแบบนี้เด็กก็แย่สิคับ',
#  '0.0',
#  'ป.2 ป.4 เปิดเข้าดู VDO ไม่ได้เลยค่ะ ไม่ไหวนะคะแบบนี้',
#  '0.0',
#  'ยังกระตุกอยู่เลยค่ะเรียนไม่ได้เลยค่ะ เสียเวลามากค่ะ',
#  '0.0',
#  'กระตุกทุกlink. ห่วยคะ',
#  '0.0',
#  'ควบคุมการผลิตให้ดี เพิ่มโปรตีนด้วยนะครับ ไม่ใช่มีแต่ผักกับผลไม้ ห่วยมากก',
#  '0.0',
#  'เมนูก๋วยเตี๋ยวน้องผมบ่นว่ากินแต่หมี่ๆอย่างเดียว 😅',
#  '0.0',
#  'วันนี้ก็มีน้ำซุปฟักลูกบอกว่าจืดอย่างกะน้ำเปล่าเลยค่ะ ปรับปรุงด้วยค่ะ 😂😂😂',
#  '0.0',
#  'ติดป้ายลดความเร็วเพิ่มเติมน่าจะดีนะคะ ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่เพียบ',
#  '0.0',
#  'เส้นใหญ่ กะทิ เป็นสิ่งที่เสียง่าย ควรหลีกเลี่ยง มาทำอาหารให้เด็กๆ วันนี้เด็ก \nปวดท้อง ท้องเสีย หลายคนคะ',
#  '0.0',
#  'เด็กๆ บอกข้าวแข็งค่ะ เมื่อวาน',
#  '0.0',
#  'เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ',
#  '0.0',
#  'หวังว่าเปิดเทอมนี้จะได้ฟังจากลูกเรื่องรสชาติและปริมาณที่เหมาะสมนะคะ',
#  '0.0',
#  'เพิ่มปริมาณอาหารให้พอกับความต้องการด่วนเลยค่ะ ห่วยตั้งแต่เปิดเทอม!!',
#  '0.0',
#  'ผมสงสารเด็ก รร. นี้มากคือ หนึ่งเลยนะ โรงอาหาร คือเเบบว่ามันเเน่นมากๆเลยครับ',
#  '0.0',
#  'ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการ\nอาหารค่ะ',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก ควรแก้ไขนะคะ',
#  '0.0',
#  'ควรพิจารณาที่จอดรถได้แล้วนะครับ',
#  '0.0',
#  'ลานจอดใหม่ ฝุ่น เยอะมาก',
#  '0.0',
#  'เมนูกระเพราหมูวันอังคารที่ผ่านมาช่วยลดความเผ็ดลงด้วยคะ',
#  '0.0',
#  'รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ...',
#  '0.0',
#  'ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่น และดินออกบ้างน่าจะดีนะคะ ',
#  '0.0',
#  'ไม่ต้องใส่พริกน่าจะดีกว่านะคะ เด็กประถมไม่ได้ทานเผ็ดได้ทุกคนค่ะ',
#  '0.0',
#  'ทำอาหารที่เด็กทานได้ง่ายกว่านี้ค่ะ เมนูแกงสำหรับเด็กประถมยังไม่เห็นด้วยค่ะ',
#  '0.0',
#  'เช็คสหกรณ์ด้วยนะคะ หน้ากากอนามัยแพงมากค่ะ',
#  '0.0',
#  'รับทราบปัญหาบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆค่ะ',
#  '0.0',
#  'พิจารณาเรื่องความสะอาดให้เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร',
#  '0.0',
#  'กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะ',
#  '0.0',
#  'กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะแล้วก็ควรจะทำให้อาหารมีรสชาติ\nมากกว่านี้',
#  '0.0',
#  'วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด \nควรทำตามตารางนะ',
#  '0.0',
#  'ส่วนใหญ่\u200bมีแต่ของทอด ไส้กรอก ลูกชิ้น ฝากให้พิจารณา\u200bอาหารที่มีประโยชน์\u200bให้\nเด็กด้วยค่ะ',
#  '0.0',
#  'ไม่ให้รถเข้าออก แบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน',
#  '0.0',
#  'เมนูอาหารวันเสาร์ เป็นเมนูไก่ทอด เป็นอย่างอื่นบ้างก้อดีน่ะค่ะ เด็กๆ บ่นว่า \nไก่ทอดทุกเสาร์เลย',
#  '0.0',
#  'น่าจะมีมีพื้นที่พักคอยให้กับญาติ ๆ หน่อยนะค่ะ เพราะว่ารอกว่าจะสอบเสร็จก็ไม่รู้\nว่าจะเอาตัวไปอยู่ที่ไหน',
#  '0.0',
#  'กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ\nพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด\nท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้\nเด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร',
#  '0.0',
#  'กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ\nพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด\nท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้\nเด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร',
#  '0.0',
#  'ขอร้องเรียนเรื่องครูประถมหน่อยค่ะ ครู ***** ***** ตีนักเรียนเพียงเพราะนักเรียน\nไม่ยอมใส่ถุงเท้าเข้าห้องเรียน ที่จริงแล้วน้องรองเท้าเปียกมาเพราะเข้าห้องน้ำมา\nอยากให้ครูท่านนีได้รับคำตักเตือนหน่อยค่ะ',
#  '0.0',
#  'รายการอาหารวันเรียนพิเศษวันเสาร์ ไม่น่ามีคะเมนูผัดมาม่า ไม่โอเคคะ จากเส้น\nมาม่าเป็นเส้นก๋วยเตี๋ยวน่าจะดีกว่านะคะ.',
#  '0.0',
#  'ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะคะ \nลดฝุ่นละออง',
#  '0.0',
#  'ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถ เด็ก ๆ เปิดหน้าต่างห้องเรียนรับลม แต่เวลารถขับ\nผ่านฝุ่นปูนปลิวอย่างเห็นได้ชัด',
#  '0.0',
#  'ช่วยมาวัดค่าอาคาร สอง อาคารสี่ อยู่ติดกับลานจอดใหม่ ฝุ่น เยอะมาก ผบรห \nลองมานั่งเรียนกับเด็กๆหน่อย',
#  '0.0',
#  'หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆเดินก็ไกลต้องมากลัวฝุ่นอีก \nปอดไม่พังตอนนี้ก็ไม่รู้จะว่าอย่างไง วอนท่านผู้บริหารลงมาเดินดินแก้ปัญหาให้\nเด็กๆด้วยเถอะ หรือพวกท่านและคณะไม่เดือดร้อนเพราะท่านใช้อภิสิทธ์ชนจอด\nใน รร ได้หรือครับ',
#  '0.0',
#  'กับข้าวเด็กเผ็ดนะคะ (ของอิสลามค่ะ) ลูกๆ ทานตั้งแต่อนุบาล ตอนนี้ประถมแล้ว \nยังไม่ปรับปรุงเลยค่ะ',
#  '0.0',
#  'ฝากพิจารณารถตู้รับส่งนักเรียนด้วย นั่งกันแน่นมากๆเลย รู้สึกกังวลครับ',
#  '0.0',
#  'หนังสือเรียน 10 วิชาหนักมากค่ะลูกแบดไม่ไหวค่ะ บ่นปวดหลัง เดินก็ไกล \nขึ้นสะพานลอยก็จะหงายหลังตกสะพาน สงสารเด็ก',
#  '0.0',
#  'ผลไม้ที่ให้เด็กทานพวกเงาะเด็กไม่ทานกันเลยค่ะ อีกอย่างปลอกกันไม่เป็นใช้ปาก\nกัด อันตรายนะคะ ยาฆ่าแมลงทั้งนั้น',
#  '0.0',
#  'ช่วยพิจารณาเรื่องการส่งงานส่งเป็นรายอาทิตย์หรืออย่างไรก็ได้ที่ทางคุณครูสะดวก \nไม่ใช่แค่มีคลิปแล้วเรียนบอกว่าเรียนจบแล้ว',
#  '0.0',
#  'ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่\u200bมีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนม\nที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ และสังเกต\u200bว่าเทอมนี้ผลไม้ไม่มีขาย\nแล้ว ฝากให้พิจารณา\u200bอาหารที่มีประโยชน์\u200bให้เด็กด้วยค่ะ',
#  '0.0',
#  'ขออนุญาตนะคะ อาหารเด็กกลางวัน ป.1ถึง ป.6อาหารเหมือนกันหมด ควรแบ่งตาม\nความเหมาะสมเด็กเล็ก และเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ ลูกชาย\nคนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่า\nไม่อร่อยและกินไม่ได้เลยค่ะถึงจะเป็นเด็กแต่ก็มีหัวใจนะคะ ขอให้กินได้ก็พอค่ะ\nอาหารจะมีคุณภาพเราต้องใส่ใจในทุกรายละเอียดและทุกๆอย่างค่ะ ขอบคุณค่ะ',
#  '0.0',
#  'แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่าเพราะบางทีได้ไก่จ่อ 2 ชิ้น ไส้\nกรอก 2 ชิ้น ไข่ต้มกินไม่เป็นกินไข่ขาวนิดหน่อย สงสารลูกให้ห่อข้าวก็ไม่ยอม\nกลัวไม่เหมือนเพื่อน เราเสียเงินเพิ่มก็ได้นะ ขอให้ดีกว่านี้ ระวังผู้ปกครองทนไม่\nไหวแอบถ่ายออกสื่อจะดังเหมือน รร.อื่นๆนะคะ อายญาติพี่น้องว่าเราส่งลูกมา\nเรียน ที่นี่ได้งัย',
#  '0.0',
#  'ทางโรงเรียน\u200b จะต้องเร่งแก้ไขให้นะคะ\u200b ไม่ใช่ให้เด็กนักเรียน\u200bหรือ\u200b ผู้ปกครอง\u200b จะต้อง\nเป็นคนประสานเองนะคะ\u200b เพราะได้แจ้งรายละเอียด\u200b และ\u200b ปัญหา\u200b ไว้ให้พิจารณา\nหมดแล้ว\u200b ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ***',
#  '0.0',
#  'อยากจะให้ทาง รร. เพิ่มเมนูหรือเพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่า\nได้ทานหมูก้อน 1ก้อนกับซุป น้อยไปนะคะ กับมาตรฐาน กับรร.ระดับนี้ ไม่ไหวๆ',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน',
#  '0.0',
#  'เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวันไม่ดี',
#  '0.0',
#  'เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่เหมือนกัน พิจารณาแก้ไขด้วย',
#  '0.0',
#  'ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ. ลองให้รถครูจอดข้างนอกแล้วเดินลุยฝนมาบ้าง',
#  '0.0',
#  'เมนูแกงสำหรับเด็กประถมยังไม่ควร ยังทานยากไป',
#  '0.0',
#  'เรียนปกติแล้วทำไมให้รถเข้าออกได้ปกติทุกคนมีความป้องกันตัวเองอยู่แล้วแบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200b เพราะถ้าเปิดเต็มรูปแบบรถคงติดมาก',
#  '0.0',
#  'นี่คือความคิดของคนภายนอกและนี่ก็คือผลงานของทางโรงเรียนทำให้คนข้างนอกเข้าใจ ผปค. ผิดจะทำยังไงก็รีบๆ ทำเถอะค่ะ ซึ่งมันไม่ใช่ความผิดของ\n ผปค. เลยนะคะ',
#  '0.0',
#  'ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่นมากสังเกตุมาหลายอาทิต\nแล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้รับความกรุณาพิจารณาด้วย',
#  '0.0',
#  'เปิดประตู3 ไม่ได้ช่วยอะไรเลย โรงเรียนจะต้องเปิด ประตู 4และ ประตู 5 เพื่อช่วยระบายรถ ที่ลานจอดรถ ในช่วงเช้า 6.00 - 8.30 น. พิจารณาแก้ไขด้วย',
#  '0.0',
#  'อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ\u200b ตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอดก็วนไป\u200bเรื่อยๆ\n ลูกก็รอไปจนกลับคนสุดท้ายของห้อง\u200b เกรงใจคุณครูที่รอเราคนเดียว\u200b',
#  '0.0',
#  'แต่ของลูกเป็นการตักรอบแรกนะคะ ถ้ามันไม่พอแสดงว่าไม่มีใครได้รอบสองแน่นอน \nช่วยพิจารณาหน่อยนะคะว่าเป็นการตักรอบแรกค่ะ',
#  '0.0',
#  'ประกาศผลสอบช้ามากจังค่ะ แต่ตังก็จะให้จ่ายก่อน งง ใจค่ะ',
#  '0.0',
#  'วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด แย่มาก',
#  '0.0',
#  'ได้ใบเกรดและใบจบช้าคะรร.อื่นเขาแจกกันตั้งแต่เดือนที่แล้ว แล้วนี่ยังคิดGPAของแต่ละกลุ่มสาระไม่เสร็จทำไมถึงทำงานช้ากันแบบนี้คะถ้านร.\nกรอกแก้ไขข้อมูลไม่ทันทำให้มีผลไม่ติดมหาลัยล่ะคะจะรับผิดชอบยังไง ทำไมถึงประกาศในcpw classroomก่อนไม่ได้คะ ห่วยสิ้นดี',
#  '0.0',
#  'แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่า',
#  '0.0',
#  'ขออนุญาตนะคะอาหารเด็กกลางวันป.1ถึงป.6อาหารเหมือนกันหมด ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ',
#  '0.0',
#  'ได้รับข้อมูลแล้ว กรุณานำไปพิจารณาด้วยนะครับไม่ใช่ขอบคุณอย่างเดียวครับ',
#  '0.0',
#  'ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่\u200bมีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนมที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ',
#  '0.0',
#  'เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ',
#  '0.0',
#  'เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ',
#  '0.0',
#  'อีกเรื่องห้องน้ำสกปรกมากๆๆครับ ร่วมถึงน้ำดื่มอีกก็ไม่เคยตรวจสอบเลยครับ จนเดียวนี้เด็กๆถึงไม่อยากเข้าห้องน้ำกับดื่มน้ำที่โรงเรียนแล้วครับ',
#  '0.0',
#  'ทางโรงเรียนเลือกตอบแค่บางคำถามหรอครับ เห็นคำถามไหนเกี่ยวกับโปรแกรม ซูม ทางโรงเรียนไม่เข้ามาตอบเลย แย่มากครับ',
#  '0.0',
#  'ไม่คิดจะคืนค่าอาหารเลยหรอค่ะ',
#  '0.0',
#  'ทางผู้ปกครองไม่สะดวกใจให้นักเรียนไปค่ายพุทธบุตรเเล้วค่ะ',
#  '0.0',
#  'โรงเรียนคะ อยากให้แก้ชื่อให้หน่อยค่ะ โพสต์ล่าสุดอ่ะค่ะพิจารณาแก้ไขด้วย',
#  '0.0',
#  'ที่จอดรถไม่น่าจะพอนะคะ\u200b ควรพิจารณาเรื่องการจอดรถอีกที\u200b \u200b',
#  '0.0',
#  'รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ...',
#  '0.0',
#  'รบกวนออกมาชี้แจ้งด้วยค่ะ',
#  '0.0',
#  'ตรงลานจอดที่ยังเป็นดิน เด็กเดินอยู่ ขับเบาๆหน่อยนะครับ ฝุ่นมันเยอะ',
#  '0.0',
#  'เพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่าได้ทานหมูก้อน 1ก้อนกับซุป \nน้อยไปนะคะ ไม่ไหวๆ',
#  '0.0',
#  'กระตุกมากค่ะ เล่นๆหยุดๆ ตลอดเลยค่ะ',
#  '0.0',
#  'กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน',
#  '0.0',
#  'กระตุกทุกlink. ห่วยคะ',
#  '0.0',
#  'แย่มากกกกกกค่ะ',
#  '0.0',
#  'รสชาติอาหารแย่มาก ไม่ไหวจะเคลียร์',
#  '0.0',
#  'ใช้เดือนเดียวพังแย่ๆมากๆ',
#  '0.0',
#  'ปรับปรุงด่วน!!!! ',
#  '0.0',
#  'เสียเวลามากๆ กว่าจะทำเรื่องคืนเงินได้ ',
#  '0.0',
#  'เสียความรู้สึกค่ะ',
#  '0.0',
#  'ไม่ไหวๆเลย',
#  '0.0',
#  'ถ้าเพิ่มร้านอิสลามก็ดีนะครับ',
#  '0.0',
#  'วันนี้ล่มอีกแล้วนะคะ เติมเงินผ่านแอพไม่ได้ค่ะ',
#  '0.0',
#  'ห้องปกติคืนนิดเดียว อย่าคืนเลยค่าเน็ตยังไม่พอเลย\nช่วยเหลือ มันต้องทุกระดับชั้นทุกคน ไม่ใช่บางกรณี ห่วยมากค่ะ',
#  '0.0',
#  'จะใช้แค่มาตราการเบื้องต้น แล้วยะงเมื่อ วันอังคารที่ผ่านมาทางโรงเรียนยังจัด\nให้มีงานปัจฉิมนิเทศ อีกซึ่งเพิ่มความเสี่ยงในการติดเชื้อขึ้นไปอีก ถ้าโควิท19 \nระบาดในเด็กน่ากลัวมากนะค่ะ อันตรายต่อเด็กๆ',
#  '0.0',
#  'รร.ควรน่าจะป้องกันโดยการห้ามเด็ก นร.ที่มีบ้านอยู่ในเขตเสี่ยงงดการเรียน\nและให้เรียนออนไลน์เป็นกลุ่มพิเศษไปเพื่อเป็นการป้องกันตั้งแต่ต้น',
#  '0.0',
#  'โรงอาหาร รร กินจนเบื่อละ',
#  '0.0',
#  'ควรมีดื่มน้ำสะอาดๆ ที่กินอยู๋ตอนนี้เด็กบอกรสชาติแปลกๆ ไม่ไหวนะคะแบบนี้',
#  '0.0',
#  'พอคนเยอะไป อาจารย์ที่อยู่ริมก็ตัวขาด เพราะ Greenscreen ไม่กว้างพอครับ',
#  '0.0',
#  'ระยะภาพ มีผลต่อความรู้สึกของผู้ฟังนะครับ แนะนำใช้ Close up \nตอน ผอ.พูดบางก็ดีครับ ตอนนี้มันกว้างและแช่เกินไป',
#  '0.0',
#  'น่าจะให้ ม.ต้น ม.ปลาย สลับกันไปเรียนนะคะ',
#  '0.0',
#  'แล้วเรื่องค่าชุดละคะยังไม่เห็นได้เลย จะจบเทอมแรกแล้ว',
#  '0.0',
#  'คิวอาร์โค้ดเล็กมาก แตกด้วยแสกนไม่ได้ค่ะ',
#  '0.0',
#  'ปิดต่อไปเด็กก็งงกับการเรียน แต่ถ้าเปิดก็เสี่ยง 😰😰',
#  '0.0',
#  'โรงเเรียนควรมีนโยบายเรียนวันคู่วันคี่ค่ะ เด็กๆจะได้ไม่อันตรายต่อการเสี่ยง',
#  '0.0',
#  'ลูกเข้าห้องเรียนออนไลน์ไม่ได้ ตัวลิ้งทำไมไม่เตรียมให้พร้อมก่อน',
#  '0.0',
#  'ร้อนกะร้อนน ฝุ่นกะเยอะะ โอ๊ยยยฟรุ๊ดฟริ๊ดดโว้ยยย',
#  '0.0',
#  'น่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะ',
#  '0.0',
#  'ตอนนี้ควรบริหารจัดการ เรื่องการจราจรก่อนนะครับ ช่วงเย็นรถติดขนาดไหน\nลองออกมายืนดูบ้างครับ ติดยาวไปยันปากเกร็ด',
#  '0.0',
#  'ที่รถมันติดหนักทุกวันนี้ก็เพราะแก้ปัญหาด้วยวิธีง่อยๆแบบนี้แหละค่ะ แย่มาก',
#  '0.0',
#  'คิดราคาค่าเทอม ep..แพงกว่าธรรมดา',
#  '0.0',
#  'ที่ผ่านมาทางโรงเรียนตัดสินใจเองหมด ควรมีทางแก้ไขที่ดีกว่านี้ครับ',
#  '0.0',
#  'ควรให้เด็กเดินเข้าไปได้ก็ดีนะครับ เพราะช่วยลดเวลาไปถึงประตู 1 \nหรือลานจอดรถไปได้หลายสิบนาทีเลย',
#  '0.0',
#  'กลายเป็นว่าทุกวันนี้มีทางเดียวที่ต้องใช้ รร.คิดว่ารถกี่พันคันที่ต้องใช้ทางนี้ ห่วย!',
#  '0.0',
#  'ควรให้วนเหมือนเดิมนะคะ',
#  '0.0',
#  'ห้องน้ำสกปรกมาก รบกวนตรวจด้วยนะคะ',
#  '0.0',
#  'ทุกวันนี้รถติดกระทบยาวเลยค่ะ ควรแก้ปัญหาจุดนี้ได้แล้ว',
#  '0.0',
#  'ปัญญาอ่อนมาก ขนาดฝนตกลงมาแล้ว บอกต้องรอคำสั่งๆ',
#  '0.0',
#  'การจราจรอัมพาตมาก หางแถวยาวทุกเส้นทาง รร.ควรพิจารณานะคะ',
#  '0.0',
#  'ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น ควรมองปัญหาตรงนี้ได้แล้ว',
#  '0.0',
#  'ตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอดก็วนไป\u200bเรื่อยๆ',
#  '0.0',
#  'รปภ.ต้องเข้มงวดบ้างนะคะ เพราะหลายๆคนบ่นว่าโรงเรียนทำให้รถติด',
#  '0.0',
#  'ควรห้ามรถทุกชนิด เข้า รร. เลยดีที่สุดรวมทั้ง ครูด้วย จบ',
#  '0.0',
#  'ปีหน้าถ้ายังบริหารแย่แบบนี้อีก\u200b ผมว่าจะให้ลูกย้ายโรงเรียนดีกว่า',
#  '0.0',
#  'อย่าเอาแต่นั่งห้องแอร์\u200b ผู้ปกครองทุกคนเค้าเบื่อพวกท่านเต็มทนแล้วครับ',
#  '0.0',
#  'ปัญหาทุกๆปัญหา มีทางแก้ มีทางออก ยอมรับฟังเสียงขอ ผปค บ้าง \nไม่ใช่ เอาแต่หาเงินเข้า รร',
#  '0.0',
#  'ปัญหามันไม่ได้เกิดกับผู้ปกครองหรอกคะ ปัญหามันเกิดจากการที่พวกท่านๆ\nเพิกเฉยและเอาเปรียบมากกว่า',
#  '0.0',
#  'ให้คุณครู และอาจารณ์. เชิญออกมาจอดรถที่ลานจอดด้วยนะค่ะ วันไหนที่ฝนตก\nทั้งตอนเช้าและตอนเย็นจะได้รับรู้ถึงปัญหาของ ผปค.และนักเรียน',
#  '0.0',
#  'รบกวนเปิดตั้งแต่16.00 เหมือนเดิมค่ะ ส่วนรถผู้ปกครองที่เห็นแก่ตัว ล็อคล้อ \nจ่ายค่าเสียหายไปเลยค่ะ ไม่งั้นรถจะสา',
#  '0.0',
#  'ความเห็นแก่ตัวของคนส่วนน้อย ทำให้คนส่วนใหญ่ที่เคารพกติกาต้องมีปัญหา\nเมื่อผู้ใหญ่ยังไม่รู้จักกฏกติกา แล้วจะเอาอะไรไปสอนลูกสอนหลานล่ะ',
#  '0.0',
#  'ควรหาทางแก้ปัญหาให้ดีกว่านี้นะ เมื่อวานผมติดอยู่ในลานจอดรถ \nเกือบ 2 ชั่วโมง ผมอยู่แถวนี้มา 10 ปี ไม่เคยเจอรถติดขนาดนี้ ',
#  '0.0',
#  'ลูกชายคนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่าไม่อร่อยและกินไม่ได้เลยค่ะ',
#  '0.0',
#  'ที่ผมเลือกให้ลูกมาเรียนเอกชนสู้กับค่าเทอมที่ค่อนข้างสูง เพื่อการศึกษา\nและสภาพแวดล้อมที่ดี แต่สิ่งที่เจอตอนนี้มันไม่คุ้มค่ากับค่าใช้จ่ายที่เผมต้องเสีย',
#  '0.0',
#  'การที่ไม่แก้ปัญหา ปัญหามันจะไม่จบเมื่อมันสะสมมากๆ มันลุกลามบานปลายนะคับ',
#  '0.0',
#  'ขออนุญาตนะคะ คือตอนนี้ดิฉัน (และเชื่อว่าอีกหลายๆคน) ได้รับผลกระทบในช่วงเช้าเป็นอย่างมาก จากการจราจรที่ติดขัดในการเปิดการเรียนการสอนแบบเต็มระบบ ',
#  '0.0',
#  'ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ',
#  '0.0',
#  'ควรแก้ให้เปิดประตูทุกด้านเพราะตอนเช้ามันติดหนักมากหน้ารร.เพราะการป้องกัน\nแค่นี้ไม่ช่วยอะไรเลย',
#  '0.0',
#  'การจราจรอัมพาตมาก หางแถวยาวทุกเส้นทาง พอผ่านหน้ารร.ได้เท่านั้นแหละ โล่งเชียว รร.ควรพิจารณานะคะ ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น',
#  '0.0',
#  'แล้วคนที่ไม่ได้เรียนเสริม ก็ต้องลำบากเหมือนเดิมใช่ไหม ต้องรอเข้าประตู 5 เวลา\n17.00 น.มันใช่ไหมทุกวันนี้กว่าจะมาถึง รร.ก็เสียเวลามากพอแล้วเห็นใจกันบ้างนะ',
#  '0.0',
#  'ควรตั้งกรวยบังคับให้ออกประตู4ทางเดียวนะคะ ให้ยามมาโบกเหมือนเดิม เพราะ \nผปค.จำเป็นต้องออกประตู4ตอน4โมงอะคะ ',
#  '0.0',
#  'โรงเรียนไม่สมควรทำเป็นอย่างยิ่งค่ะ การที่มีรถแอบเข้าไปจอดควรจัดการปัญหา\nให้ รปภ. และเจ้าหน้าที่ตรวจสอบอย่างเข้มข้น เพราะมันจะกระทบกับผู้ปกครอง\nจำนวนมากค่ะ',
#  '0.0',
#  'ผู้ปกครองทำผิดกฎ 1 ท่านแต่ทางโรงเรียนตัดสินทุกท่าน\u200b ปัญหารถตืดเป็นชั่วโมง\nรอบโรงเรียนมีวิธีแก้ไม่ควรปล่อยเป็นภาระผู้ปกครองต่อไป',
#  '0.0',
#  'ผลงานที่ยอดแย่ 8:32 ผู้ปกครองยังวุ่นวายวนจอดรถเพื่อเดินไปส่งลูก สุดยอดมัยคะ รถติดแออัดสะสมยันสะพานพระราม4จร้า',
#  '0.0',
#  'ณ.เวลานี้วันนี้ รร.เปิดทุกระดับชั้นเพราะวันที่ 8-9 กย รร ยังมีการสอบนักเรียน\nม.ปลายกับ ม.ต้นยังสลับกันมาก็ยังไม่เต็มรูปแบบ แต่วันนี้รถติดมากเป็นผลมาจาก \nรร.ชลประทานเปิดเรียนเต็มทุกระดับชั้นต้องพิจารณานะคะว่าควรจะทำยังไง',
#  '0.0',
#  'ขณะนี้เวลานี้ยังติดกันอยู่ในลานจอดรถแบบขยับไม่ได้เลย เสียเวลามากมาย',
#  '0.0',
#  'รบกวนทาง รร. ใส่ใจปัญหานี้ก่อนจะลามไปเรื่องอื่นค่ะ ควรปรับปรุงแนวทางการ\nจราจรใน รร. ถ้ามันไม่เวิร์ค ก็ปรับปรุง ',
#  '0.0',
#  'แย่มาก\nบ้านอยู่แค่ใน ซ. รร.อัมพรไพศาลออกบ้าน 6.00 น. จะส่งลูกให้ทันเรียนเสริมเช้า 7.30 น.ยังสาย',
#  '0.0',
#  'ตอนเย็นก็มี ผปค เห็นแก่ตัวจอดรถปิดหน้ารถที่จอดในช่อง แล้วไม่ใส่เกียร์ว่าง\nเราต้องรอนานมากกว่านางจะมา แล้วจอดกัน2ด้านเลย รถที่วิ่งออกไปลำบากมาก ',
#  '0.0',
#  'เกินไปแล้ว ค่าเทอมขึ้นตลอดโต๊ะเรียนปรับปรุงหน่อยคะเก่ามาก',
#  '0.0',
#  'ไม่ต้องอ้างฝุ่นเพาะตึกเรียนข้างลานจอดรถใหม่เด็กกินฝุ่นเข้าไปเต็มๆ',
#  '0.0',
#  'ห้องเรียน ห้องนำ้ ภาชนะที่ใส่อาหารเด็ก ผู้บริหารควรจะมาดูแลเอาใจใส่เรื่องนี้มั่งนะคะ. ยอดแย่ลงทุกวันคะ.',
#  '0.0',
#  'ควรจะเปิดให้รถผู้ปกครองเข้าไปรับส่งเด็กได้นะคะ',
#  '0.0',
#  'ตอนนี้เดือดร้อนมาก ลูกเรียนอนุบาล 2 กับ ป.1 วนรถกว่าหาที่จอด \nเข้าไปส่งใน รร.ได้ เสียเวลาเป็นชั่วโมง',
#  '0.0',
#  'รร.ปรับปรุงเรื่องที่จอดรถไม่ใช่ว่าจะทำให้เหตุการณ์รถติดดีขึ้น ที่ไม่โวยวาย\nเพราะต้องทน ถ้ายังเป็นอยู่อย่างนี้',
#  '0.0',
#  'รถติดมากคะไม่สมควรปิดประตู4ติดทั้งเช้าเย็นไม่เฉพาะแต่ผู้ปกครองรถทั่วไปก็พลอยติดไปด้วยเพราะไม่มีทางระบายรถผู้บริหารควรมาดูความเป็นจริงบางนะคะแย่มากช่วงนี้',
#  '0.0',
#  'ลานจอดรถก็ไม่เพียงพอ พิจารณาแก้ไขด้วย !!',
#  '0.0',
#  'ทาง รร. ควรทำมาตรการเด็ดขาดไปเลยค่ะว่าไม่ให้จอด ให้ขับรับแล้วออกเลย',
#  '0.0',
#  'สงสารเด็กๆที่ต้องเดินไกล และผู้ปกครองในตอนเช้าก็ต้องรีบไปทำงานด้วยค่ะ',
#  '0.0',
#  'ถ้าทุกคนปฎิบัติตามกฎและระเบียบที่ทางโรงเรียนวางไว้ก็คงไม่วุ่นวายมากแบบนี้\nแต่มีคนบางกลุ่มที่เห็นแก่ตัว และเห็นแก่ความสะดวกสบายของตัวเอง ทำให้เกิด\nความวุ่นวายและยุ่งยากแบบนี้...เห็นหลายรอบแล้ว ',
#  '0.0',
#  'ควรจัดยาม รร.มาโบกรถที่ซอยต้นสนหลัง รร.หน่อยค่ะ รถติดแย่งกันไปแย่งกัน\nมาทำให้ไปทำงานไป รร.ไม่ทันค่ะ',
#  '0.0',
#  'ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ การเห็นแก่ตัวของคนส่วนน้อย แต่สร้างปัญหาให้คนส่วนมาก อันนี้ไม่ถูกต้องนะครับ ',
#  '0.0',
#  'ไม่ควรทำเป็นอย่างยิ่งครับ รร. กรุณาพิจารณาประกาศนี้ใหม่ด้วยครับ การเห็นแก่ตัวของคนส่วนน้อย แต่สร้างปัญหาให้คนส่วนมาก อันนี้ไม่ถูกต้องนะครับ ',
#  '0.0',
#  'ฝากพิจารณารถตู้ รับ-ส่ง นักเรียนด้วยนะครับ พอเริ่มเรียนเต็ม รถตู้แน่นมากๆนะครับ ',
#  '0.0',
#  'รถติดทั้งเช้าทั้งเย็น รร ควรเปลี่ยนวิธีและรีบแก้ไขคะ',
#  '0.0',
#  'การจราจรหน้ารร.ติดขัดไปไกล ควรเกรงใจผู้ใช้ถนนคนอื่นด้วยค่ะ',
#  '0.0',
#  'มีปัญญาแก้ไขปัญหาเพียงแค่นี้แล้วจะไปสอนอะไรเด็กๆ',
#  '0.0',
#  'ทุกวันนี้ก็ติดโครตๆแล้ว ไม่เห็นมีการพัฒนาเลย',
#  '0.0',
#  'เมื่อวานลูกเปียกมาเลยคะนั่งหนาวในรถตู้กว่าจะถึงบ้าน\u200b เค้ามีร่มมีเสื้อกันฝนแต่\nเด็กน้อยยังไงก็มีเปียกคะ\u200b วันหนัยไปรับเองก็วนรถจนท้อคะ\u200b ปรับปรุงหน่อยนะคะ',
#  '0.0',
#  'ไม่เข้าใจแค่ให้ขับรถวนเข้าไปส่งนักเรียนแค่นี้มันจะแย่อะไรนักหนา ดูข้างหน้า \nรร รถติดมาก',
#  '0.0',
#  'ติดหนักมากคะด้านนอก แบบนี้ไม่ไหวนะคะ ติดเช้า/เย็นเห็นใจ ผปค.บ้างคะ',
#  '0.0',
#  'ควรปรับปรุงแก้ไข้อลุ้มอร่วยบ้างกรณีฝนฟ้าตก ฝากไว้ให้คิดด้วยคับ',
#  '0.0',
#  'เจอปัญหารถติด ก็พอทน แต่น้ำท่วมในรร.ขนาดนี้ บอกเลยว่าขอบาย สงสารลูก \nหากต้องเดินลุยน้ำเรียน ไม่ไหวจริงๆ',
#  '0.0',
#  'คิดได้แย่มากให้รถเข้าออกทางเดียว รถทางตรงเขาก็ไปไม่ได้ ติดรถ ผปค. รอเลี้ยวเขาซอยข้างสนามกอล์ฟ แทนที่จะเปิดอีกประตูด้านวัด ให้เข้าออกได้อีกทาง\n',
#  '0.0',
#  'ที่จอดรถที่ทำอยู่ไม่เพียงพอแน่นอน ติดสนั่นทั้งอำเภอปากเกร็ดแน่ๆ พิจารณา\nอีกทีค่ะ !!',
#  '0.0',
#  'พวกเขาอยู่เเต่ห้องเเอร์รอเงินอย่างเดียวละครับพวกนี้ไม่เคยลงมาดูอะไรสักอย่าง',
#  '0.0',
#  'อย่าเอาแต่นั่งห้องแอร์\u200b ผู้ปกครองทุกคนเค้าเบื่อพวกท่านเต็มทนแล้วครับ',
#  '0.0',
#  'รถมันก็ติดเป็นคอขวดเลยครับ บริหารจัดการแย่มาก',
#  '0.0',
#  'ได้รับผลกระทบในช่วงเช้าเป็นอย่างมาก แก้ไขปัญหาบ้างครับ',
#  '0.0',
#  'พยายามปรับเปลี่ยนเวลาในการออกไปทำงานให้เร็วขึ้นเพื่อเลี่ยงการจราจรแล้ว \nแต่ก็ยังได้รับผลกระทบอยู่เหมือนเดิม รร ควรจะแก้ไขการจราจรได้แล้ว',
#  '0.0',
#  'ผปค บางคนวิ่งส่วนย้อนทางออกทำให้รถคันอื่นติดยาวที่จอดข้างใน \nควต้องปรับปรุงรการจราจร และนิสัยผู้ปกครองด้วย',
#  '0.0',
#  'ผู้ปกครองบางคนก็เห็นแก่ตัว ไม่เตรียมตัวพร้องลงลืมของลืมกระเป๋ารองเท้าบ้าง \nจอดรอลูกไปซื้อของห้องสหกรณ์รถติดยาว',
#  '0.0',
#  'รร.ควรพิจารณานะคะ ผลกระทบเป็นวงกว้างไม่ใช่เฉพาะผปค. รร.นี้เท่านั้น ',
#  '0.0',
#  'ดีจัง ลูกเราย้ายมาเรียนหอวังนนท์แล้ว มาอ่านแล้วเหมือนย้อนกลับไป ที่ต้องทน\nมา 6ปี ที่แล้ว ปัญหาที่แก้ไข ไม่ได้ 🤭🤭',
#  '0.0',
#  'รบกวนเปิดตั้งแต่16.00 เหมือนเดิมค่ะ ส่วนรถผู้ปกครองที่เห็นแก่ตัว ล็อคล้อ \nจ่ายค่าเสียหายไปเลยค่ะ ไม่งั้นรถจะสาหัสมาก',
#  '0.0',
#  'ความเห็นแก่ตัวของคนส่วนน้อยทำให้คนส่วนใหญ่ที่เคารพกติกาต้องมีปัญหาแย่ๆ',
#  '0.0',
#  'เมื่อวานผมติดอยู่ในลานจอดรถ เกือบ 3 ชั่วโมง ควรหาทางแก้ปัญหานะ ',
#  '0.0',
#  'ห้ามนำรถเข้าไปจอดในโรงเรียนผมเห็นด้วยนะคับ แต่ถ้าห้ามเข้าไปเลยปัญหา\nก็เป็นแบบนี้ ควรหาวิธีแก้ด้วยครับ',
#  '0.0',
#  'เพจโรงเรียนเลี่ยงที่จะตอบคำถามทางผู้ปกครอง ผมนั่งดูย้อนหลังไปน้อยมากที่จะ\nมาตอบปัญหาที่มีการสอบถามเรื่องการจราจร ห่วยไปนะครับบบ',
#  '0.0',
#  'ควรเปิดช่องประตูเล็กเพื่อให้ผู้ปกครองเดินไปส่งได้นะ',
#  '0.0',
#  'ครูใส่รองเท้าที่เดินข้างนอกเหยียบพื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย \nรบกวนทาง รร พิจารณาเรื่องความสะอาดให้เด็กๆด้วย',
#  '0.0',
#  'เด็กๆ บางคนไม่ชอบ มักกะโรนี ควรมีอะไรแทนบ้างนะคะ',
#  '0.0',
#  'ควรปรับปรุงเรื่องรสชาติบ้างนะค ต้มจืดก็จืดมาก',
#  '0.0',
#  'หมูก็ให้มาแค่ชิ้นน้อยๆ ควรพิจารณาปรับปรุงค่ะ',
#  '0.0',
#  'หวังว่าจะปรับปรุงเรื่องรสชาติและปริมาณที่เหมาะสมนะ',
#  '0.0',
#  'เด็กต้องแบกกระเป๋าหนัก และเดินไกลมากฝากปัญหานี้ให้ผู้บริหารด้วยค่ะ',
#  '0.0',
#  'จยย.ที่ขับเข้ามาแล้วเด็กต้องเดินหลบรถอันตรายมาก',
#  '0.0',
#  'กับข้าวของลูกๆอิสลาม ยังไม่ได้รับการปรับปรุงเลยค่ะ',
#  '0.0',
#  'หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆ',
#  '0.0',
#  'ลานจอดใหม่ ฝุ่น เยอะมาก',
#  '0.0',
#  'ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถทีครับ เยอะมากสงสารสุขภาพลูก',
#  '0.0',
#  'ถนนข้างสนามกอล์ฟฝุ่นฝุ่นเยอะมาก ควรแก้ไขตรงนี้ด่วนๆค่ะ',
#  '0.0',
#  'ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่สงสารเด็กๆมาก',
#  '0.0',
#  'ถ้าโรงเรียนไม่มีศักยภาพในการจัดสรรระบบการจอดรถ การจราจรพอ ควรจะเปิดให้รถผู้ปกครองเข้าไปรับส่งเด็กได้นะคะ',
#  '0.0',
#  'อิดออดในการคืนเงินมาก หรือต้องให้คำนวนให้ แย่มาก',
#  '0.0',
#  'เพจโรงเรียนเลี่ยงที่จะตอบคำถามทางผู้ปกครองผมนั่งดูย้อนหลังไปน้อยมากที่จะมาตอบปัญหาที่มีการสอบถามเรื่องการจราจร การที่ไม่แก้ปัญหา\n ปัญหามันจะไม่จบเมื่อมันสะสมมากๆ มันลุกลามบานปลายนะคับ',
#  '0.0',
#  'รร. ปรับปรุงเรื่องที่จอดรถไม่ใช่ว่าจะทำให้เหตุการณ์รถติดดีขึ้น ที่ไม่โวยวายเพราะต้องทน ถ้ายังเป็นอยู่อย่างนี้คงต้องหา รร.ใหม่ให้ลูกค่ะ ตอนนี้เสียสุขภาพจิตมาก',
#  '0.0',
#  'ช่วยดูด้วยค่ะว่าเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหน',
#  '0.0',
#  'รบกวนออกมาชี้แจ้งด้วยค่ะ',
#  '0.0',
#  'ก๋วยเตี๋ยวหมูน้ำตก หมูน้อยไปนะควรเพิ่มอีกนิดค่ะ !!',
#  '0.0',
#  'แกงคั่วฟักทอง คิดว่าเด็กๆไม่น่าชอบนะคะ ควรเปลี่ยนจากแกงบ้าง',
#  '0.0',
#  'ยำหมูยอลดความเผ็ดลงหน่อยคะ่หนูทานไม่ได้',
#  '0.0',
#  'แอปเปิ้ลช้ำไปหน่อยค่ะ ช่วยปรังปรุงอีกนิดนะคะ',
#  '0.0',
#  'ทอดมันมันมากกก ลูกกินไม่ได้ปรังปรุงด่วนค่ะ',
#  '0.0',
#  'ทั้ังประชาชนทั้ง ผปค ด่าไปผู้บริหารไม่เคยเข้ามาดูไม่เคยแก้ไขปัญหาตรงนี้เลย',
#  '0.0',
#  'แกงขั่วฟักเขียว แค่ชื่อเด็กๆไม่ทานแล้ว เด็กๆคงเบื่อแกงแล้วค่ะ ',
#  '0.0',
#  'ควรเพิ่มปริมาณข้าวสวยอีกนิดค่ะ ลูกทานไม่อิ่ม',
#  '0.0',
#  'ไข่เจียวจืดมาก ปรังปรุงรสชาติหน่อยก็ดีนะครู',
#  '0.0',
#  'ข้าวผัดกุนเชียง แต่กุนเชียงได้น้อยมาก ปรังปรุงด้วยค่ะหลายรอบแล้วนะคะ ',
#  '0.0',
#  'ก๋วยเตี๋ยวเปลี่ยนจากเส้นหมี่เป็นบะหมี่บ้างนะคะ ไม่ได้เรื่องเลย',
#  '0.0',
#  'ก๋วยเตี๋ยวเส้นหมี่อีกแล้ว ลองมากินเองมั้ยคะจะได้รู้ว่ามันน่าเบื่อ',
#  '0.0',
#  'ห้องน้ำสกปรกมาก ตรวจด้วยค่ะ !!!',
#  '0.0',
#  'รบกวนออกมาชี้แจ้งเรื่องคืนค่าเทอมด้วยค่ะ',
#  '0.0',
#  'ห้องน้ำยังคงสกปรกเหมือนเดิม',
#  '0.0',
#  'ตอนเลิกเรียน\u200b ลำบากมากครับ\u200b ไม่มีที่จอด',
#  '0.0',
#  'ต้มจืดลูกบอกจืดสมชื่อมาก พิจาณาด้วยค่ะ',
#  '0.0',
#  'ปรับปรุงเรื่องที่จอดรถด้วยค่ะ ตอนนี้เสียสุขภาพจิตมาก',
#  '0.0',
#  'โรงอาหารมีหนู สกปรกไปนะแก้ไขด่วนค่ะะะะะ',
#  '0.0',
#  'ควรจัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ\u200b ไม่ไหวๆ',
#  '0.0',
#  'ภาพกิจกรรมสอนเสริมวันเสาร์เทควันโด สวยมากเลยค่ะ',
#  '1.0',
#  'ขอบคุณมากๆเลยค่าสำหรับอาหารของเด็กอนุบาลที่ไม่ใส่พริกแกง ',
#  '1.0',
#  'โรงเรียน update ข่าวสารรวดเร็ว ทันใจผู้ปกครองมากค่ะ สุดยอดค่ะ',
#  '1.0',
#  'เด็กๆได้รับทั้งความรู้และสนุกสนาน แถมได้กระชับมิตรกับเพื่อน\nใหม่ในกลุ่ม ดีมากๆค่ะ',
#  '1.0',
#  'ในที่สุด 😆😆😆😆 เพจจะกลับมาเหมือนปกติแล้วเย้ๆ',
#  '1.0',
#  'เด็กดีเราต้องชื่นชมเป็นกำลังใจให้สุดยอดเลยจ้า',
#  '1.0',
#  'ชื่นชมในความมีวินัยมานะบากบั่นในการฝึกซ้อมจนได้รับรางวัล\nขอให้ประสพความสำเร็จยิ่งยิ่งขึ้นไปค่ะ ขอแสดงความยินดีด้วยนะคะ',
#  '1.0',
#  'เด็กๆเก่งมากค่ะ ❤❤',
#  '1.0',
#  'ขอบคุณมากเรยค่ะที่ตอบคำถามคุณแม่ ส่วนใหญ่ ผปค.มีผลกระ\nทบช่วงเช้ามากกว่าช่วงเย็นค่ะคุณครู ตอนเช้าวนเข้า รอรถออก\nนานมากเลยค่ะ',
#  '1.0',
#  'ขอบคุณทาง รร ค่ะ ส่วนหนึ่งก็เห็นใจที่ รร จะต้องใช้เงินบริหารจัด\nการบุคคลากรใน รร เพื่อให้ รร อยู่รอดเพราะเป็น ร.รเอกชน',
#  '1.0',
#  'อาหารใช้ได้ค่ะ ลูกบอกว่าอร่อย บางวันก็ถุกปาก ปากวันก็ไม่ถุก\nปาก สลับๆกันไปค่ะ แต่อย่างว่าแต่ละคนชอบไม่เหมือนกีน รวมๆ\nแล้ว ดีค่ะ',
#  '1.0',
#  'ในสถานการณ์เเบบนี้การบริหารการจัดการไม่ใช่เรื่องง่าย \nเป็นกำลังใจให้นะครับสู้ๆครับ..\n',
#  '1.0',
#  'ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่\nจะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้\nมากเลยครับ',
#  '1.0',
#  'ขอบคุณสำหรับการทำคลิปที่ภาพสวย เสียงชัดนะคะ \nครูและทีมคงต้องเหนื่อยและตั้งใจกันมาก ',
#  '1.0',
#  'CPW Classroom ดูง่ายขึ้น สะดวกมากขึ้น ขอบคุณนะคะ',
#  '1.0',
#  'ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ',
#  '1.0',
#  'ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจ\nขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ',
#  '1.0',
#  'ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจ\nขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ',
#  '1.0',
#  'ขอบคุณทางรร. ที่รับฟัง และนำเอาคำติชมของผปค. ทุกท่านไป\nปรับเปลี่ยนเมนู ให้สอดคล้องกับเด็กประถมเล็กๆ ด้วยนะคะ 🙏🏻',
#  '1.0',
#  'เรียนออนไลน์แล้วนักเรียนได้เกรดดีมากเลยค่ะ',
#  '1.0',
#  'ขอให้แก้ปัญหาได้นะคะ สู้ๆค่ะเป็นกำลังใจให้นะคะ',
#  '1.0',
#  'ขอขอบคุณนักเรียนจิตอาสาของโรงเรียนด้วยนะครับที่เข้ามาทำ\nความสะอาดที่วัด',
#  '1.0',
#  'คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ',
#  '1.0',
#  'ขอบคุณนะคะ จะได้ไปบอกลูกเค้าอยากดูมากเลย 🙂',
#  '1.0',
#  'หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ ชอบอาหารที่ ร.ร',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ช่วงบ่ายดูได้ปกติแล้วครับ..ขอบคุณมากๆครับ..',
#  '1.0',
#  'ขอบคุณผอ.ด้วยนะคะ วันนี้เห็นผอ.ไปช่วยดูแลเด็กๆข้ามถนน',
#  '1.0',
#  'เมื่อเช้าเห็นท่าน ผอ.ออกมายืนรับเด็กๆตรงไฟแดงเอง\nท่านน่ารักมากๆ',
#  '1.0',
#  'ขอแสดงความยินดีแด่คุณครูทุกๆท่านเป็นอย่างยิ่งครับ',
#  '1.0',
#  'เยี่ยมมากๆ...นี่แหละคนรุ่นใหม่และหลายๆคน ในร.ร.\nจะมาสร้างฝันและดูแลชลประทานให้ยิ่งใหญ่ๆต่อไป',
#  '1.0',
#  'เยี่ยมมากๆ...นี่แหละคนรุ่นใหม่และหลายๆคน ในร.ร.\nจะมาสร้างฝันและดูแลชลประทานให้ยิ่งใหญ่ๆต่อไป',
#  '1.0',
#  'ศิษย์เก่งมาจากครูที่เก่งด้วยค่ะ ขอชื่นชมค่ะ\n',
#  '1.0',
#  'ยินดีกับคุณครูอีกครั้งหนึ่งครับเหมาะสมมากๆครับ',
#  '1.0',
#  'ขอบคุณคุณครูและบุคลากรที่ รร.ทุกท่านที่คอยดูแลเอาใจใส่ นร.ค่ะ\n',
#  '1.0',
#  'ชอบมากเลยคะโรงเรียนนี้..เคยเข้าไปติดต่อจะพาลูกเข้าเรียนตอน\nม.4เจ้าหน้าที่พูดจาดีมากๆ ',
#  '1.0',
#  'ชอบมากเลยคะโรงเรียนนี้..เคยเข้าไปติดต่อจะพาลูกเข้าเรียนตอน\nม.4เจ้าหน้าที่พูดจาดีมากๆ ',
#  '1.0',
#  'ขอบคุณมากๆ เลยนะคะ ขอบคุณมากจริง ๆ ค่ะ',
#  '1.0',
#  'ขอขอบคุณโรงเรียนชลประทานวิทยา อาจารย์ทุกท่านที่ให้การ\nสนับสนุนหนูทั้งเวลาเรียน และเวลาซ้อมค่ะ 🙏',
#  '1.0',
#  'ขอบคุณมากเลยค่ะที่ตอบคำถามคุณแม่ สบายใจมากขึ้นเลยค่ะ',
#  '1.0',
#  'ขอบคุณที่ปรับปริมาณอาหารให้กับเด็กนะคะ ขอบคุณมากจริงๆค่ะ',
#  '1.0',
#  'ขอบคุณที่ปรับปริมาณอาหารให้กับเด็กนะคะ ขอบคุณมากจริงๆค่ะ',
#  '1.0',
#  'ลูกบอกว่าอาหารวันนี้อร่อยมากค่ะ ปริมาณอาหารกำลังดีด้วยค่ะ',
#  '1.0',
#  'ลูกบอกว่าอาหารวันนี้อร่อยมากค่ะ ปริมาณอาหารกำลังดีด้วยค่ะ',
#  '1.0',
#  'แกงเขียวหวานอร่อยมากค่ะ ลูกติดใจอยากใก้ทำอีกค่ะ',
#  '1.0',
#  'วันนี้การจรจารในโรงเรียนไหลลื่นมากค่ะ ขอบคุณที่ รปภ และ\nทาง รร นะคะ',
#  '1.0',
#  'ต้มเลือดหมูวันนี้เครื่องแน่มาก ลูกบอกว่ากินจนอิ่มเลยค่ะ \nอร่อยมากๆค่ะ',
#  '1.0',
#  'ขากลับวันนี้รถไม่ค่อยติด ขอบคุณทาง รร นะคะ',
#  '1.0',
#  'อาหารวันนี้อร่อยมากค่ะ ขอบคุณทางฝ่ายโภชนาการและ รร มากๆเ\nลยนะคะ',
#  '1.0',
#  'อาหารวันนี้อร่อยมากค่ะ ขอบคุณทางฝ่ายโภชนาการและ รร มากๆเ\nลยนะคะ',
#  '1.0',
#  'ขอบคุณที่่ลดปริมาณพริกลงนะคะ ขอบคุณมากๆค่าาา',
#  '1.0',
#  'ขอบคุณที่่ลดปริมาณพริกลงนะคะ ขอบคุณมากๆค่าาา',
#  '1.0',
#  'ศิษย์เก่งมาจากครูที่เก่งด้วยค่ะ ขอชื่นชมค่ะ\n',
#  '1.0',
#  'เป๊ะมากครับ สุดยอดเด็กๆ เก่งจังเลย',
#  '1.0',
#  'เป๊ะมากครับ สุดยอดเด็กๆ เก่งจังเลย',
#  '1.0',
#  'อาหารถูกหลักโภชนาการ ขอชื่นชมครับ',
#  '1.0',
#  'ขอบคุณมากค่ะ ฝากด้วยค่ะ',
#  '1.0',
#  'ออกแบบได้ สวยงาม น่าสวมใส่',
#  '1.0',
#  'ออกแบบได้สวยงามมากครับ',
#  '1.0',
#  'ขอบคุณนะคะ 🥰🥰',
#  '1.0',
#  'เว็บ รร.ออกแบบได้สวยเลยครับ',
#  '1.0',
#  'thank',
#  '1.0',
#  'Thank you',
#  '1.0',
#  'good',
#  '1.0',
#  'เมนูวันนี้อร่อยมากค่ะ',
#  '1.0',
#  'คุณครูดูแลดีมากจริงๆค่ะ',
#  '1.0',
#  'คุณครูดูแลดีมากจริงๆค่ะ',
#  '1.0',
#  'well done ',
#  '1.0',
#  'well done ',
#  '1.0',
#  'เว็บ รร.ออกแบบได้สวยเลยครับ',
#  '1.0',
#  'thank',
#  '1.0',
#  'Thank you',
#  '1.0',
#  'good',
#  '1.0',
#  'ขอบคุณนะคะ 🥰🥰',
#  '1.0',
#  'Thank',
#  '1.0',
#  'thank you',
#  '1.0',
#  'Good',
#  '1.0',
#  'Good job',
#  '1.0',
#  'Congratulations',
#  '1.0',
#  'congratulations',
#  '1.0',
#  'Fantastic',
#  '1.0',
#  'Congratulations',
#  '1.0',
#  'congratulations',
#  '1.0',
#  'Fantastic',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ😊💐',
#  '1.0',
#  'Thank',
#  '1.0',
#  'thank you',
#  '1.0',
#  'Good',
#  '1.0',
#  'Good job',
#  '1.0',
#  'Congratulation',
#  '1.0',
#  'congratulation',
#  '1.0',
#  'fantastic',
#  '1.0',
#  'well done ',
#  '1.0',
#  'well done ',
#  '1.0',
#  'Thank',
#  '1.0',
#  'thank you',
#  '1.0',
#  'Good',
#  '1.0',
#  'คิดถึงตอนลูกสาวอยู่ ปฐมวัย ได้รับการดูแลเอาใจใส่ จากครูเจี้ยบ (ครูไพลิน เกษียณแล้ว) ครูจอย และครูวีณา\nลูกสาวคือดื้อมาก กลางวันไม่ยอมนอน ได้ครูวีณา คอยเล่นด้วยมาตลอด\nขอบคุณมากๆ\nตอนนี้อยู่ประถม 3/16 แล้วครับ ยังคิดถึงครูทั้ง 3 ท่านอยู่เสมอ',
#  '1.0',
#  'คิดถึงตอนลูกสาวอยู่ ปฐมวัย ได้รับการดูแลเอาใจใส่ จากครูเจี้ยบ (ครูไพลิน เกษียณแล้ว) ครูจอย และครูวีณา\nลูกสาวคือดื้อมาก กลางวันไม่ยอมนอน ได้ครูวีณา คอยเล่นด้วยมาตลอด\nขอบคุณมากๆ\nตอนนี้อยู่ประถม 3/16 แล้วครับ ยังคิดถึงครูทั้ง 3 ท่านอยู่เสมอ',
#  '1.0',
#  'ภูมิใจเสมอที่ได้เรียกตัวเองว่าเป็นศิษย์โรงเรียนนี้',
#  '1.0',
#  'ในสถานการณ์เเบบนี้การบริหารการจัดการไม่ใช่เรื่องง่าย... เป็นกำลังใจให้นะครับสู้ๆครับ..',
#  '1.0',
#  'ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่จะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้มากเลยครับ',
#  '1.0',
#  'ขอบคุณ ที่ดูแล ลูกๆ ให้ครับ ในช่วงโควิดแบบนี้ ถึงแม้ว่าพ่อแม่จะทำงานอยู่บ้านทุกคน เเต่ทางโรงเรียนก็ช่วยแบ่งเบาภาระได้มากเลยครับ',
#  '1.0',
#  'CPW Classroom ดูง่ายขึ้น สะดวกมากขึ้น ขอบคุณนะคะ',
#  '1.0',
#  'ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ',
#  '1.0',
#  'ขอบคุณแอดมินมากครับ ประสานงานดีมากครับ',
#  '1.0',
#  'ขอบคุณค่ะที่รับฟังและปรับแก้ไขให้ผู้ปกครองมั่นใจ และสบายใจขึ้น เปลี่ยนจากผัดลูกชิ้น เป็นหมูหรือไก่ เยี่ยมคะ        ',
#  '1.0',
#  'เดินทางกลับมาโดยสวัสดิภาพ\nทุกคณะครู นักเรียนทุกท่านค่ะ\nเทพเทวดา เจ้าที่เจ้าทางเปิดทาง\nสะดวกสบายราบรื่นนะค่ะ😇😇',
#  '1.0',
#  'เดินทางกลับมาโดยสวัสดิภาพ\nทุกคณะครู นักเรียนทุกท่านค่ะ\nเทพเทวดา เจ้าที่เจ้าทางเปิดทาง\nสะดวกสบายราบรื่นนะค่ะ 😇😇',
#  '1.0',
#  'ขอขอบคุณนักเรียนจิตอาสาของโรงเรียนด้วยนะครับที่เข้ามาทำความสะอาดที่วัด',
#  '1.0',
#  'ขอบคุณที่รับฟังค่ะ',
#  '1.0',
#  'รายการอาหารดีมาก',
#  '1.0',
#  'หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ...ชอบอาหารที่ร.ร.',
#  '1.0',
#  'หลานบอกข้าวหมูแดงเมื่อวานอร่อยมากๆ...ชอบอาหารที่ร.ร.',
#  '1.0',
#  'คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ',
#  '1.0',
#  'รู้สึกประทับใจมากเลย',
#  '1.0',
#  'รู้สึกประทับใจมากเลย',
#  '1.0',
#  'น่านับถือ',
#  '1.0',
#  'เรียบร้อยแล้ว ไวมาก ขอบคุณทางเจ้าหน้าที่ทุกท่าน ด้วยครับ',
#  '1.0',
#  'ขอบคุณ\u200bค่ะ\u200b สำหรับเมนู\u200bอาหาร\u200bกลางวัน\u200bของเด็กๆค่ะ\u200b ที่ส่งมาให้ผู้ปกครอง\u200bทราบค่ะ',
#  '1.0',
#  'เยี่ยมเลยคะ',
#  '1.0',
#  'ขอชื่นชมทางรร.นะค่ะที่มีการปรับปรุง',
#  '1.0',
#  'รู้สึกดีใจมากที่ส่งลูกมาเรียนรร.นี้',
#  '1.0',
#  'คุณครูดูแลเอาใจใส่เด็กๆได้เป็นอย่างดี',
#  '1.0',
#  'คุณครูดูแลเอาใจใส่เด็กๆได้เป็นอย่างดีมาก',
#  '1.0',
#  'ขอบใจมากจ่ะ',
#  '1.0',
#  'ขอบคุณมากเรยค่ะที่ตอบคำถามคุณแม่',
#  '1.0',
#  'เรียบร้อยแล้ว ไวมาก ขอบคุณทางเจ้าหน้าที่ทุกท่าน ด้วยครับ',
#  '1.0',
#  'ได้แล้วค่ะ ขอบคุณค่ะ',
#  '1.0',
#  'ลูกบอกข้าวผัดเมื่อวานอร่อยมากๆเลยค่ะ',
#  '1.0',
#  'คลิปแนะนำคอร์สเรียนว่ายน้ำ ทางโรงเรียนทำมาได้ดีมากเลยค่ะ',
#  '1.0',
#  'มีครูคอยดูแลระหว่างการเดินขึ้นลงบันไดหมดความกังวลเรื่องความ\nสะอาดเลยค่ะ ขอบคุณนะคะที่คอยใส่ใจในรายละเอียดเล็กๆน้อยๆ',
#  '1.0',
#  'กับข้าววันนี้ได้เยอะและอร่อยมากค่ะลูกบอกวันนี้ทานหมดเกลี้ยงเลย',
#  '1.0',
#  'อาหารวันนี้ดีมากคะ ขอบคุณนะคะ',
#  '1.0',
#  'ลูกถ่ายรูปผลไม้ของวันนี้มาให้ดูผลไม้สด และหวานกำลังพอดีเลยค่ะ',
#  '1.0',
#  'อาหารกลางวันพรุ่งนี้ถ้าเปลี่ยนเป็นถ้าเปลี่ยนเป็นหมูตุ๋นๆ \nน่าจะชอบทานมากกว่านะคะ',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆ วงโยธวาทิต ด้วยครับ',
#  '1.0',
#  'ขอแสดงความยินดีกับเด็กๆที่ได้รับรางวัลด้วยนะคะ เก่งมากค่ะ',
#  '1.0',
#  'ยอดเยี่ยมค่ะ ราคาเหมาะสม',
#  '1.0',
#  'กระเป๋า รร สวยค่ะ เหมือนในรูปเลย ชอบค่ะ',
#  '1.0',
#  'ราคาโบว์กับคุณภาพมีความเหมาะสมกันแล้ว ขอบคุณนะคะ',
#  '1.0',
#  'รายการอาหารอาทิตย์นี้ดีมากๆเด็กๆน่าจะรับประทานกันอร่อยนะครับ',
#  '1.0',
#  'เก่งมากๆ คับลูกๆ ทั้ง2😍👍',
#  '1.0',
#  'ยินดีด้วยครับ',
#  '1.0',
#  'ดีใจกับน้องดิวด้วยนะครับ ขอให้ประสบความสำเร็จในคณะศึกษาอยู่',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ชื่นชมกับกิจกรรมดีของชลประทาน…เป็นกำลังใจให้กับทีมงาน\nทุกๆท่าน สู้นะค่ะ',
#  '1.0',
#  'ขอบคุณผอ.ด้วยนะครับ วันนี้เห็นผอ.ไปช่วยดูแลเด็กๆข้ามถนน',
#  '1.0',
#  'ขอบคุณผอ.นะคะ ที่ตอนเช้าช่วยดูลูกๆข้ามถนนครับ',
#  '1.0',
#  'ไป ๆ ดีลชอบ ๆๆ',
#  '1.0',
#  'เก่งมากค่ะ',
#  '1.0',
#  'สวยงาม เก่งมากจ๊ะ สร้างชื่อเสียงให้รร.และประเทศชาติ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะเก่งมากๆ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'เก่งมากค่ะ',
#  '1.0',
#  'ยินดีด้วยครับ ❤',
#  '1.0',
#  'คว้าเหรัยญทองกลับมานะครับ เชียร์ๆ',
#  '1.0',
#  'สุดเลยค่าน้องแตะเตี้ยม ยินดีกับคุณพ่อคุณแม่ด้วยค่า สุดยอดดด',
#  '1.0',
#  'ส่งใจไปเชียร์ค่ะ\n',
#  '1.0',
#  'ยินดีด้วยนะคะ ยอดเยี่ยมมากๆ เลยค่ะ',
#  '1.0',
#  'เก่งมากๆเลย ปลื้มจัง ครูจะขอเป็นกำลังใจให้และชื่นชมกับ\nความสำเร็จในทุกขั้นของพวกหนูนะคะ 🥰❤️',
#  '1.0',
#  'ขอแสดงความยินดีด้วยยอดเยี่ยมมากค่ะ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยครับเก่งมากๆครับ',
#  '1.0',
#  'เก่งทุกคนเลยค่ะ',
#  '1.0',
#  'เก่งมากจร้าาา',
#  '1.0',
#  'ขอแสดงความยินดีกับทุกๆคนด้วยนะครับเก่งมากๆ',
#  '1.0',
#  'ยินดีด้วยนะคะ เก่งมากๆ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยนะคะ ',
#  '1.0',
#  'เก่งมากค่ะยินดีด้วย ขอให้ชนะเลิศกลับมานะคะ',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ\n',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยค่ะ',
#  '1.0',
#  'ชอบทุกๆกิจกรรมของชมรมเลย ติดตามและสนับสนุนนะคะ ❤️',
#  '1.0',
#  'ยินดีด้วยนะคะ',
#  '1.0',
#  'เด็กดีเป็นศรีต่อตัวเอง ครอบครัว คนรอบข้างและของชาติจริงๆ \nยินดีด้วยนะคะ',
#  '1.0',
#  'ภาพสวยมากๆเลยค่าาา',
#  '1.0',
#  'สวยมากครับ',
#  '1.0',
#  'เด็กๆเก่งมากค่ะ ยินดีกับน้องด้วยนะคะ\n',
#  '1.0',
#  'ภาพสวยมากครับ❤️\n',
#  '1.0',
#  'เก่งมากๆครับ ยินดีด้วยครับ',
#  '1.0',
#  'สวยมากค่ะ ขอแสดงความยินดีด้วย',
#  '1.0',
#  'ขอร่วมแสดงความยินดีและภาคภูมิใจกับความสำเร็จของน้องด้วย\nนะครับ',
#  '1.0',
#  'เป็นกำลังใจให้ครับ ^^',
#  '1.0',
#  'ขอให้โชคดี เก็บเกี่ยวประสบการณ์ดีๆ เกินทางปลอดภัยนะคะ',
#  '1.0',
#  'ขอขอบคุณ โรงเรียนชลประทานวิทยา คณาจารย์ เจ้าหน้าที่ \nศิษย์รุ่นพี่ เพื่อนและทุกหน่วยงาน ที่เมตตาอบรม สั่งสอน ส่งเสริม \nสนับสนุน ให้น้องได้ค่อยๆก้าวเดินมาถึงจุดนี้และยังเป็นต้นทุนที่ดี\nงามในการเดินทางเพื่อความฝันต่อๆไปด้วยค่ะ',
#  '1.0',
#  'ขอบแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยนะคะ',
#  '1.0',
#  'ชื่นชมยินดีเด็กเก่งค่ะ',
#  '1.0',
#  'เด็กๆสุดยอดจริงๆชื่นชมและดีใจด้วยค่ะ',
#  '1.0',
#  'ขอบคุณค่ะ ดีต่อใจ🥰',
#  '1.0',
#  'งดงาม ดูกี่ปีกี่ปีก็งดงาม',
#  '1.0',
#  'เป็นอีกหนึ่งความภูมิใจ สุดยอดมาก',
#  '1.0',
#  'ขอแสดงความยินดีกับเด็กๆด้วยนะคะ',
#  '1.0',
#  'ยินดีด้วยค่ะ เด็กๆเก่งมากๆค่ะ\n',
#  '1.0',
#  'ยินดีด้วยนะคะคุณครูทุกท่าน',
#  '1.0',
#  'ยินดีด้วยค่ะ เก่งมากๆค่ะ',
#  '1.0',
#  'Congratulations กับเด็กๆ ทุกคนด้วยค้าบ',
#  '1.0',
#  'ยินดีกับน้องๆทุกๆคนด้วยจ้า',
#  '1.0',
#  'เด็กๆชลประทานเก่งมากค่ะ',
#  '1.0',
#  'ยินดีด้วยกับลูกชลประทานทุกคน\nขอให้ประสบความสำเร็จ * ชาติ ศาสนา พระมหากษัตริย์ *💗',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆทุกคนนะครับ',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆทุกท่านนะครับ',
#  '1.0',
#  'ยินดีกับทุกท่านด้วยค่ะ',
#  '1.0',
#  'สวยมากเลยต้องมงแล้วค่ะ😅🤗',
#  '1.0',
#  'เก่งมากลูกเก่งด้วยหล่อด้วย',
#  '1.0',
#  'ขอแสดงความยินดีด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยค่ะ ส่งกำลังใจ นร ชลประทานค่า',
#  '1.0',
#  'ยินดีกับเด็กๆและผู้ปกครองนะคะนึกถึงวันที่ประกาศผลของลูกสาว\nเลยค่ะ',
#  '1.0',
#  'ขอบคุณค่ะ ฝากลูกชายในรั้ว CPW ด้วยค่ะ',
#  '1.0',
#  'ลูกสาวสมหวังแล้วค่ะ  ดีใจสุดๆ',
#  '1.0',
#  'เข้าใจความรู้สึกค่ะ ยินดีด้วยนะค่ะ 👏👏💐💐',
#  '1.0',
#  'ขอแสดงความยินดีกับน้อง ๆ และครอบครัวด้วยคะ \nทุกคนยอดเยี่ยมมาก ๆ คะ',
#  '1.0',
#  'ยินดีกับเด็กๆ ด้วยค่ะ',
#  '1.0',
#  'ยินดีด้วยนะค่ะทุกคน',
#  '1.0',
#  'ยินดีกับเด็กๆทุกคนและครอบครัว คุณพ่อคุณแม่ หายเหนื่อยเลย',
#  '1.0',
#  'ยินดีกับน้องๆทุกคนนะครับ',
#  '1.0',
#  'ทุกคนยอดเยี่ยมมาก ๆ คะขอบคุณมากค่ะ ยินดีกับทุกท่านด้วยค่ะ \nยังตื่นเต้นอยู่เลยค่ะ แม่ดีใจอาการออกกว่าลูกอีก',
#  '1.0',
#  'ขอแสดงความยินดีกับน้องๆและครอบครัวด้วยครับ',
#  '1.0',
#  'ขอแสดงความยินดีกับเด็กๆที่สอบผ่านทุกคนนะคะ และเป็นกำลังใจ\nต่อให้กับเด็กๆที่ยังไม่สมหวังกับสนามนี้ แต่สนามต่อไปต้องเป็นของ\nเราแน่นอนเลยค่ะ ✌️♥️',
#  '1.0',
#  'ยินดีกับน้องๆทุกบ้านที่สอบติดค่ะ',
#  '1.0',
#  'ขอแสดงความยินดีกับทุกๆคนค่ะ💕💕💕',
#  '1.0',
#  ...]

# %%
from pythainlp.util import normalize
from pythainlp import word_tokenize
import string
import re
import csv
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from stop_words import get_stop_words
from pythainlp.util import normalize
import pandas as pd
th_stop_origin = tuple(thai_stopwords())
# append tuple thai stop word
th_stop = (th_stop_origin + ("สวัสดี", "ค่ะ", "เลย", "เรย","ๆ", "สุด", "นะคะ", "นะค่ะ", "ค่า", "อีกแล้ว","‼","⁉"))
en_stop = tuple(get_stop_words('en'))
def split_word(text):
    tokens = word_tokenize(text, engine='deepcut')  # แบ่งคำภาษาไทย

    # Remove stop words ภาษาไทย และภาษาอังกฤษ
    tokens = [i for i in tokens if not i in th_stop and not i in en_stop]

    # ลบช่องว่าง
    tokens = [i for i in tokens if not ' ' in i]

    return tokens

def clean_msg(msg):
    # ลบ text ที่อยู่ในวงเล็บ <> ทั้งหมด
    msg = re.sub(r'<.*?>', '', msg)
    # ลบ hashtag
    msg = re.sub(r'#', '', msg)
    # ลบ เครื่องหมายคำพูด (punctuation)
    for c in string.punctuation:
        msg = re.sub(r'\{}'.format(c), '', msg)
    # ทำให้ทุกคำต่อกัน
    msg = ' '.join(msg.split())
    # ลบ link https
    msg = re.sub(r'http\S+', '', msg)

    return msg
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def cleanning(text):
    return clean_msg(normalize(remove_emoji(text)))
    
def add_data_to_csv_with_deepcut(text,label):
    data=[]
    flag=0

    clean_text = cleanning(text)
    list_of_word = split_word(clean_text)
        
    temp_data=[list_of_word,str(label)]
    data.append(temp_data)
    with open('dataset\data(question).csv', 'a',encoding="UTF8") as file:
        header = ['txt','label']
        writer = csv.writer(file)
        # if(flag == 0):
        #     flag=1
        #     writer.writerow(header)
        writer.writerows(data)

# %%
for i in range (0,size,2):
    print(f"{data1[i]} , {data1[i+1]}")
    add_data_to_csv_with_deepcut(data1[i].lower(),data1[i+1])
# Out:
# ไม่ทราบว่า ตารางเรียที่จะเรียน ออนไลน์ วันที่ 17 นี้ ดูได้จากที่ไหนคะ , 1
# เรียนทักษะว่ายเด็กโตเปิดสอนไหมคะ , 7
# ทางโรงเรียนมีเปิดรับสมัครเข้ ป. 1รอบ 2มั้ยคะ , 7
# ค่าสมัครภาคภาษาอังกฤษราคาเท่าไหร่คะ , 0
# ผลการเรียน จะส่งเมื่อไรครับ , 7
# ห้องปกติรับสมัครเมื่อไรคะ , 0
# สอบถามหน่อยค่ะกรณีผู้ปกครองติดธุระไปไม่ได้เป็นอะไรไหมค่ะ , 7
# ม.4มีรับเพิ่มเติมไหมค่ะ , 7
# กังวลเรื่องการพ้นยาอ่ะค่ะ จะมีสารเคมีตกค้างอยู่บนโต๊ะเด็กๆมั้ยคะ
#  นั่น เช็ดทำความสะอาดให้มั้ยคะ กลัวเด็กจับโต๊ะแล้วเอามือเข้าปาก , 1
# ทำไมเมนูอาหารภาคปกติกับภาคep.. ถึงกินเหมือนกัน...ไม่แยก
#  เลยแบบนี้ คุณจะมาคิดราคาค่าเทอม ep..แพงกว่าธรรมดาทำไม...
#  เอาอะไรมาคิด , 3
# ม.1 ค่ะ ตอนแรกแจ้งว่าวันที่ 8 หยุด สอบ 9 แล้วถ้าเป็นแบบนี้ 8
#  ไป รร แล้วสอบ 9 เหรอคะ , 2
# เปิดประตู 4 (ในรูป) เพื่อให้รถวิ่งผ่านไปลานจอดด้วยได้มั้ยคะ
#  **ย้ำนะคะให้ รถวิ่งผ่าน ห้ามจอดรถ** แบ่งเบาการจราจรใน
#  ซอยบ้างนะคะ ทุกวันใช้จากถนนเลี่ยงเมืองไปถึง รร ใช้เวลา
#  ไม่น้อยกว่า 40 นาทีทุกวันเลยค่ะ , 7
# พอดีพี่ชายเรียนอยู่ที่รร.ร.นี้ก็เลยอยากให้น้องเขาเรียนด้วยกัน
#  เพราะผู้ปกครองลำบากในการรับส่งหลายที่ค่ะ แล้วอย่างนี้พอ
#  จะมีวิธีไหนบ้างค่ะ , 1
# รบกวนสอบถามค่ะ ถ้า ปี2566 ทางโรงเรียนเปิดรับสมัครเด็กภาย
#  นอกเข้าเรียนชั้น ป.4 แบบปกติไหมคะ พอดีมีเกณฑ์จะย้ายไปอยู่
#  แถวปากเกร็ด-แจ้งวัฒนะช่วงปีนั้นค่ะ , 7
# ช่วงที่นักเรียนหยุดเรียนโควิด ไม่มีการเรียนการสอน ตั้งแต่วันที่
#  28 ธ.ค. 63 ถึง 31 ม.ค.64 ทางโรงเรียนจะดำเนินการคืนค่า
#  เทอมให้ผู้ปกครองมั๊ยคะ , 7
# อยากย้ายไปเรียนเทอมหน้าขึ้นมป. 2 มากๆค่ะ ต้องทำอย่างไรคะ
#  เปิดรับสมัครเมื่อไร , 5
# มีแผนจะให้ผู้ปกครองเอารถเข้าไปส่งในโรงเรียนได้เมื่อไหร่คะ , 2
# ทางเข้าออก รร ยังใช้รูปแบบเดิมไม๊ค่ะ ไม่งั้นรถติดขั้นเทพมาก
#  ถ้าไม่ปรับปรุง , 4
# ตารางเรียน จะแจกให้ใหม่ หรือ Download ได้วันไหนคะ , 1
# สอบ TEDET สองวิชานะคัฟ..น่าจะครึ่งวันใช่ไหมคัฟ , 1
# ขอรายละเอียดผังห้องสอบด้วยคะ หาไม่เจอคะ , 1
# มีป้ายห้ามย้อนศรในลานจอดรถให้หน่อยได้มั้ยคะ
#  ขาดวินัยกันอย่างแรงคะ , 7
# น้องเกิดวันที่31กรกฏาคม2561เข้าเกณฑ์มั้ยค่ะยังรับสมัครอยู่มั้ยค่ะ , 7
# เริ่มเปิดรับสมัครอนุบาล1 วันที่1ธ.ค64นี้ใช่มัยค่ะ ทางออนไลไหมค่ะ , 7
# มีเบอร์ที่สามารถติดต่อได้ไหมค่ะอยากมั่นใจว่าการสมัครไม่ตกหล่น
#  ค่ะ , 7
# เตรียมอบุบาลห้องล่ะกี่คนค่ะ แล้วน้องเรียนเลิกกี่โมงค่ะ , 6
# ขออนุญาตสอบถามค่ะ เห็ดที่นักเรียนโครงการ สสวท. วิจัย มีจัด
#  ขายไหมค่ะ , 1
# ฝนตกหนัก รถเข้ารับเด็กในร.ร. ได้ไหม , 1
# สนามสอบมีแจ้งหรือยังคะ , 7
# ป.6ค่าเทอม ประมาณเท่าไรค่ะ , 5
# เปิดรับสมัครป.1 2565เมื่อไรคะ , 7
# อยากทราบค่าเทอมอนุบาล EP คะ , 7
# สอบปลายภาคม.ปลายวันที่เท่าไรค่ะ , 7
# ชำระเกินไปแล้วต้องทำอย่างไรคะ , 6
# ป4 eng cpw คืนค่าเทอมเท่าไรคะ , 7
# ป.1ทางโรงเรียนเปิดรับวันใหนค่ะ , 2
# การสอบนี้ร.ร.ไม่ได้บังคับนักเรียน EP หรือคะ , 2
# ยังมีตรวจสุขภาพประจำปีของนักเรียนอยู่มั้ยคะ , 7
# ผลการเรียนของน้องอนุบาลดูได้ที่ไหนหรอค่ะ , 0
# ขอเบอร์โทรติดต่อหน่อยฝั่งอนุบาลหน่อยคะ , 1
# สมัครเรียนออนไลน์หรือต้องไปที่ รร หรอครับปีนี้ , 0
# ภาษาจีนเริ่มเรียนชั้นไหนค่ะ , 1
# เมื่อวันศุกร์ที่แล้วลูกบอกต้มจืดได้เต้าหู้สองชิ้นกับเศษๆหมู
#  คืออะไรค่ะ , 6
# เข้าไปจ่ายค่าเทอมก่อนได้มั้ยคะ​ ไม่ถนัดกับการโอน , 6
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2
# เตรียม อนุบาลเต็มยังคะ , 1
# เกรดประกาศยังคะ , 1
# โหลด QR code ไม่ได้ต้องทำยังไงครับ , 1
# ม.1 เปิดรับเมื่อไรค่ะ , 7
# รับสมัคประถมศึกษา​ปีที่1ช่วงใหนค่ะ , 7
# อ.1ค่าเทอมเท่ารัยคะ , 7
# เรียนออนไลน์รึคะ , 1
# เรียนออนไลน์หรอคะ , 7
# เตรียมอนุบาลรับกี่ขวบคะ , 1
# โครงการ EP ร่วมด้วยไหมครับ , 6
# ระดับมัธยมใช้ตารางสอนเดิมเหมือนกันใช่ไหมค่ะ , 5
# ไปจ่ายที่ห้องการเงินวันทื่1 ธ.ค ได้มั๊ยคะ , 6
# วันอาทิตย์สหกรณ์โรงเรียนเปิดไหมครับ , 7
# What time do you eat lunch? , 1
# How many students are there in your class? , 4
# How many buildings are there in your school? , 7
# What is your principal’s name? , 7
# How long is your lesson? , 4
# มีแผนจะให้ผู้ปกครองเอารถเข้าไปส่งในโรงเรียนได้เมื่อไหร่คะ , 3
# ค่าประกันอุบัติเหตุ ส่วนนี้ หายไปไหนค่ะ , 4
# กิจกรรมดนตรีต้านยาเสพติด คนนอกเข้ามารับชมได้ไหมคะ , 1
# ย้ายเข้าตอนป.3 ต้องมีหลักฐานอะไรบ้างค่ะ ต้องซื้อใบสมัครรึ
#  เปล่าค่ะ , 7
# Esmp ของม.1 มอบตัววัน7 ธค. หมายถึงต้องชำระค่าเล่าเรียน
#  ล่วงหน้าทั้งหมดเลยใช่ไหมครับ ในกรณีถ้าผู้ปกครองไม่ว่างติด
#  ภาระกิจ อนุโลมให้ขยับเวลาได้ไหมครับ ผมเป็นศิษย์เก่า ชปว.
#  ลูกคนเล็กกำลังขึ้นม.1. คนโตขึ้นม.4 เรียน ESMP อยู่ครับ
#  (ถามเผื่อทั้งสองคนเลยครับ) , 7
# ขอรายละเอียดเข้าศึกษาต่อ ชั้น ม.1 ภาคเรียนปกติ ของ นร.ภายนอก
#  ด้วยครับ (เห็นมีแต่โครงการEP ไม่มีภาคปกติ) , 7
# ใบสมัครสอบซื้อที่ไหนครับ?? , 7
# นักเรียนใหม่ ม.1 มีแค่ภาค EP หรอค่ะ , 1
# ป.4 ข้างนอกไม่ได้เปิดรับเลยใช่มั้ยคะ , 7
# สอบถามคะ..อยากย้ายลูกจากต่างจังหวัด สมัครเข้า ป.4 โรงเรียนเปิด
#  รับหรือเปล่าคะ , 5
# สอบถามอนุบาล1รับกี่ขวบ และจะสมัครได้วันไหน , 7
# ม1 ภาคปกติ (นักเรียนภายนอก) มีจัดสอบหรือเปล่าคะ , 7
# ราคาใบสมัครสสวทกับepกี่บาทคะ , 9
# สอบถามครับ​ นักเรียนภายนอก​จบป.6 จะเข้าชั้นมัธยมปีที่1​ มีเฉพาะ
#  ห้องEP เหรอครับ , 3
# รับสมัครเด็ก อ.2 เมื่อไหร่คะ , 9
# น้องเกิดตุลา 63 ต้องสมัครปีไหนคะ ต้องโทรไปจองสิทธิ์ตั้งแต่เมื่อไหร่คะ
#  ขอบคุณค่ะ , 7
# ศิษย์เก่าสามารถเข้าโรงเรียนได้ไหมคะ , 8
# ขออนุญาตสอบถามครับ เห็นลูกผมบอกว่าอาหารอิสลามเป็นเมนูเดียวกัน
#  กับอาหารทั่วไปเลยอะครับ มีการเปลี่ยนวัตถุดิบบ้างไหมครับ , 6
# สวัสดีครับ ขอสอบถามหน่อยนะครับว่าวันเปิดเทอมคือวันที่เท่าไรหรอครับ , 7
# สวัสดีครับ ผมชื่อ ด.ช.ณัฐพงศ์ พงศ์เจริญ ผมทำบัตรนักเรียนหัก ต้องทำ
#  ยังไงดีครับ , 7
# เงิน 2,000 เข้าที่ไหนอย่างไรไม่ทราบเรื่องเลยครับ , 4
# สามารถจ่ายค่าเทอมแบบออนไลน์ได้มั้ยครับ , 4
# ขอสอบถามหน่อยครับ.... , 4
# สวัสดีค่ะ ไม่ทราบว่าทางโรงเรียนจะมีขายชุดนักเรียนวันไหนหรอคะ , 8
# สวัสดีงับ ผมขอสอบถามเกี่ยวกับการย้ายแผนการเรียนหน่อยงับว่าผมควร
#  จะทำยังไง , 6
# แล้วจะรู้ได้ยังไงว่าทางโรงเรียนได้รับเงินยอดที่โอนหรือยังอ่ะคะ , 1
# ขอสอบถามหน่อยค่ะ เสื้อพละจะมีมาขายในวันไหนหรอคะ , 7
# ขอสอบถามหน่อยครับ สีกางเกงของโรงเรียนเขาเรียกว่าสีอะไรนะครับ
#  พอดีจะซื้อไปให้หลานแต่ไม่แน่ใจว่าเรียกสีนี้ว่าอะไร , 2
# สอบถามหน่อยค่ะ หลักสูตรภาษาอังกฤษ สอนโดยครูต่างชาติหรือเปล่าคะ , 7
# จะเดินทางมาโรงเรียนชลประทานได้อย่างไร , 4
# ตอนนี้ที่สหกรณ์โรงเรียนมีขายไหมครับ หรือต้องไปซื้อจากข้างนอก
#  พอดีวันที่ซื้อชุดนักเรียนไม่ได้ซื้อเอาไว้ครับ เเล้วราคาท่าไหร่ครับ , 8
# ตรวจสุขภาพนักเรียนที่โรงพยาบาลหรือ โรงเรียนคะ , 1
# สมัครสอบแต่ไม่มีรายชื่อ ต้องทำอย่างไรคะ , 7
# ฝนตกหนัก นำรถเข้ารับเด็กในร.ร. ได้ไหม , 4
# ป.6 ค่าเทอม ประมาณเท่าไรค่ะ , 6
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
#  มาเบิกค่ะ , 6
# ชำระเกินไปแล้วต้องทำอย่างไรคะ , 1
# ชำระค่าเทอมของแอปโรงเรียนอยู่ไหนครับ , 4
# อยากทราบว่า รองเท้าพละต้องเป็นสีขาวเท่านั้นมั้ยครับ , 7
# EP ป.1ค่าเทอมเท่าไหรค่ะ , 6
# สามารถเข้าไปติดต่อเพื่อชำระค่าเทอมล่วงหน้าที่ห้องการเงินได้เลยใช่
#  ไหมครับเปิดรับชำระได้เลยใช่นะครับ , 7
# จ่ายบัตรเครดิตมีค่าธรรมเนียมไหมคะ , 7
# เตรียมอนุบาลรับสมัครกี่ขวบคะ , 7
# สมัครป1 ep ค่ะ ค่าเทอมเท่าไหร่ค่ะ , 7
# เข้าไปสมัครอนุบาลนี่ไปได้ทุกวันหรือเว้นวันหยุดราชการคะ , 7
# รูปสมัครเรียนน้องอนุบาล 1 ก็ต้องใส่ชุดนักเรียนถ่ายรูปเหรอคะ , 7
# ค่าเทอมเท่ารัยคะโปรแกรม EP , 6
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 7
# มอบตัวต้องไปตรงไหนของ รร.คะ , 7
# เอกสารการเขียนคําร้องต้องใช้รูปถ่ายขนาดเท่าไหร่ครับ , 9
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ , 7
# การทดสอบวัดระดับภาษาอังกฤษ CEFR มีค่าสมัครสอบไหมคะ , 3
# ถ้าจะสั่งตัดชุด รด ติดต่อได้ที่ไหนคะ , 1
# ท้องฟ้าจำลองเปิดอีกทีเมื่อไหร่เหรอครับ , 9
# สอบถามเรื่องเรียนว่ายน้ำหน่อยค่ะ , 5
# ชุด นร. มีจำหน่ายไหมคะ ถ้ามีจำหน่ายวันไหน , 1
# อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ , 1
# เสียค่าสมัครสอบเท่าไหร่ค่ะ , 1
# ขอเกรดหน่อยครับ , 1
# ผลการเรียน , 1
# ผลการเรียนม.ต้น , 1
# เกรดออกเมื่อไหร่ครับ , 1
# สามารถดูเกรดได้ที่ไหน , 1
# เกรดออกหรือยัง , 1
# ขอดูเกรด , 1
# gpa ของลูกเป็นเท่าไหร่ , 1
# วิชาภาษาไทยได้เกรดอะไร , 1
# วิชาภาษาอังกฤษเกรดออกแล้วหรือยัง , 1
# วิชาเลขเกรดจะออกเมื่อไหร่ , 1
# อนุบาล 2 เปิดรับไหมคะ , 1
# ซื้อใบสมัคร อ.1 ได้ที่ไหนคะ , 1
# ไปซื้อใบสมัครอนุบาล 1 ได้วันไหนบ้างคะ ไปช่วง 15:00 โมงได้ไหมคะ , 1
# ค่าเทอม อ.1 เท่าไหร่ครับ , 1
# น้องเกิด 16 พค 60 สามารถสมัคร อ.1ได้ไหมคะ , 1
# ขออนุญาตสอบถามครับ มอบตัวอนุบาล 1 ที่ไหนหรอครับ , 1
# ประกาศผลการคัดเลือกอนุบาล 1 ยังไงหรอคะ , 1
# ค่าเทอมเตรียมอนุบาลเท่าไหร่ครับ , 1
# ค่าสมัครอนุบาล 1 เท่าไหร่คะ , 1
# รับสมัครนักเรียนภายนอกมั้ยคะ , 1
# ขออนุญาติสิบถามค่ะ ค่าเทอม ECP เท่าไหร่คะ , 1
# ขอดูตารางเรียน ของ ม.1 หน่อยค่ะมีให้ดูมั้ยคะ , 1
# ตารางเรียน ป.2 มาหรือยังครับ , 1
# ตารางเรียนมายังคะ ลูกสาวอยู่ชั้น ป4 ค่ะ , 1
# ขอตารางเรียน ป5 หน่อยค่ะ , 1
# ตารางเรียนชั้นปฐมศึกษาปีที่ 6 มายังคับ , 1
# สามารถจอดรถได้ที่ไหน , 2
# ลานจอดจอดได้กี่คัน , 2
# รับส่งลูกได้ที่ไหนบ้าง , 2
# โรงเรียนเสียค่าจอดรถไหมครับ , 2
# มีที่สำหรับจอดมอเตอร์ไซค์มั้ย , 2
# ลูกขับมอเตอร์ไซค์ไปโรงเรียนได้มั้ยคะ , 2
# รถมอเตอร์ไซค์จอดรวมกับรถยนต์ได้มั้ยคะ , 2
# แล้วมอเตอร์ไซค์สามารถขับเข้าโรงเรียนได้มั้ยครับ , 2
# สามารถเข้าไปจอดรอรับลูกได้มั้ยครับ , 2
# มีที่จอดรถกี่อาคารครับ , 2
# ช่วงเวลาที่โรงเรียนมีการเรียนการสอนสามารถเข้าไปรับลูกได้มั้ยครับ , 2
# รถโรงเรียนจอดรอที่ไหนหรอคะ , 2
# มีรถรับส่งนักเรียนไหมคะ , 2
# รถโรงเรียนมีรอบกี่โมงบ้าง , 2
# มีรสบัสบริการไหม , 2
# รถบัสจอดรอที่ไหนหรอคะ , 2
# มีบัสรับส่งนักเรียนไหมคะ , 2
# รถบัสโรงเรียนมีรอบกี่โมงบ้าง , 2
# โรงเรียนมีรถรับส่งไหมครับ , 2
# มีรถตู้บริการรถรับ-ส่งมั้ยคะ , 2
# รถตู้โรงเรียนคิดค่าบริการเท่าไหร่ , 2
# รถตู้โรงเรียน1คันนั่งได้กี่คน , 2
# สมัครใช้บริการรถบัสโรงเรียนได้ที่ไหน , 2
# สมัครใช้บริการบัสโรงเรียนได้ที่ไหน , 2
# ขอรายละเอียดข้อมูลรถบัสโรงเรียนเพิ่มเติม , 2
# มีรถรับส่งไปเรียนรักษาดินแดนไหมคะ , 2
# รถรับส่งจอดตามจุดไหนบ้างคะ , 2
# ขอแผนที่จุดจอดรถโรงเรียนครับ , 2
# รถรับส่งจอดหน้าหมู่บ้านไหม , 2
# รถรับส่งจอดตามรถประจำทางไหม , 2
# รถบัสมารับถึงหน้าบ้านเลยมั้ยคะ , 2
# รถรับส่งมารอรับหน้าบ้านหรือต้องรอตามจุดครับ , 2
# รถบัสจอดรับกี่จุดหรอคะ , 2
# สามารถปั่นจักนยานไปเรียนได้มั้ย , 2
# มีจุดรับฝากรถจักรยานไหม , 2
# ขอแผนผังอาคารเรียน , 3
# อยากได้ตารางอาหารแต่ละวัน , 3
# ภาพเมนูอาหาร , 3
# โรงอาหารจัดอาหารอะไรให้บ้าง , 3
# ตอนพักเบรกมีอาหารว่างมั้ยคะ , 3
# อาหารว่างเป็นอะไรคะวันนี้ , 3
# นักเรียนได้อาหารว่างคนละกี่ชิ้น , 3
# โรงเรียนทำอาหารเองหรือป่าว , 3
# ถ้าลูกทานแล้วไม่อิ่มสามารถเติมได้ไหม , 3
# ลูกทานอาหารร่วมกับเพื่อนกี่คน , 3
# อาหารของโรงเรียนสะอาดมั้ย , 3
# มีร้านอาหารอื่นๆที่ลูกสามารถไปซื้อได้มั้ยครับ , 3
# อาหารแต่ละมื้อมีอไรบ้างครับ , 3
# ผลไม้แต่ละวันสับเปลี่ยนบ้างไหมคะ , 3
# นักเรียนทานไม่หมดมีมาตรการยังไงบ้าง , 3
# สามารถเอาอาหารไปทานเองได้ไหมครับ , 3
# อาหารมีอะไรบ้าง , 3
# เมนูอาหารเดือนนี้ , 3
# อาหารของโรงเรียนมีอะไรบ้าง , 3
# เด็กต้องไปตักอาหารเองไหมคะ , 3
# ลูกอยากทานข้าวผัดจะมีมั้ยคะ , 3
# เมนูไก่ทอดจะมาอาทิตย์ไหนครับ , 3
# มีเมนูนํ้าอะไรให้บ้างครับเวลาทานอาหาร , 3
# มีอาหารสำหรับนักเรียนอิสลามมั้ยครับ , 3
# นักเรียนอิสลามนั่งตรงไหนหรอครับ , 3
# ลูกแพ้อาหารโรงเรียนมีอาหารแยกมั้ยคะ , 3
# ลูกแพ้อาหารทะเลมีอาหารอื่นทดแทนไหม , 3
# แพ้พวกนมมีเมนูอื่นทดแทนไหมครับ , 3
# แพ้อาหารทะเลสามารถแจ้งได้ที่ไหนบ้าง , 3
# แพ้อาหารแจ้งไว้ที่คุณครูท่านไหน , 3
# เดือนหน้้ามีเมนูอาหารอะไรบ้างหรอคะ , 3
# มีเมนูอาหารสำหรับนักเรียนอิสลามโดยเฉพาะไหม , 3
# อาหารถูกตามหลักฮาลาลหรือไม่ , 3
# มีการฆ่าเชื้อโดยการนำภาชนะแช่นำ้ร้อนไหมคะ , 3
# ล้างช้อนส้อมโดยนำ้ร้อนหรือป่าว , 3
# มีการใช้ช้อนกลางหรือทัพพีในการตักอาหารมั้ยคะ , 3
# อาหารเค็มมากไหมคะ , 3
# ปกติแล้้วใครเป็นคนคุมคุณภาพอาหารของโรงเรียนหรอคะ , 3
# อาหารมีการจัดเตรียมนานมั้ยคะก่อนที่เด็กจะลงมาทาน , 3
# อาหารกลางวันซื้อมาหรือว่าทำเองคะ , 3
# ลูกอยากทานบะหมี่ค่ะอาทิตย์หน้ามีมั้ย , 3
# มีแจกนมกล่องหลังอาหารหรือเวลาว่างมั้ยครับ , 3
# เมนูอาหารของพรุ่งนี้มีอะไรบ้าง , 3
# มีแกงมั้ยคะในเมนูอาหาร , 3
# ลูกอยากทานข้าวผัดวันนี้มีไหมครับ , 3
# สามารถพกจานไปใช้ส่วนตัวได้ไหม , 3
#  สวัสดีค่ะ ไม่ทราบว่าทางโรงเรียนจะมีขายชุดนักเรียนวันไหนหรอคะ , 3
# ชุดนักเรียน จะเปิดขายเมื่อไหร่ครับ กลัวว่าถ้าโรงเรียนเปิด 14 มิถุนา แล้วน้องจะไม่มีชุด (ชุดเดิมใส่ไม่ได้แล้ว) , 3
# นักเรียนที่ขึ้นชั้นประถม 4 เปลี่ยนเครื่องแบบใช่ไหมคะ แล้วสามารถซื้อชุดได้วันไหนค่ะ , 3
# ชุดนักเรียนชั้น ม.4 ซื้อได้วันไหนค่ะ , 3
# เริ่มจำหน่ายชุดนักเรียนวันไหนค่ะ จะส่งปักด้วยค่ะ ขอบคุณค่ะ , 3
# วันที่17พค.​คือให้ซื้อหนังสือและชุดใช่ไหมคะ​ , 3
# ชุดพละราคาเท่าไหร่คะ , 0
# ขอเบอร์โทรของโรงเรียนหน่อยค่ะ , 0
# โทรหาโรงเรียนได้ที่ไหนบ้าง , 0
# โทรหาทางโรงเรียนได้ช่วงเวลาไหนบ้าง , 0
# อยากติดต่อโรงเรียน , 0
# ติดต่อได้ที่ไหนบ้าง , 0
# ติดต่อได้ที่ี่ช่องทางไหนเพิ่มเติมได้บ้างครับ , 0
# เวลานี้มาสามารถติดต่อได้ไหม , 0
# ขอเบอติดต่อของโรงเรียน , 0
# อยากโทรหาโรงเรียนครับเรื่องลูก , 0
# อยากทราบเบอร์ติดต่อของโรงเรียนค่ะ , 0
# อยากได้เบอร์โทรหาโรงเรียนค่ะ , 0
# เวลานี้สามารถติดต่อโรงเรียนได้ไหม , 0
# ขอไลน์ภาค EP หน่อยค่ะ , 5
# มีช่องทางไลน์ให้ติดต่อมั้ยคะภาค EP , 5
# สอนเสริมวันเสาร์โครงการ EP  ช่วงไหน ช่วงบ่ายหรือเช้าคะ , 5
# ภาค ep มีไลน์ให้ติดต่อมั้ยคับ , 5
# จองวัน - เวลาในการรับฟังการแนะนำ ep ยังไงคะ , 5
# ขอเบอร์ติดต่อ ep หน่อยค่ะ , 5
# จะติดต่อโครงการ EP ได้ยังไงคะ , 5
# อยากทราบค่าเทอมโครงการอีพี , 5
# ติดต่อแผนกอีพีได้ที่ไหน , 5
# โครงการอีพีรับเด็กอนุบาลไหม , 5
# อีพีมีเรียนเสริมช่วงไหนบ้างครับ , 5
# ขอช่องการติดต่อโครงการอีพีหน่อยค่ะ , 5
# epมีอาจารย์จากต่างประเทศมาสอนไหมคะ , 5
# อีพีสอนเป็นภาษาไทยหรือภาษาอังกฤตครับ , 5
# epมีอาจารย์์จากประเทศไหนบ้างครับ , 5
# epจำเป็นต้องมีพื้นฐานอะไรบ้างคะ , 5
# ไม่มีพื้นฐานทางด้านภาษาอังกฤตสามารถสมัครโครงการepได้ไหม , 5
# โครงการepมีสอบวัดระดับไหม , 5
# อีพีต้องมีการเตรียมตัวอย่างไรบ้าง , 5
# ลูกพูดได้แต่ภาษาไทยสามารถสมครโครงการepได้ไหมคะ , 5
# ถ้าลูกไม่มีพื้นทางด้านภาษาสามารถสมัครโครงการอีพีได้ไหม , 5
# อีพีเปิดสมัครชั้นไหนบ้าง , 5
# epเปิดสมัครชั้นไหนบ้าง , 5
# แผนการสอนของโครงการอีพีเป็นอย่างไรบ้าง , 5
# โครงการอีพีมีีเข้าแถวตอนเช้ามั้ยคะ , 5
# อยากดูรูปห้องเรียนของโครงการepค่ะ , 5
# โครงการอีพีอัตราส่วนระหว่างนักเรียนกับครูต่อห้องเป็นเท่าไหร่คะ , 5
# epมีนักเรียนกี่คนต่อห้องครับ , 5
# อีพีมีครูประจำชั้นหรือครูพี่เลี้ยงมั้ยครับ , 5
# โครงการอีพีทีกี่ห้องครับ , 5
# เด็กในแต่ละห้องepมีประมาณกี่คนครับ , 5
# epมีแอร์ทุกห้องไหม , 5
# โครงการepมีเครื่องปรับอากาศทุกห้องไหมครับ , 5
# โครงการอีพีมีกฎระเบียบอย่างไรบ้าง , 5
# epต้องเครียมอะไรไปเรียนบ้าง , 5
# epสามารถนำipadไปเรียนได้ไหมครับ , 5
# โครงการอีพีสามารถนำแท็ปเลตเข้าไปเรียนได้ไหมครับ , 5
# โครงการอีพีสามารถพกอุปกรณ์สื่อสารเข้าห้องเรียนได้ไหมคะ , 5
# จะมีการเปิดบ้านของโครงการอีพีไหมคะ , 5
# อีพีมีการเปิดบ้านไหมคะจะได้พาลูกไปดู , 5
# จะมีการจัดopen house ของโครงการepไหมคะ , 5
# พ่อแม่สามารถดูตัวอย่างการเรียนการสอนโครงการepได้ที่ไหนคะ , 5
#  ค่าเทอม EP ของ ม.1 เท่าไหร่คะ , 0
# ตอนนี้ติดต่อได้ไหม , 0
# อยากติดต่อโรงเรียนค่ะ , 0
# โรงเรียนตั้งอยู่ไหนคะ , 0
# ติอต่อโรงเรียนยังไงได้บ้าง , 0
# ติอต่อโรงเรียนยังไง , 0
# อยากได้ช่องทางการติดต่อ , 0
# โทรหาโรงเรียนได้ที่ี่เบอร์อะไรคะ , 0
# อยากโทรหาโรงเรียนค่ะต้องโทรไปที่เบอร์ไหน , 0
# ติดต่อที่ทางเพจได้ไหมคะ , 0
# อยากติดต่อโรงเรียนเรื่ื่องลูกครับ , 0
# ลูกเป็นยังไงบ้างครับตอนนี้ , 8
# อยากเปิดร้ายขายอาหารในโรงเรียนต้องทำอย่างไรบ้าง , 8
# เปิดร้ายอาหารในโรงอาหารได้ไหม , 8
# สมัครเป็นครูต้องทำอย่างไรบ้าง , 8
# ตอนนี้มีตำเเหน่งอะไรเปิดรับบ้างครับ , 8
# หางานครับเปิดรับสมัครตำแหน่งอะไรบ้าง , 8
# จะมีเปิดคัดเลือกร้านอาหารในโรงเรียนเมื่อไหร่คะ , 8
# เช่าที่ขายของในโรงเรียนได้ไหม , 8
# สมัครขายอาหารในโรงเรียนต้องทำอย่างไรบ้าง , 8
# เปิดร้้านขายลูฏชิ้น ไส้กรอกในโรงเรียนได้ไหม , 8
# สามารถเช่าพื้นที่ในโรงเรียนขายของได้ไหมคะ , 8
# เช่าพื้นเล็กๆที่ภายในโรงเรียนได้ไหม , 8
# ค่าเช่าพื้นที่ร้านอาหารในโรงเรียนเท่าไหร่คะ , 8
# อยากขายนํ้าหวานในโรงเรียนตอนติดต่อที่ไหนคะ , 8
# อยากขายอุปกรณ์เครื่องเขียนในโรงเรียนติดต่อที่ไหนครับ , 8
# สมัครเป็นสหกรณ์ขายของภายในโรงเรียนติดต่อที่ไหน , 8
# อยากเปิดร้านขายเครื่องเขียนในโรงเรียนติดต่อที่ไหนคะ , 8
# เช่าพื้นที่ในโรงเรียนขายอุปกรณ์เครื่องเขียนได้มั้ย , 8
# สวัสดีครับจากเนสเล่นะครับ อยากเข้าไปจัดกิจกรรมภายในโรงเรียนต้องสามารถทำได้ไหมครับ , 8
# จะจัดกิจกรรมภายในโรงเรียนมีค่าใช้จ่ายอะไรบ้าง , 8
# จัดกิจกรรมภายในโรงเรียนมีเงื่อนไขอย่างไรบ้าง , 6
# ข​อ​ง​ ป.1​ ไม่มีคืนค่าเทอมหรือค่ะ , 6
# ทางรร.ไม่คืนค่าเทอมบ้างหรอค่ะ
#  , 6
# สอบถามเรื่องคืนค่าเทอมค่ะ , 6
# ค่าอาหารทางโรงเรียนจะคืนค่าอาหารกลางวันที่น้องไม่ได้ทานที่โรงเรียน หรือ ค่าใช้จ่ายบ้างส่วนคืนบ้างเปล่าครับ , 6
# คืนค่าอาหารกลางวันด้วยหรือเปล่าคะ , 6
# EP คืนค่าเทอมมั้ยคะ , 6
# ป.4 ปกติ คืนแค่ 500 บาท เองหรอค่ะ รวมหักค่าอาหารหรือยังค่ะ , 6
# สอบถามค่ะ แผนก English Program ไม่มีการจ่ายค่าเทอมคืนบ้างหรือค่ะ , 6
# โรงเรียนน่าจะเคลียร์เรื่องตัวเลขให้มากกว่านี้นะคะ สรุปคือคืนเท่าไหร่คืนยังไงคะ , 6
# ค่าอาหารกลางวันเด็กจะมีคืนด้วยหรือไม่ค่ะ , 6
# ค่าเรียนภาษาจีน ของอนุบาลมีคืนบ้างมั้ยคะ , 6
# ค่าห้องเรียนปรับอากาศของ อ.1 คืนมั้ยค่ะ , 6
# คืนค่าเทอมช่องทางไหนคะ , 6
# สอบถามคับ จะคืนค่าเทอมในช่องทางไหนหรอครับ , 6
# Ep มีคืนมัยคะ , 6
# จะต้องมีการคืน​เงินค่าอาหาร​ด้วยใช่ไหม เพราะทางโรงเรียน​เก็บเงินแบบจำนวนเต็ม​ไป ใช่หรือไม่คะ , 6
# เงินคืนค่าเรียนปรับพื้นฐานสรุปว่าทางโรงเรียนจะคืนให้ทางไหน และวันไหนคะ , 6
# สอบถามค่ะจะมีการคืนค่าชัมเมอร์ไหมคะ , 6
# ขอใบเสร็จมาเบิกได้เมื่อไรค่ะ , 6
# จะขอใบเสร๊จไปเบิกต้องทำไงคับ , 6
# ไปชำระค่าเทอมวันที่ 17พ.ค นี้ได้ไหมคะ เพราะต้องการใบเสร็จไปเบิกค่ะ , 6
# หาใบเสร็จค่าเรียนปรับพื้นฐานป.1ไม่เจอจะเบิกได้ไหมค่ะ , 6
# ขอผ่อนค่าเทอมกับโรงเรียนได้ไหมค่ะ , 6
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จมาเบิกค่ะ , 6
# เบิกค่าเล่าเรียนต้องใช้เอกสารอะไรบ้างในการไปยื่นคะ , 6
# ใช้บัตรกสิกร ผ่อน 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 6
# ชำระค่าเทอมสามารถชำระโดยใช้บัตรเครดิต tmb ได้ไหมคะ        , 6
# ค่าเทอมจ่ายทีเดียวหรือผ่อนจ่ายได้คะ , 6
# ใช้บัตรกสิกร ผ่อนค่าเทมอ 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 6
# ค่าเทอมขอผ่อนค่าเทอมกับโรงเรียนได้ไหมครับ , 6
# มีบัตรกสิกรอยู่แล้วสามารถผ่อนได้เลยไหมครับ , 6
# ชำระค่าเทอมผ่านธนาคารกสิกรได้ปกติใช่มั๊ยคะ , 6
# ค่าเรียนปรับพื้นฐาน ม.1ยังไม่คืนอีกหรอคะ , 6
# ชำระและส่งหลักฐานได้ตั้งแต่วันไหนคะ , 6
# สามารถให้ผ่อนชำระ หรือลดค่าเทอมบ้างมั้ยคับ  , 6
# ตอนคืนค่าเทอมไม่เห็นจะโอนกลับผ่าน Kbank แล้วให้เปิดไปทำไมครับ ??? , 6
# ชำระค่าเทอมทุกระดับชั้นเลยใช่ไหมครับเบอร์บัญชีเบอร์นี้ , 6
# วันที่ 8-9 พค. ยังมีรับชำระที่โรงเรียนอยู่หรือไม่ครับ , 6
# สามารถชำระค่าเทอมได้ช่องทางเดียวเหรอคะ , 6
# ผ่อนค่าเทอมมีค่าธรรมเนียมในการใช้บัตรไหมคะ , 6
# ขอเลขบัญชีในการจ่ายค่าเทอมหน่อยค่ะ , 6
# จ่าค่าเทอมล่าช้าแต่ไม่เกินวันที่4 ธันวาคมได้ไหมค่ะ , 7
# ขอสอบถามหน่อยครับ สีกางเกงของโรงเรียนเขาเรียกว่าสีอะไรนะครับ พอดีจะซื้อไปให้หลานแต่ไม่แน่ใจว่า
# เรียกสีนี้ว่าอะไร , 4
# วันที่ตรวจเครื่องกายตรวจไม่ผ่าน จะต้องทำยังไงคะ , 4
# ปักตรา รร.ข้างไหนคะ , 4
# ทางฝ่ายปกครองจะทำหนังสือแจ้ง ผปค นร ที่ขับขี่มอเตอร์ไซด์ มา รร เมื่อไหร่คะ , 4
# อยากให้ลูกเรียน รด ต้องอยู่ชั้นไหนคะ , 4
# ขออนุุญาติสอบถามค่ะ รูปถ่ายที่ใช้สมัคร รด.ต้องมีขนาดเท่าไหร่คะ , 4
# ขออสอบถามครับสำเนา ปพ.1 ที่จะต้องยื่นสมัคร รด.ต้องใช้หน้าหลังใช่ไหมครับ , 4
# สมัคร รด.ได้ช่วงไหนคะ , 4
# นักเรียนชายไว้ทรงนักเรียนได้อย่างเดียวเหรอคะ ไว้รองทรงได้มั้ยคะ , 4
# ขอระเบียบการแต่งกาย ม.ต้นหน่อยค่ะ , 4
# สวัสดีครับลูกมาบอกผมว่าโดนเพื่อนแกล้งทางโรงเรียนจัดการยังไงได้บ้างครับ , 4
# ลูกถูกเพื่อนแกล้งที่โรงเรียนค่ะ ตอนนี้ลูกไม่อยากไปโรงเรียนแล้วจะทำเรื่องขอพักการเรียนหรือย้ายห้องได้ไหมคะ , 4
# อยากทำเรื่่องพักการเรียนต้องทำอย่างไรบ้างครับ , 4
# ทำไมลูกถึงถูกพักการเรียนคะ , 4
# สวัสดีค่ะมีคุณครูท่านนึงพูดจาไม่ดีค่ะทำให้ลูกรู้สึกแย่ รบกวนตักเตือนครูได้ไหมคะ , 4
# เปิดกี่โมงคะ , 7
# ทางโรงเรียนมีเปิดรับสมัครเข้ ป. 1รอบ 2มั้ยคะ , 0
# ปริ้นใบสมัครไม่ได้ค่ะ , 0
# สมัครไปแล้ว ทำไมไม่มีรายชื่อคะ ต้องทำยังไงคะ , 1
# เข้าระบบลงทะเบียนไม่เห็นได้เลยค่ะ หน้าจอค้างแบบนี้ แก้ไขอย่างไรค่ะ , 9
# วันนี้ห้องเรียนพิเศษ สสวท มีคาบปฏิบัติมั้ยคะ , 9
# มีข้อสงสัยค่ะ microbit นี่สอนเฉพาะในเสริมวันเสาร์ใช่ไหมคะ? ในหลักสูตรปกติไม่เห็นมีสอน
# แถมเรียนมาจะครึ่งภาคเรียนที่สองแล้ว เพิ่งจะเริ่ม ให้ใช้ scratch ตามตำรา สสวท. ด้วย , 9
# ขอตารางการสอบคัดเลือกเข้าโครงการห้องเรียนพิเศษวิทยาศาสตร์หน่อยค่ะ , 9
# สอบคัดเลือกเข้าสสวท. เริ่มกี่โมงคะ , 9
# มีรูปงานแนะแนว สสวท วันนี้มั้ยคะ , 9
# รับสมัคร  ESMP เมื่อไหร่ครับ , 9
# ปรับพื้นฐาน ม.1 ESMP แต่งชุดอะไรครับ , 0
# ถ้าไปซื้อสมุดหนังสือหลังวันที่ 16/6 ต้องไปติดต่อที่ไหนคะ ขอบคุณค่ะ , 3
# วันนี้สหกรณ์เปิดขายชุดนักเรียนไหมคะ , 3
# ชุดนักเรียนจะมีเปิดจำหน่ายอีกไหมครับ , 3
# โรงเรียนควรเปิดเสาร์และอาทิตย์ขายสมุดและหนังสือบ้างนะครับเพราะผู้ปกครองวันธรรมดาต้องทำงานครับ , 1
# วันเสาร์-อาทิต เปิดหรือเปล่าคะ , 3
# เสาร์-อาทิตย์ สามารถไปซื้อชุดนักเรียนได้ไหมค่ะ
#  , 3
# มีขายชุดนักเรียนด้วยเปล่าคะ , 3
# ชุดนักเรียนซื้อได้วันไหนค่ะ
#  , 3
# ค่าเทอม ม.ปลาย จ่ายเมื่อไหร่คะ , 3
# ชุดนักเรียนเปิดจำหน่ายถึงเมื่อไรครับผม
#  , 1
# สมุดเปิดไหมค่ะ , 3
# ม.3ดูวิชาวิทย์ชั่วโมงสรุปสายใยอาหารและแบบทดสอบหลังเรียนไม่ได้ค่ะ ไม่มีคลิปขึ้น รบกวนแก้ไขด้วยค่ะ , 3
