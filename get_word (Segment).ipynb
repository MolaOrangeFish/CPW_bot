# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset_segment.csv')

df.drop('Unnamed: 0',
  axis='columns', inplace=True)
# df.drop('Unnamed: 3',
#   axis='columns', inplace=True)
df
# Out:
#                                                     txt  label
# 0     จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรีย...      0
# 1     ฝากถึงท่าน​ ผอ.​ที่กล่าวในการประขุม​ ผปค. ม6 เ...      0
# 2     คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหาย...      0
# 3     ขอความกรุณาผู้ปกครองอย่า start รถ ระหว่างรอเลย...      0
# 4                     เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ      0
# ...                                                 ...    ...
# 1663               รับสมัครถึงวันไหนค่ะ ยังสมัครทันมั้ย      2
# 1664                 อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ      2
# 1665                 อยากรู้ว่าม1จะขอเข้าสมัครได้ใหม่คะ      2
# 1666                         เสียค่าสมัครสอบเท่าไหร่ค่ะ      2
# 1667                               ใบสมัครใช้อะไรบ้างคะ      2
#
# [1668 rows x 2 columns]

# %%
# df = df.fillna(0)

df = df.replace({0.: '0', 1.: '1',2.: '2'})
df['label'].unique()
# Out:
# array(['0', '1', '2'], dtype=object)

# %%
df = df.applymap(str)
# Out:
# /tmp/ipykernel_46781/1614842595.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(str)

# %%
df
# Out:
#                                                     txt label
# 0     จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรีย...     0
# 1     ฝากถึงท่าน​ ผอ.​ที่กล่าวในการประขุม​ ผปค. ม6 เ...     0
# 2     คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหาย...     0
# 3     ขอความกรุณาผู้ปกครองอย่า start รถ ระหว่างรอเลย...     0
# 4                     เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ     0
# ...                                                 ...   ...
# 1663               รับสมัครถึงวันไหนค่ะ ยังสมัครทันมั้ย     2
# 1664                 อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ     2
# 1665                 อยากรู้ว่าม1จะขอเข้าสมัครได้ใหม่คะ     2
# 1666                         เสียค่าสมัครสอบเท่าไหร่ค่ะ     2
# 1667                               ใบสมัครใช้อะไรบ้างคะ     2
#
# [1668 rows x 2 columns]

# %%
df.to_csv("Dataset_segment.csv")

# %%
df["txt"][0]
# Out:
# 'จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรียน ทำรถติด แทนที่จะจัดรถเข้า\nทางออกทาง ให้เข้าออกปะปนกันไปหมด'

# %%
df["label"][0]
# Out:
# '0'

# %%
df["label"].unique()
# Out:
# array(['0', '1', '2'], dtype=object)

# %%
size = df.shape[0]

# %%
data1 = []

for i in range (size):
        data1.append(df["txt"][i])
        data1.append(df["label"][i])

# %%
from pythainlp.util import normalize
from pythainlp import word_tokenize
import string
import re
import csv
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from stop_words import get_stop_words
from pythainlp.util import normalize
import pandas as pd
th_stop_origin = tuple(thai_stopwords())
# append tuple thai stop word
th_stop = (th_stop_origin + ("สวัสดี", "ค่ะ", "เลย", "เรย","ๆ", "สุด", "นะคะ", "นะค่ะ", "ค่า", "อีกแล้ว","‼","⁉"))
en_stop = tuple(get_stop_words('en'))
def split_word(text):
    tokens = word_tokenize(text, engine='deepcut')  # แบ่งคำภาษาไทย

    # Remove stop words ภาษาไทย และภาษาอังกฤษ
    tokens = [i for i in tokens if not i in th_stop and not i in en_stop]

    # ลบช่องว่าง
    tokens = [i for i in tokens if not ' ' in i]

    return tokens

def clean_msg(msg):
    # ลบ text ที่อยู่ในวงเล็บ <> ทั้งหมด
    msg = re.sub(r'<.*?>', '', msg)
    # ลบ hashtag
    msg = re.sub(r'#', '', msg)
    # ลบ เครื่องหมายคำพูด (punctuation)
    for c in string.punctuation:
        msg = re.sub(r'\{}'.format(c), '', msg)
    # ทำให้ทุกคำต่อกัน
    msg = ' '.join(msg.split())
    # ลบ link https
    msg = re.sub(r'http\S+', '', msg)

    return msg
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def cleanning(text):
    return clean_msg(normalize(remove_emoji(text)))
    
def add_data_to_csv_with_deepcut(text,label):
    data=[]
    flag=0

    clean_text = cleanning(text)
    list_of_word = split_word(clean_text)
        
    temp_data=[list_of_word,str(label)]
    data.append(temp_data)
    with open('dataset/data(segment).csv', 'a',encoding="UTF8") as file:
        header = ['txt','label']
        writer = csv.writer(file)
        # if(flag == 0):
        #     flag=1
        #     writer.writerow(header)
        writer.writerows(data)

# %%
for i in range (0,len(data1),2):
    print(f"{data1[i]} , {data1[i+1]}")
    add_data_to_csv_with_deepcut(data1[i].lower(),data1[i+1])
# Out:
# จัดการจราจรแย่มาก ไม่คำนึงถึงพื้นที่รอบโรงเรียน ทำรถติด แทนที่จะจัดรถเข้า
# ทางออกทาง ให้เข้าออกปะปนกันไปหมด , 0
# 4/4 [==============================] - 0s 12ms/step
# ฝากถึงท่าน​ ผอ.​ที่กล่าวในการประขุม​ ผปค. ม6 เข้านี้นะคะ​ เรื่องการปรับปรุง​
# รร​ ให้ทันสมัย​ เช่น​ การเปลี่ยนโปรเจคเตอร์ในหอประชุมใหญ่เป็น​จอ led​  , 0
# 5/5 [==============================] - 0s 14ms/step
# คลิปวันวันต่อต้านยาเสพติดโลกเสียงเบาและขาดๆหายๆค่ะ มีกระตุกๆด้วย , 0
# 2/2 [==============================] - 0s 17ms/step
# ขอความกรุณาผู้ปกครองอย่า start รถ ระหว่างรอเลยนะครับ มลพิษสูงมาก
# สงสารเด็ก ( ลองวัด pm2.5 ดูได้ประมาณ119 ) , 0
# 4/4 [==============================] - 0s 14ms/step
# เห็นยอดแล้วปวดหัวรอเลยค่ะ ไม่ไหวๆ , 0
# 2/2 [==============================] - 0s 7ms/step
# น่าจะมีที่ฉีดดากในห้องน้ำได้แล้วครับครู ลำบากมาก  , 0
# 2/2 [==============================] - 0s 11ms/step
# กฎระเบียบไม่ดี เเถมยังตีเด็กอีก , 0
# 1/1 [==============================] - 0s 34ms/step
# ตอนเช้าๆรถติดสุดๆ พิจารณาด้วยครับ , 0
# 2/2 [==============================] - 0s 8ms/step
# ตรงประตูระวังเชือกผูกรองเท้าด้วยนะคะ อันตราย , 0
# 2/2 [==============================] - 0s 11ms/step
# ช่วงเวลาเย็นๆรถติดมาก ไม่เห็นคิดจะออกมาจัดการเลย ควรคิดได้แล้วนะครับ , 0
# 3/3 [==============================] - 0s 8ms/step
# ผึ้งจะเปิดเรียนจะไห้จ่ายค่าเทอมเลย ควรนึกถึงพ่อกับแม่บ้างนะให้ตายเถอะ , 0
# 3/3 [==============================] - 0s 11ms/step
# คนที่ไม่ได้ฉีดก็เรียนอยู่บ้านไปดิในเมื่อเลือกที่จะไม่ฉีดอ่ะ นักเรียนที่ฉีดมี 70%
# คนที่ไม่ฉีดมี 30% ทำไมต้องลากคนส่วนใหญ่ไปลำบากด้วยในเมื่อเลือกที่จะไม่ฉีด , 0
# 5/5 [==============================] - 0s 10ms/step
# ถามไปก็ไม่เคยมาอ่านหรือตอบ แย่มาก , 0
# 2/2 [==============================] - 0s 3ms/step
# สมัครให้ลูกเรียนห้องพิเศษ แอร์ 10800บาท แต่เรียนออนไลน์
# แล้วไม่มีช่วยเราบ้างเลย .....เสียความรู้สึกมากๆๆ , 0
# 4/4 [==============================] - 0s 9ms/step
# ควรคืนค่าเทอมห้อง EP เพราะว่าไม่ได้เรียนที่โรงเรียน เรียนที่บ้านทั้งเทอมเลย , 0
# 3/3 [==============================] - 0s 8ms/step
# ไม่ลดก็ช่วยค่าเน็ต+ค่าไฟที่ใช้ในการเรียนด้วยจ้าช่วงนี้โควิดระบาดทางผู้ปกครอง
# ก็ลำบากเหมือนกันเห็นใจบ้าง , 0
# 4/4 [==============================] - 0s 9ms/step
# เป็นการช่วยเหลือที่เล็กน้อยมาก ห่วยที่สุด , 0
# 2/2 [==============================] - 0s 5ms/step
# ในห้องน้ำควรมีทิชชู่ ยิ่งเด็ก ผญ สำคัญเรื่องความสะอาด และเด็กบางคน
# เห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0
# 4/4 [==============================] - 0s 10ms/step
# ในห้องน้ำควรมีทิชชู่ ยิ่งเด็ก ผญ สำคัญเรื่องความสะอาด และเด็กบางคน
# เห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0
# 4/4 [==============================] - 0s 10ms/step
# ในห้องน้ำควรมีทิชชู่ ยิ่งเด็ก ผญ สำคัญเรื่องความสะอาด และเด็กบางคน
# เห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0
# 4/4 [==============================] - 0s 10ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่
# เหมือนกัน พิจารณาแก้ไขด้วย , 0
# 3/3 [==============================] - 0s 10ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่
# เหมือนกัน พิจารณาแก้ไขด้วย , 0
# 3/3 [==============================] - 0s 10ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่
# เหมือนกัน พิจารณาแก้ไขด้วย , 0
# 3/3 [==============================] - 0s 10ms/step
# เรียนปกติแล้วทำไมให้รถเข้าออกได้ปกติ ทุกคนมีความป้องกันตัวเองอยู่
# แล้ว แบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน , 0
# 5/5 [==============================] - 0s 9ms/step
# เปิดเรียนปกติครบทุกระดับชั้นแต่ถ้าทางโรงเรียนไม่ให้ผู้ปกครองนำรถ
# เข้าโรงเรียนไปส่งเด็กๆมันคงจะแย่สำหรับผู้ปกครองหลายๆคนนะค่ะ
# รบกวน รร. ลองลงมาดูลานจอดรถใหม่ตอนเช้าตอนเย็นบ้างนะค่ะว่ารถ
# มันติดแค่ไหน , 0
# 7/7 [==============================] - 0s 11ms/step
# เปิดเรียนปกติครบทุกระดับชั้นแต่ถ้าทางโรงเรียนไม่ให้ผู้ปกครองนำรถ
# เข้าโรงเรียนไปส่งเด็กๆมันคงจะแย่สำหรับผู้ปกครองหลายๆคนนะค่ะ
# รบกวนรร. ลองลงมาดูลานจอดรถใหม่ตอนเช้าตอนเย็นบ้างนะค่ะว่ารถ
# มันติดแค่ไหน , 0
# 7/7 [==============================] - 0s 11ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​เพราะถ้าเปิด
# เต็มรูปแบบรถคงติดมาก , 0
# 3/3 [==============================] - 0s 11ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​เพราะถ้าเปิด
# เต็มรูปแบบรถคงติดมาก , 0
# 3/3 [==============================] - 0s 11ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​เพราะถ้าเปิด
# เต็มรูปแบบรถคงติดมาก , 0
# 3/3 [==============================] - 0s 8ms/step
# ช่วยพิจารณาการขับรถไปเทียบส่งหน้าตึก แบบไม่จอด ด้วยค่ะ ตอนนี้แค่
# เรียนวันเว้นวันก็ไม่ทันแล้วที่จอดไม่พอ เด็กอนุบาลยังต้องใช้เวลาเดินเข้า
# ไปส่งอีก เปิดมา 2 เดือนแล้วที่จอดรถก็ยังสร้างไม่เสร็จเลย
# ช่วยพิจารณาด้วยนะคะ , 0
# 7/7 [==============================] - 0s 9ms/step
# เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน
# แน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ
# 20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี
# รถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น
# มากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้
# รับความกรุณาพิจารณาด้วย , 0
# 12/12 [==============================] - 0s 12ms/step
# เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน
# แน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ
# 20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี
# รถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น
# มากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้
# รับความกรุณาพิจารณาด้วย , 0
# 12/12 [==============================] - 0s 10ms/step
# เรื่องรถรับส่งนักเรียนเด็กนักเรียนทุกคนอยากไปโรงเรียนเช้าแต่รถนักเรียน
# แน่นมากจนไม่มีที่นั่งเห็นลูกหลานไปนั่งตรงที่ไม่ไช่ที่นั่งเด็กในรถประมาณ
# 20 คนหรือมากกว่านั้นมีความคิดเห็นว่าตอนเช้าสายที่มีเด็กมากหน้าจะมี
# รถ 2 คัน เสียเงินก็เสียเท่ากันแต่ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่น
# มากสังเกตุมาหลายอาทิศ แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้
# รับความกรุณาพิจารณาด้วย , 0
# 12/12 [==============================] - 0s 10ms/step
# เปิดประตู 3 เพื่ออะไร ไม่ได้ช่วยอะไรเลย โรงเรียนจะต้องเปิด ประตู 4 และ
# ประตู 5 เพื่อช่วยระบายรถ ที่ลานจอดรถ ในช่วงเช้า 6.00 - 8.30 น. และ
# ช่วงบ่าย 15.30 - 18.00 น. ทุกวันนี้ประชาชนที่สัญจรผ่านไป-มา หน้า
# โรงเรียนต่างก็ไม่พอใจในการบริหารจัดการด้านการจราจรของโรงเรียน
# เป็นอย่างมากแล้วค่ะ , 0
# 9/9 [==============================] - 0s 12ms/step
# ไม่เข้าใจรรคืนเงินทีไรคนบ่นกันจัง ลูกชายคนโตเรียนโครงการพิเศษของ
# รร รัฐบาล ค่าเทอมก็เกือบสองหมื่นคืนเงินมาแค่ 1380 ไม่เห็นมี ผปค
# โพสบ่นในเพจรร แต่นี่ รร เอกชนขนาดภาคปกติยังคืนเยอะกว่ารรรัฐบาล
# อีก คนบ่นกันจัง😞 , 0
# 7/7 [==============================] - 0s 9ms/step
# อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจน และเพียงพอด้วยครับ​
# ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ ลูกก็รอไปจนกลับ
# คนสุดท้ายของห้อง​ เกรงใจคุณครูที่รอเราคนเดียว​ , 0
# 6/6 [==============================] - 0s 9ms/step
# อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจน และเพียงพอด้วยครับ​
# ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ ลูกก็รอไปจนกลับ
# คนสุดท้ายของห้อง​ เกรงใจคุณครูที่รอเราคนเดียว​ , 0
# 6/6 [==============================] - 0s 11ms/step
# แต่ของลูกเป็นการตักรอบแรกนะคะ ถ้ามันไม่พอแสดงว่าไม่มีใครได้รอบ
# สองแน่นอน ช่วยพิจารณาหน่อยนะคะเพราะว่าเป็นการตักรอบแรกค่ะ , 0
# 4/4 [==============================] - 0s 10ms/step
# จัดเวลาการเรียนการสอนน้อยเร่งรัดทุกเรื่องผลการเรียนจะเป็นอย่างไรไม่รู้
# เอาแต่จะตัดระบบให้เป็นปัจุบันในการทำงานของหน่อยงานตนเอง , 0
# 4/4 [==============================] - 0s 10ms/step
# กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth
# ด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์
# เอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก , 0
# 7/7 [==============================] - 0s 9ms/step
# กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth
# ด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์
# เอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก , 0
# 7/7 [==============================] - 0s 11ms/step
# กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth
# ด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์
# เอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก , 0
# 7/7 [==============================] - 0s 9ms/step
# กระตุก กระตุก จนนิ่งไปเลยครับ โรงเรียนควรพิจารณาเรื่องของ bandwidth
# ด้วยนะครับ นักเรียนหลายพันคนเข้าใช้ระบบพร้อมๆ กัน แบบนี้ขอเป็นไฟล์
# เอกสาร หรือ vdo แบบ offline ให้ลูกเรียนน่าจะดีกว่าครับ แย่มาก , 0
# 7/7 [==============================] - 0s 11ms/step
# รบกวนคุณครูปรับปรุงเรื่องการออกเสียง ร,ล ให้ชัดเจนด้วยนะคะ !
# โดยเฉพาะวิชาภาษาไทย ขอบคุณค่ะ  , 0
# 3/3 [==============================] - 0s 9ms/step
# ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม
# คลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ
# วานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก
# ษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา
# บ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ , 0
# 10/10 [==============================] - 0s 12ms/step
# ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม
# คลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ
# วานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก
# ษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา
# บ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ , 0
# 10/10 [==============================] - 0s 11ms/step
# ระดับ ป 4 วันนี้ 5/01/64 มีคลิปการเรียนการสอน เพื่ม กระตุก เหมือนเดิม
# คลิปเมื่อวาน (เด็กๆยังเรียนไม่ได้เลยเพราะกระตุกดูไม่ได้) พอไปค้นของเมื่อ
# วานของเก่าของใหม่นี่ก็มั่วไปหมด ไม่พร้อมก็คือไม่พร้อมคะ ระดับ มัธยมศึก
# ษาดูได้ ประถมดูไม่ได้ ชำระเงินเหมือนกันนะคะ ให้คุณนิตยา รับทราบปัญหา
# บ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆคะ , 0
# 10/10 [==============================] - 0s 11ms/step
# โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย
# วิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ
# ยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ , 0
# 6/6 [==============================] - 0s 10ms/step
# โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย
# วิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ
# ยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ , 0
# 6/6 [==============================] - 0s 12ms/step
# โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย
# วิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ
# ยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ , 0
# 6/6 [==============================] - 0s 11ms/step
# โปรดพิจารณา สำหรับแผนก ep บางวิชาที่เรียนเป็นภาษาอังกฤษ ซึ่งมีหลาย
# วิชาพอสมควร น่าจะสอนแบบออนไลน์สดนะคะ เพราะถ้าเด็กไม่เข้าใจ
# ยังสามารถสอบถาม T. กับTA. ประจำวิชาได้ค่ะ ถ้าเป็นแบบนี้ไม่โอเคนะคะ , 0
# 6/6 [==============================] - 0s 10ms/step
# วันนี้ก็ยังกระตุกอยู่เลยครับ..เด็กเรียนไม่รู้เรื่องเลย มาๆ หยุดๆ..รบกวนช่วย
# แก้ไขโดยด่วนด้วยครับ..เมื่อวานนี้ของ ป.4 มี 13 วิชา เรียนจนจบได้แค่ 3
# วิชาเอง ในช่วงครึ่งวัน..วันนี้เหลือแค่ 4 วิชา ยังกระตุกเหมือนเดิม.. , 0
# 7/7 [==============================] - 0s 10ms/step
# สรุปเลยนะคะ การเรียนออนไลน์ระดับประถม ไม่มีการปรับปรุงให้ดีขึ้น เช่น
# เสียงจากคลิป ฟังไม่รู้เรื่อง อุปกรณ์ รร ให้คุณครูลงทุนกันเองหรอคะ เสียง
# พูดได้ยินดับๆหายๆ รร ควรลงทุนอุปกรณ์ให้คุณครูนะคะ เช่น ไมค์ในการ
# อัดคลิป เรื่องภาพก็อีกเรื่องนึง แต่เรื่องเสียงนี่สำคัญที่สุด เพราะ นร. ต้อง
# ฟังที่คุณครูอธิบาย กลายเป็นว่า ทำงานซ้ำซ้อน ขอให้ รร ลงทุนอุปกรณ์
# ให้ครูด้วยนะคะ , 0
# 12/12 [==============================] - 0s 10ms/step
# สรุปเลยนะคะ การเรียนออนไลน์ระดับประถม ไม่มีการปรับปรุงให้ดีขึ้น เช่น
# เสียงจากคลิป ฟังไม่รู้เรื่อง อุปกรณ์ รร ให้คุณครูลงทุนกันเองหรอคะ เสียง
# พูดได้ยินดับๆหายๆ รร ควรลงทุนอุปกรณ์ให้คุณครูนะคะ เช่น ไมค์ในการ
# อัดคลิป เรื่องภาพก็อีกเรื่องนึง แต่เรื่องเสียงนี่สำคัญที่สุด เพราะ นร. ต้อง
# ฟังที่คุณครูอธิบาย กลายเป็นว่า ทำงานซ้ำซ้อน ขอให้ รร ลงทุนอุปกรณ์
# ให้ครูด้วยนะคะ , 0
# 12/12 [==============================] - 0s 11ms/step
# คลิปค้างและกระตุกมากค่ะเป็นเกือบทุกวิชาค่ะ ตั้งแต่เช้าจนถึงตอนนี้ค่ะ
# ดูไม่รู้เรื่องเลยค่ะ , 0
# 3/3 [==============================] - 0s 9ms/step
# คลิปค้างและกระตุกมากค่ะเป็นเกือบทุกวิชาค่ะ ตั้งแต่เช้าจนถึงตอนนี้ค่ะ
# ดูไม่รู้เรื่องเลยค่ะ , 0
# 3/3 [==============================] - 0s 12ms/step
# vdo กระตุกมากโหลดช้ามากดูแล้วสะดุดมาก ไม่รู้เรื่องเลยในการดูแต่ละวิชา , 0
# 3/3 [==============================] - 0s 8ms/step
# vdo กระตุกมากโหลดช้ามากดูแล้วสะดุดมาก ไม่รู้เรื่องเลยในการดูแต่ละวิชา , 0
# 3/3 [==============================] - 0s 7ms/step
# เว็ปโรงเรียนโหลดนานมาก พอเปิดได้คลิปกระตุกดูไม่รู้เรื่องเลยค่ะ , 0
# 2/2 [==============================] - 0s 10ms/step
# เว็ปโรงเรียนโหลดนานมาก พอเปิดได้คลิปกระตุกดูไม่รู้เรื่องเลยค่ะ , 0
# 2/2 [==============================] - 0s 10ms/step
# ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง
# เรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก
# นั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม
# ที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ , 0
# 9/9 [==============================] - 0s 12ms/step
# ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง
# เรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก
# นั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม
# ที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ , 0
# 9/9 [==============================] - 0s 10ms/step
# ควรพิจารณาเรื่องการเรียนผ่าน zoom ด้วยคะ โรงเรียนต่างจังหวัดเค้ายัง
# เรียนผ่านโปรแกรมนี้เลยคะ อย่างน้อยก็มีการตอบโต้กับนักเรียน ไม่ใช่ให้เด็ก
# นั่งฟังอย่างเดียว ไม่ใช่ครูทุกคนที่จะสอนให้น่าสนใจหรือน่านั่งฟังเลยคะ เทอม
# ที่แล้วแม่นั่งฟังกับลูกยังน่าเบื่อเลยคะ รบกวนพิจารณาคะ , 0
# 9/9 [==============================] - 0s 10ms/step
# ทาง รร ควรซื้อแอพ Zoom premium ให้ครูด้วยค่ะ เวลาแค่ 40 นาทีจากแอพ
# zoom ฟรี มันไม่พอ ในกรณีสอนสดกว่าจะรอให้นักเรียนมาครบกินเวลาไปกว่า 10
# นาทีเลย เผื่อเวลาเน็ตหลุดด้วย เสียเวลามากเรียนก็ไม่ต่อเนื่อง ไม่เต็มที่ ยิ่งเด็ก
# ม.ปลายนี่ไม่ต้องพูดถึงเลย เด็กๆบ่นกันเยอะมากค่ะ , 0
# 9/9 [==============================] - 0s 9ms/step
# ทาง รร ควรซื้อแอพ Zoom premium ให้ครูด้วยค่ะ เวลาแค่ 40 นาทีจากแอพ
# zoom ฟรี มันไม่พอ ในกรณีสอนสดกว่าจะรอให้นักเรียนมาครบกินเวลาไปกว่า 10
# นาทีเลย เผื่อเวลาเน็ตหลุดด้วย เสียเวลามากเรียนก็ไม่ต่อเนื่อง ไม่เต็มที่ ยิ่งเด็ก
# ม.ปลายนี่ไม่ต้องพูดถึงเลย เด็กๆบ่นกันเยอะมากค่ะ , 0
# 9/9 [==============================] - 0s 11ms/step
# ทาง รร ควรซื้อแอพ Zoom premium ให้ครูด้วยค่ะ เวลาแค่ 40 นาทีจากแอพ
# zoom ฟรี มันไม่พอ ในกรณีสอนสดกว่าจะรอให้นักเรียนมาครบกินเวลาไปกว่า 10
# นาทีเลย เผื่อเวลาเน็ตหลุดด้วย เสียเวลามากเรียนก็ไม่ต่อเนื่อง ไม่เต็มที่ ยิ่งเด็ก
# ม.ปลายนี่ไม่ต้องพูดถึงเลย เด็กๆบ่นกันเยอะมากค่ะ , 0
# 9/9 [==============================] - 0s 10ms/step
# ขอโทษนะคะกดเข้าไปในวีดีโอเปิดไม่ได้ค่ะเปิดติดบ้างไม่ติดบ้างค่ะ ช่วยแก้ไข
# หน่อยค่ะ เป็นแบบนี้บ่อยๆไม่ไหวนะคะ , 0
# 4/4 [==============================] - 0s 9ms/step
# ช่วยแก้ไขหน่อยนะคะ เปิดไม่ได้เลยคะ ลองใช้ทั้ง WiFi และ 5G ก็เปิดไม่ได้คะ
# เปิดติดบ้างไม่ติดบ้าง เซ็งคะ , 0
# 4/4 [==============================] - 0s 7ms/step
# ช่วยแก้ไขหน่อยนะคะ เปิดไม่ได้เลยคะ ลองใช้ทั้ง WiFi และ 5G ก็เปิดไม่ได้คะ
# เปิดติดบ้างไม่ติดบ้าง เซ็งคะ , 0
# 4/4 [==============================] - 0s 9ms/step
# จัดซัมเมอรไปเลยคะ ดิฉันไม่ให้ลูกไปเรียนแน่นอน ถือว่าทำบุญให้ รร. คะอันตราย
# ขนาดนี้ ยังคิดจะจัดสอนซัมเมอร์อีก โควิดวันนี้ คนติดเพิ่มอีกเป็นพันคน เด็กๆติดมา
# ถึงหายก็ปอดหายไปครึ่งนึง อนาคตสุขภาพเด็กคงแย่ , 0
# 7/7 [==============================] - 0s 11ms/step
# จัดซัมเมอรไปเลยคะ ดิฉันไม่ให้ลูกไปเรียนแน่นอน ถือว่าทำบุญให้ รร. คะอันตราย
# ขนาดนี้ ยังคิดจะจัดสอนซัมเมอร์อีก โควิดวันนี้ คนติดเพิ่มอีกเป็นพันคน เด็กๆติดมา
# ถึงหายก็ปอดหายไปครึ่งนึง อนาคตสุขภาพเด็กคงแย่ , 0
# 7/7 [==============================] - 0s 11ms/step
# เรื่องวันซื้อ - ขายอุปกรณ์การเรียน คิดว่าเสี่ยงเกินไปคะ เพราะเป็นการรวมกลุ่มคน
# จำนวนมาก , 0
# 3/3 [==============================] - 0s 10ms/step
# ช่วยดูด้วยค่ะวาาเด็ก ม.6 รุ่นนี้เดือดร้อนมากเเค่ไหนพลาดโอกาสหลายอย่างยัง
# ต้องพลาดที่เรียนอีก , 0
# 3/3 [==============================] - 0s 11ms/step
# ทางโรงเรียน​ จะต้องเร่งแก้ไขให้นะคะ​ ไม่ใช่ให้เด็กนักเรียน​หรือ​ ผู้ปกครอง​ จะต้อง
# เป็นคนประสานเองนะคะ​ เพราะได้แจ้งรายละเอียด​ และ​ ปัญหา​ ไว้ให้พิจารณา
# หมดแล้ว​ ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ*** , 0
# 7/7 [==============================] - 0s 10ms/step
# ทางโรงเรียน​ จะต้องเร่งแก้ไขให้นะคะ​ ไม่ใช่ให้เด็กนักเรียน​หรือ​ ผู้ปกครอง​ จะต้อง
# เป็นคนประสานเองนะคะ​ เพราะได้แจ้งรายละเอียด​ และ​ ปัญหา​ ไว้ให้พิจารณา
# หมดแล้ว​ ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ*** , 0
# 7/7 [==============================] - 0s 9ms/step
# ห้องน้ำนักเรียนอาคาร 8 อับชื้นและสกปรกมาก รบกวนตรวจด้วยนะคะ , 0
# 2/2 [==============================] - 0s 9ms/step
# ห้องน้ำนักเรียนอาคาร 8 อับชื้นและสกปรกมาก รบกวนตรวจด้วยนะคะ , 0
# 2/2 [==============================] - 0s 13ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้แล้วนะคะ... , 0
# 2/2 [==============================] - 0s 8ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้แล้วนะคะ... , 0
# 2/2 [==============================] - 0s 8ms/step
# ให้ไก่มาน้อยมากเลยคะ อยากให้ดูแลเรื่องปริมาณอาหารให้ด้วยค่ะ , 0
# 2/2 [==============================] - 0s 8ms/step
# กระตุกมากค่หยุดๆะ เล่นๆ ตลอดเลยค่ะ  เสียอารมณ์ค่ะ , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุกมากค่หยุดๆะ เล่นๆ ตลอดเลยค่ะ  เสียอารมณ์ค่ะ , 0
# 2/2 [==============================] - 0s 8ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน ห่วยมาก , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน ห่วยมาก , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุกบ่อย​ file ค้างมากๆๆเลยค่ะ​ 😅😅 เด็ก​เดินหนีไปแล้วค่ะ , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุกทุกคลิปเลย เรียนไม่ได้เลยค่ะ แย่ที่สุด , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุกทุกคลิปเลย เรียนไม่ได้เลยค่ะ แย่ที่สุด , 0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกบ่อยมากค่ะ โหลดๆหยุดๆ 😞 , 0
# 1/1 [==============================] - 0s 27ms/step
# เข้าดูไม่ได้เลยครับ ทั้งกระตุกทั้งค้างครับ 😞 , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุกๆ ค้างๆ กว่าจะผ่านไปแต่ละวิชาใช้เวลานานมาก แย่มาก , 0
# 2/2 [==============================] - 0s 10ms/step
# กระตุกๆ ค้างๆ กว่าจะผ่านไปแต่ละวิชาใช้เวลานานมาก แย่มาก , 0
# 2/2 [==============================] - 0s 10ms/step
# กระตุกสะดุดตลอด ทุกวิชา ไม่สามารถเรียนได้เลยแบบนี้เด็กก็แย่สิคับ , 0
# 2/2 [==============================] - 0s 14ms/step
# กระตุกสะดุดตลอด ทุกวิชา ไม่สามารถเรียนได้เลยแบบนี้เด็กก็แย่สิคับ , 0
# 2/2 [==============================] - 0s 10ms/step
# clip กระตุก ช่วยแก้ไข หน่อยค่ะ!! , 0
# 1/1 [==============================] - 0s 30ms/step
# ป.2 ป.4 เปิดเข้าดู VDO ไม่ได้เลยค่ะ ไม่ไหวนะคะแบบนี้ , 0
# 2/2 [==============================] - 0s 9ms/step
# ยังกระตุกอยู่เลยค่ะเรียนไม่ได้เลยค่ะ เสียเวลามากค่ะ , 0
# 2/2 [==============================] - 0s 6ms/step
# ยังกระตุกอยู่เลยค่ะเรียนไม่ได้เลยค่ะ เสียเวลามากค่ะ , 0
# 2/2 [==============================] - 0s 9ms/step
# กระตุกทุกlink. ห่วยคะ , 0
# 1/1 [==============================] - 0s 25ms/step
# กระตุกทุกlink. ห่วยคะ , 0
# 1/1 [==============================] - 0s 27ms/step
# โรงเรียนดำเนินการช้ามากเลยค่ะ แบบนี้ก็ไม่ไหวนะคะ , 0
# 2/2 [==============================] - 0s 8ms/step
# ควบคุมการผลิตให้ดี เพิ่มโปรตีนด้วยนะครับ ไม่ใช่มีแต่ผักกับผลไม้ ห่วยมากก , 0
# 3/3 [==============================] - 0s 10ms/step
# ได้รับข้อมูลแล้ว กรุณานำไปพิจารณาด้วยนะครับไม่ใช่ขอบคุณอย่างเดียว , 0
# 3/3 [==============================] - 0s 8ms/step
# เมนูก๋วยเตี๋ยวน้องผมบ่นว่ากินแต่หมี่ๆอย่างเดียว 😅 , 0
# 2/2 [==============================] - 0s 7ms/step
# ช่วยไปพิจารณาให้เข้ากับเหตุการณ์ที่ต้องเจอ คาดว่าน่าคงอีกยาวค่ะ , 0
# 2/2 [==============================] - 0s 10ms/step
# วันนี้ก็มีน้ำซุปฟักลูกบอกว่าจืดอย่างกะน้ำเปล่าเลยค่ะ ปรับปรุงด้วยค่ะ 😂😂😂 , 0
# 3/3 [==============================] - 0s 7ms/step
# กับข้าวของอิสลามลูก และ เพื่อนๆบอกว่าเผ็ดมากค่ะ รบกวนช่วยแก้ไขด้วยนะคะ , 0
# 3/3 [==============================] - 0s 6ms/step
# ติดป้ายลดความเร็วเพิ่มเติมน่าจะดีนะคะ ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่เพียบ , 0
# 3/3 [==============================] - 0s 8ms/step
# ติดป้ายลดความเร็วเพิ่มเติมน่าจะดีนะคะ ฝุ่นปูนลอยเข้าหน้าต่าง เด็ก ๆ นั่งอยู่เพียบ , 0
# 3/3 [==============================] - 0s 8ms/step
# เส้นใหญ่ กะทิ เป็นสิ่งที่เสียง่าย ควรหลีกเลี่ยง มาทำอาหารให้เด็กๆ วันนี้เด็ก
# ปวดท้อง ท้องเสีย หลายคนคะ , 0
# 4/4 [==============================] - 0s 8ms/step
# เส้นใหญ่ กะทิ เป็นสิ่งที่เสียง่าย ควรหลีกเลี่ยง มาทำอาหารให้เด็กๆ วันนี้เด็ก
# ปวดท้อง ท้องเสีย หลายคนคะ , 0
# 4/4 [==============================] - 0s 8ms/step
# เด็กๆ บอกข้าวแข็งค่ะ เมื่อวาน , 0
# 1/1 [==============================] - 0s 27ms/step
# เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0
# 3/3 [==============================] - 0s 7ms/step
# เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวัน ไม่ดีค่ะ , 0
# 3/3 [==============================] - 0s 7ms/step
# ได้ปรับปรุงเรื่องรสชาติยังค่ะ แจ้งตั้งแต่เทอมที่แล้วต้มจืดก็จืดมาก , 0
# 3/3 [==============================] - 0s 9ms/step
# หวังว่าเปิดเทอมนี้จะได้ฟังจากลูกเรื่องรสชาติและปริมาณที่เหมาะสมนะคะ , 0
# 3/3 [==============================] - 0s 7ms/step
# เพิ่มปริมาณอาหารให้พอกับความต้องการด่วนเลยค่ะ ห่วยตั้งแต่เปิดเทอม!! , 0
# 3/3 [==============================] - 0s 7ms/step
# เพิ่มปริมาณอาหารให้พอกับความต้องการด่วนเลยค่ะ ห่วยตั้งแต่เปิดเทอม!! , 0
# 3/3 [==============================] - 0s 6ms/step
# ลูกชายเรียนอยู่ ม5 บ่นว่าลงมาของกินเกือบหมดเลยค่ะ , 0
# 2/2 [==============================] - 0s 7ms/step
# ผมสงสารเด็ก รร. นี้มากคือ หนึ่งเลยนะ โรงอาหาร คือเเบบว่ามันเเน่นมากๆเลยครับ , 0
# 3/3 [==============================] - 0s 7ms/step
# ผมสงสารเด็ก รร. นี้มากคือ หนึ่งเลยนะ โรงอาหาร คือเเบบว่ามันเเน่นมากๆเลยครับ , 0
# 3/3 [==============================] - 0s 8ms/step
# ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการ
# อาหารค่ะ , 0
# 3/3 [==============================] - 0s 9ms/step
# ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการ
# อาหารค่ะ , 0
# 3/3 [==============================] - 0s 8ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ , 0
# 2/2 [==============================] - 0s 7ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ , 0
# 2/2 [==============================] - 0s 7ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ , 0
# 2/2 [==============================] - 0s 7ms/step
# ฝนตกส่งลูกลำบากมาก ควรแก้ไขนะคะ , 0
# 1/1 [==============================] - 0s 30ms/step
# ฝนตกส่งลูกลำบากมาก ควรแก้ไขนะคะ , 0
# 1/1 [==============================] - 0s 36ms/step
# อยากให้ดูแลเรื่องปริมาณอาหารให้ด้วยค่ะ , 0
# 2/2 [==============================] - 0s 5ms/step
# ควรพิจารณาที่จอดรถได้แล้วนะครับ , 0
# 1/1 [==============================] - 0s 25ms/step
# ควรพิจารณาที่จอดรถได้แล้วนะครับ , 0
# 1/1 [==============================] - 0s 29ms/step
# ลานจอดใหม่ ฝุ่น เยอะมาก , 0
# 1/1 [==============================] - 0s 24ms/step
# พิจารณา ห้องน้ำ เด็กๆ ใช้สบู่ก้อนล้างมือค่ะ สบู่ก้อนสะสมเชื้อโรค , 0
# 2/2 [==============================] - 0s 10ms/step
# เมนูกระเพราหมูวันอังคารที่ผ่านมาช่วยลดความเผ็ดลงด้วยคะ , 0
# 2/2 [==============================] - 0s 7ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ... , 0
# 2/2 [==============================] - 0s 8ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ... , 0
# 2/2 [==============================] - 0s 10ms/step
# ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่น และดินออกบ้างน่าจะดีนะคะ  , 0
# 3/3 [==============================] - 0s 9ms/step
# ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่น และดินออกบ้างน่าจะดีนะคะ  , 0
# 3/3 [==============================] - 0s 8ms/step
# ก๋วยเตี๋ยวอยากให้เพิ่มเส้นบ้าง น้องผมบ่นว่ากินแต่หมี่ๆอย่างเดียว , 0
# 2/2 [==============================] - 0s 10ms/step
# ไม่ต้องใส่พริกน่าจะดีกว่านะคะ เด็กประถมไม่ได้ทานเผ็ดได้ทุกคนค่ะ , 0
# 2/2 [==============================] - 0s 10ms/step
# ไม่ต้องใส่พริกน่าจะดีกว่านะคะ เด็กประถมไม่ได้ทานเผ็ดได้ทุกคนค่ะ , 0
# 2/2 [==============================] - 0s 11ms/step
# ทำอาหารที่เด็กทานได้ง่ายกว่านี้ค่ะ เมนูแกงสำหรับเด็กประถมยังไม่เห็นด้วยค่ะ , 0
# 3/3 [==============================] - 0s 9ms/step
# คุณครูปรับปรุงเรื่องการออกเสียง ร,ล ให้ชัดเจนด้วยนะคะ  , 0
# 2/2 [==============================] - 0s 7ms/step
# เช็คสหกรณ์ด้วยนะคะ หน้ากากอนามัยแพงมากค่ะ , 0
# 2/2 [==============================] - 0s 6ms/step
# รับทราบปัญหาบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆค่ะ , 0
# 2/2 [==============================] - 0s 8ms/step
# รับทราบปัญหาบ้างนะคะ ไม่มีการปรับปรุงเลย ห่วยมากๆค่ะ , 0
# 2/2 [==============================] - 0s 7ms/step
# เพิ่มปริมาณอาหารหน่อยนะคะ อาทิตย์ก่อนลูกแจ้งว่าได้ทานหมูก้อน 1  , 0
# 2/2 [==============================] - 0s 10ms/step
# พิจารณาเรื่องความสะอาดให้เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0
# 3/3 [==============================] - 0s 9ms/step
# พิจารณาเรื่องความสะอาดให้เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0
# 3/3 [==============================] - 0s 8ms/step
# กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะ , 0
# 2/2 [==============================] - 0s 6ms/step
# กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะ , 0
# 2/2 [==============================] - 0s 5ms/step
# กินต้มจืดเกือบทุกวัน ควรมีอาหารมากกว่านี้ค่ะแล้วก็ควรจะทำให้อาหารมีรสชาติ
# มากกว่านี้ , 0
# 3/3 [==============================] - 0s 8ms/step
# ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ ลูกก็รอไปจนกลับคนสุดท้ายของห้อง , 0
# 3/3 [==============================] - 0s 6ms/step
# วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด
# ควรทำตามตารางนะ , 0
# 3/3 [==============================] - 0s 9ms/step
# มันแย่มากเลย , 0
# 1/1 [==============================] - 0s 24ms/step
# ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ฝากให้พิจารณา​อาหารที่มีประโยชน์​ให้
# เด็กด้วยค่ะ , 0
# 3/3 [==============================] - 0s 8ms/step
# เน้นทางด้านวิชาการ ดึงศักยภาพและความสามารถของนักเรียน ไม่ต้องจำกัดเเค่
# ห้องเรียนพิเศษ สนับสนุนทุกห้องเรียน ฝากท่าน ผอ.โปรดพิจารณา ด้วยค่ะ , 0
# 5/5 [==============================] - 0s 8ms/step
# ไม่ให้รถเข้าออก แบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน , 0
# 3/3 [==============================] - 0s 9ms/step
# พิจารณาห้องน้ เด็กๆด้วยค่ะ  , 0
# 1/1 [==============================] - 0s 28ms/step
# เมนูอาหารวันเสาร์ เป็นเมนูไก่ทอด เป็นอย่างอื่นบ้างก้อดีน่ะค่ะ เด็กๆ บ่นว่า
# ไก่ทอดทุกเสาร์เลย , 0
# 3/3 [==============================] - 0s 9ms/step
# วันนี้ต้มจืดของห้อง ป.2 ให้ไก่มาน้อยมากเลยคะ อยากให้ดูแลเรื่องปริมาณอาหาร
# ให้ด้วยค่ะ ขอบคุณค่ะ , 0
# 3/3 [==============================] - 0s 9ms/step
# น่าจะมีมีพื้นที่พักคอยให้กับญาติ ๆ หน่อยนะค่ะ เพราะว่ารอกว่าจะสอบเสร็จก็ไม่รู้
# ว่าจะเอาตัวไปอยู่ที่ไหน , 0
# 4/4 [==============================] - 0s 10ms/step
# กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ
# พื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด
# ท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้
# เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0
# 9/9 [==============================] - 0s 15ms/step
# กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ
# พื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด
# ท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้
# เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0
# 9/9 [==============================] - 0s 8ms/step
# กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ
# พื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด
# ท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้
# เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0
# 9/9 [==============================] - 0s 9ms/step
# กิจกรรมดีแต่เรื่องความสะอาด น่าจะปรับปรุงนะ ครูใส่รองเท้าที่เดินข้างนอกเหยียบ
# พื้นไปทั่ว และให้เด็กอนุบาล1นั่งพื้นกินกล้วย มือเด็กก็จับพื้นมาจับหน้า ขยี้ตา สุด
# ท้ายติดโรคมือ เท้าปาก ,Covid รบกวนทาง รร พิจารณาเรื่องความสะอาดให้
# เด็กๆด้วย น่าสงสารนั่งพื้นตามคำสั่ง …ไม่รู้เรื่องอะไร , 0
# 9/9 [==============================] - 0s 9ms/step
# อีกเรื่องห้องน้ำชายของประถมดูเหมือนจะมีปัญหาน้ำล้นตอนกดชักโครก
# อยากให้รับปรุงเรื่องนี้ด้วย , 0
# 3/3 [==============================] - 0s 8ms/step
# ขอร้องเรียนเรื่องครูประถมหน่อยค่ะ ครู ***** ***** ตีนักเรียนเพียงเพราะนักเรียน
# ไม่ยอมใส่ถุงเท้าเข้าห้องเรียน ที่จริงแล้วน้องรองเท้าเปียกมาเพราะเข้าห้องน้ำมา
# อยากให้ครูท่านนีได้รับคำตักเตือนหน่อยค่ะ , 0
# 6/6 [==============================] - 0s 11ms/step
# สวัสดีค่ะ อยากให้โรงเรียนพิจารณาอาหารกลางวันเป็นพวกอาหารญี่ปุ่นด้วยอ่ะคะ
# กินอาหารทั่วๆไปเเล้วรู้สึกดูไม่หลากหลายเท่าไหร่เลยอ่ะค่ะ  , 0
# 4/4 [==============================] - 0s 9ms/step
# รายการอาหารวันเรียนพิเศษวันเสาร์ ไม่น่ามีคะเมนูผัดมาม่า ไม่โอเคคะ จากเส้น
# มาม่าเป็นเส้นก๋วยเตี๋ยวน่าจะดีกว่านะคะ. , 0
# 4/4 [==============================] - 0s 8ms/step
# ที่จอดรถสนามกอล์ฟมันร้อนมากเลยครับ ถ้าหาอะไรมาบังแดดได้ก็สมควรที่จะ
# ทำนะครับ , 0
# 3/3 [==============================] - 0s 8ms/step
# ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะคะ
# ลดฝุ่นละออง , 0
# 3/3 [==============================] - 0s 9ms/step
# ถนนข้างสนามกอล์ฟน่าจะให้รถดับเพลิงมาฉีดล้างฝุ่นและดินออกบ้างน่าจะดีนะคะ
# ลดฝุ่นละออง , 0
# 3/3 [==============================] - 0s 10ms/step
# ฝากช่วยดูเรื่องฝุ่นตรงลานจอดรถ เด็ก ๆ เปิดหน้าต่างห้องเรียนรับลม แต่เวลารถขับ
# ผ่านฝุ่นปูนปลิวอย่างเห็นได้ชัด , 0
# 4/4 [==============================] - 0s 8ms/step
# โต๊ะที่โรงอาหารด่านล่างฝุ่นบนโต๊ะเยอะมากนะคะ..ฝากไว้อีกเรื่องคะ (ไปนั่ง
# รอเอาแขนวางบนโต๊ะทีไรติดแขนเยอะเลย ต้องเอาทิชชู่มาเช็ดก่อนทุกที) , 0
# 5/5 [==============================] - 0s 8ms/step
# ช่วยมาวัดค่าอาคาร สอง อาคารสี่ อยู่ติดกับลานจอดใหม่ ฝุ่น เยอะมาก ผบรห
# ลองมานั่งเรียนกับเด็กๆหน่อย , 0
# 4/4 [==============================] - 0s 7ms/step
# หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆเดินก็ไกลต้องมากลัวฝุ่นอีก
# ปอดไม่พังตอนนี้ก็ไม่รู้จะว่าอย่างไง วอนท่านผู้บริหารลงมาเดินดินแก้ปัญหาให้
# เด็กๆด้วยเถอะ หรือพวกท่านและคณะไม่เดือดร้อนเพราะท่านใช้อภิสิทธ์ชนจอด
# ใน รร ได้หรือครับ , 0
# 8/8 [==============================] - 0s 8ms/step
# หาทางลดฝุ่นที่ลานจอดรถให้หน่อยเถอะสงสารเด็กๆเดินก็ไกลต้องมากลัวฝุ่นอีก
# ปอดไม่พังตอนนี้ก็ไม่รู้จะว่าอย่างไง วอนท่านผู้บริหารลงมาเดินดินแก้ปัญหาให้
# เด็กๆด้วยเถอะ หรือพวกท่านและคณะไม่เดือดร้อนเพราะท่านใช้อภิสิทธ์ชนจอด
# ใน รร ได้หรือครับ , 0
# 8/8 [==============================] - 0s 8ms/step
# เมนูกระเพราหมูวันอังคารที่ผ่านมาช่วยลดความเผ็ดลงด้วยคะ ลำไส้เด็กบางคน
# อาจไม่แข็งแรงพอที่จะรับความเผ็ดได้นะคะ , 0
# 4/4 [==============================] - 0s 8ms/step
# กับข้าวเด็กเผ็ดนะคะ (ของอิสลามค่ะ) ลูกๆ ทานตั้งแต่อนุบาล ตอนนี้ประถมแล้ว
# ยังไม่ปรับปรุงเลยค่ะ , 0
# 3/3 [==============================] - 0s 9ms/step
# กับข้าวเด็กเผ็ดนะคะ (ของอิสลามค่ะ) ลูกๆ ทานตั้งแต่อนุบาล ตอนนี้ประถมแล้ว
# ยังไม่ปรับปรุงเลยค่ะ , 0
# 3/3 [==============================] - 0s 8ms/step
# ฝากพิจารณารถตู้รับส่งนักเรียนด้วย นั่งกันแน่นมากๆเลย รู้สึกกังวลครับ , 0
# 3/3 [==============================] - 0s 7ms/step
# ฝากพิจารณารถตู้รับส่งนักเรียนด้วย นั่งกันแน่นมากๆเลย รู้สึกกังวลครับ , 0
# 3/3 [==============================] - 0s 8ms/step
# หนังสือเรียน 10 วิชาหนักมากค่ะลูกแบดไม่ไหวค่ะ บ่นปวดหลัง เดินก็ไกล
# ขึ้นสะพานลอยก็จะหงายหลังตกสะพาน สงสารเด็ก , 0
# 4/4 [==============================] - 0s 10ms/step
# หนังสือเรียน 10 วิชาหนักมากค่ะลูกแบดไม่ไหวค่ะ บ่นปวดหลัง เดินก็ไกล
# ขึ้นสะพานลอยก็จะหงายหลังตกสะพาน สงสารเด็ก , 0
# 4/4 [==============================] - 0s 8ms/step
# ผลไม้ที่ให้เด็กทานพวกเงาะเด็กไม่ทานกันเลยค่ะ อีกอย่างปลอกกันไม่เป็นใช้ปาก
# กัด อันตรายนะคะ ยาฆ่าแมลงทั้งนั้น , 0
# 4/4 [==============================] - 0s 9ms/step
# ขอแนะนำนะคะจากเผ็ดน้อยเปลี่ยนเป็นไม่เผ็ดเลยค่ะ กระเพราเด็กไม่
# ต้องใส่พริกน่าจะดีกว่านะคะ เด็กประถมไม่ได้ทานเผ็ดได้ทุกคนค่ะ  , 0
# 4/4 [==============================] - 0s 9ms/step
# ช่วยพิจารณาเรื่องการส่งงานส่งเป็นรายอาทิตย์หรืออย่างไรก็ได้ที่ทางคุณครูสะดวก
# ไม่ใช่แค่มีคลิปแล้วเรียนบอกว่าเรียนจบแล้ว , 0
# 4/4 [==============================] - 0s 9ms/step
# ฝากพิจารณาถึงคุณครูประจำชั้น หรือ ป้าภารโรงด้วยนะครับ ตักอาหารให้พอ
# เหมาะกับตัวเด็กที่รับประทานนะครับ น้องผมที่เรียน ชลประทานบอกว่า บางวัน
# ครูตักให้น้อยมาก บางวันก็ตักให้เยอะเกินจนกินไม่หมด และวัตถุดิบที่นำมาทำ
# ควรเป็นวัตถุดิบที่เหมาะกับเด็กทานได้นะครับ เช่นกุนเชียง ก็แข็งเกินไป  , 0
# 9/9 [==============================] - 0s 9ms/step
# ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนม
# ที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ และสังเกต​ว่าเทอมนี้ผลไม้ไม่มีขาย
# แล้ว ฝากให้พิจารณา​อาหารที่มีประโยชน์​ให้เด็กด้วยค่ะ , 0
# 7/7 [==============================] - 0s 9ms/step
# ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนม
# ที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ และสังเกต​ว่าเทอมนี้ผลไม้ไม่มีขาย
# แล้ว ฝากให้พิจารณา​อาหารที่มีประโยชน์​ให้เด็กด้วยค่ะ , 0
# 7/7 [==============================] - 0s 9ms/step
# ขออนุญาตนะคะ อาหารเด็กกลางวัน ป.1ถึง ป.6อาหารเหมือนกันหมด ควรแบ่งตาม
# ความเหมาะสมเด็กเล็ก และเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ ลูกชาย
# คนโตบอกไม่มีใครกินเลยเหลือเยอะเพราะมันไม่อร่อย ยิ่งคนเล็กบอกคำเดียวว่า
# ไม่อร่อยและกินไม่ได้เลยค่ะถึงจะเป็นเด็กแต่ก็มีหัวใจนะคะ ขอให้กินได้ก็พอค่ะ
# อาหารจะมีคุณภาพเราต้องใส่ใจในทุกรายละเอียดและทุกๆอย่างค่ะ ขอบคุณค่ะ , 0
# 11/11 [==============================] - 0s 10ms/step
# อยากขอให้โรงเรียนไม่มีแต่ต้มจืดค่ะหนูกินต้มจืดเกือบทุกวันควรมีอาหารมากกว่านี้
# ค่ะ แล้วก็ควรจะทำให้อาหารมีรสชาติมากกว่านี้ค่ะเพราะบางวันอาหารไม่มีรสชาติ
# เลย ขอบคุณค่ะ , 0
# 6/6 [==============================] - 0s 8ms/step
# แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่าเพราะบางทีได้ไก่จ่อ 2 ชิ้น ไส้
# กรอก 2 ชิ้น ไข่ต้มกินไม่เป็นกินไข่ขาวนิดหน่อย สงสารลูกให้ห่อข้าวก็ไม่ยอม
# กลัวไม่เหมือนเพื่อน เราเสียเงินเพิ่มก็ได้นะ ขอให้ดีกว่านี้ ระวังผู้ปกครองทนไม่
# ไหวแอบถ่ายออกสื่อจะดังเหมือน รร.อื่นๆนะคะ อายญาติพี่น้องว่าเราส่งลูกมา
# เรียน ที่นี่ได้งัย , 0
# 10/10 [==============================] - 0s 10ms/step
# ลูกชายบ่นบ่อยๆว่าที่โรงอาหารคิวยาว ต้องรอนานจนบางครั้งใกล้จะหมดเวลาพัก
# วันนี้มีโรงอาหารใหม่เปิดแล้วหวังว่าจะดีขึ้นนะคะ , 0
# 4/4 [==============================] - 0s 9ms/step
# ทางโรงเรียน​ จะต้องเร่งแก้ไขให้นะคะ​ ไม่ใช่ให้เด็กนักเรียน​หรือ​ ผู้ปกครอง​ จะต้อง
# เป็นคนประสานเองนะคะ​ เพราะได้แจ้งรายละเอียด​ และ​ ปัญหา​ ไว้ให้พิจารณา
# หมดแล้ว​ ***ทางโรงเรียนควรจะเร่งหาทางแก้ไขให้ด่วนนะคะ*** , 0
# 7/7 [==============================] - 0s 8ms/step
# อยากให้มีครบทุกวิชาค่ะตามตารางเรียนที่เคยเรียน ไม่ใช่มีแต่วิชาหลัก
# 5 วิชาหนักแบบนี้ พิจารณาด้วนค่ะ!! , 0
# 4/4 [==============================] - 0s 7ms/step
# อยากจะให้ทาง รร. เพิ่มเมนูหรือเพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่า
# ได้ทานหมูก้อน 1ก้อนกับซุป น้อยไปนะคะ กับมาตรฐาน กับรร.ระดับนี้ ไม่ไหวๆ , 0
# 5/5 [==============================] - 0s 10ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 7ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 5ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 6ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 7ms/step
# ในห้องน้ำควรมีทิชชู่ เรื่องความสะอาดสำคัญมาก , 0
# 2/2 [==============================] - 0s 5ms/step
# เด็กบางคนเห็นห้องน้ำสกปรกก็ไม่กล้าเข้าห้องน้ำ อั้นไว้ทั้งวันไม่ดี , 0
# 3/3 [==============================] - 0s 7ms/step
# นักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่เหมือนกัน พิจารณาแก้ไขด้วย , 0
# 3/3 [==============================] - 0s 8ms/step
# เด็กนักเรียนหญิงจำเป็นต้องมีคู่ละ 20 บาท 2-3 วันหลุดซื้อบ่อย ๆ ก็แย่เหมือนกัน พิจารณาแก้ไขด้วย , 0
# 3/3 [==============================] - 0s 10ms/step
# ห้องน้ำนักเรียนอาคาร 8 อับชื้นและสกปรกมาก รบกวนตรวจด้วยนะคะ , 0
# 2/2 [==============================] - 0s 14ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ. ลองให้รถครูจอดข้างนอกแล้วเดินลุยฝนมาบ้าง , 0
# 3/3 [==============================] - 0s 8ms/step
# ฝนตกส่งลูกลำบากมาก น่าจะปรับปรุงใหม่นะครับ. ลองให้รถครูจอดข้างนอกแล้วเดินลุยฝนมาบ้าง , 0
# 3/3 [==============================] - 0s 8ms/step
# เมนูแกงสำหรับเด็กประถมยังไม่ควร ยังทานยากไป , 0
# 2/2 [==============================] - 0s 9ms/step
# ทางเข้าออก รร ยังใช้รูปแบบเดิมไม๊ค่ะ ไม่งั้นรถติดขั้นเทพมากถ้าไม่ปรับปรุง , 0
# 3/3 [==============================] - 0s 10ms/step
# เรียนปกติแล้วทำไมให้รถเข้าออกได้ปกติทุกคนมีความป้องกันตัวเองอยู่แล้วแบบนี้รถก็ติดแย่สินักเรียนไม่ใช่หลักร้อยนะคะนี่นักเรียนหลายพัน , 0
# 5/5 [==============================] - 0s 8ms/step
# ปิดเรียนปกติครบทุกระดับชั้นแต่ถ้าทางโรงเรียนไม่ให้ผู้ปกครองนำรถเข้าโรงเรียนไปส่งเด็กๆมันคงจะแย่สำหรับผู้ปกครองหลายๆคนนะค่ะ , 0
# 4/4 [==============================] - 0s 9ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​ เพราะถ้าเปิดเต็มรูปแบบรถคงติดมาก , 0
# 3/3 [==============================] - 0s 9ms/step
# เปิดมา 2 เดือนแล้วที่จอดรถก็ยังสร้างไม่เสร็จเลย ไม่ไหวนะ , 0
# 2/2 [==============================] - 0s 11ms/step
# นี่คือความคิดของคนภายนอกและนี่ก็คือผลงานของทางโรงเรียนทำให้คนข้างนอกเข้าใจ ผปค. ผิดจะทำยังไงก็รีบๆ ทำเถอะค่ะ ซึ่งมันไม่ใช่ความผิดของ
#  ผปค. เลยนะคะ , 0
# 5/5 [==============================] - 0s 9ms/step
# ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่นมากสังเกตุมาหลายอาทิต
# แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้รับความกรุณาพิจารณาด้วย , 0
# 4/4 [==============================] - 0s 10ms/step
# ต้องไปนั่งตรงที่ไม่ไช่ที่นั่งแล้วมันก็แน่นมากสังเกตุมาหลายอาทิต
# แล้วควรต้องแก้ไขขอบคุณมากค่ะหวังว่าคงได้รับความกรุณาพิจารณาด้วย , 0
# 4/4 [==============================] - 0s 9ms/step
# เมนูวันเสาร์ ไม่ควรจะเป็นพวกข้าวเหนียวหมู หรือม่าม่าผัด , 0
# 2/2 [==============================] - 0s 10ms/step
# เปิดประตู3 ไม่ได้ช่วยอะไรเลย โรงเรียนจะต้องเปิด ประตู 4และ ประตู 5 เพื่อช่วยระบายรถ ที่ลานจอดรถ ในช่วงเช้า 6.00 - 8.30 น. พิจารณาแก้ไขด้วย , 0
# 5/5 [==============================] - 0s 9ms/step
# โทรไป *หลาย* ครั้ง ไม่มีคนรับสายเลยนะคะ พิจารณาแก้ไขด้วย , 0
# 2/2 [==============================] - 0s 7ms/step
# อยากให้จัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ​ ตอนเลิกเรียน​ ลำบากมากครับ​ ไม่มีที่จอดก็วนไป​เรื่อยๆ
#  ลูกก็รอไปจนกลับคนสุดท้ายของห้อง​ เกรงใจคุณครูที่รอเราคนเดียว​ , 0
# 6/6 [==============================] - 0s 10ms/step
# แต่ของลูกเป็นการตักรอบแรกนะคะ ถ้ามันไม่พอแสดงว่าไม่มีใครได้รอบสองแน่นอน
# ช่วยพิจารณาหน่อยนะคะว่าเป็นการตักรอบแรกค่ะ , 0
# 4/4 [==============================] - 0s 9ms/step
# แต่ของลูกเป็นการตักรอบแรกนะคะ ถ้ามันไม่พอแสดงว่าไม่มีใครได้รอบสองแน่นอน
# ช่วยพิจารณาหน่อยนะคะว่าเป็นการตักรอบแรกค่ะ , 0
# 4/4 [==============================] - 0s 8ms/step
# ไปติดต่อมาแล้วค่ะ ไม่ได้รับบริการเลยนอกจากบอกว่า ก็คือต้องทำเรื่องขอสมัครบัตรเครดิตและรออนุมัติ อย่างน้อย 14 วันทำการ
# วงเงินก็แล้วแต่ลูกค้าค่ะว่าจะ cover ค่าเทอมรึเปล่า และสามารถไปสมัครที่สาขาไหนก็ได้ที่คุณลูกค้าสะดวกค้ะ ..... ก็เดิน งง งง ออกมาค่ะ , 0
# 8/8 [==============================] - 0s 9ms/step
# ประกาศผลสอบช้ามากจังค่ะ แต่ตังก็จะให้จ่ายก่อน งง ใจค่ะ , 0
# 2/2 [==============================] - 0s 8ms/step
# ออกเกรดช้ามาก , 0
# 1/1 [==============================] - 0s 30ms/step
# วันนี้ไม่ใช่น้ำตกหมู ไม่เห็นทำตามตารางเลย เห็นเด็กบอกเป็นไก่ทอด แย่มาก , 0
# 3/3 [==============================] - 0s 6ms/step
# เสียงเบาค่ะ , 0
# 1/1 [==============================] - 0s 23ms/step
# ได้ใบเกรดและใบจบช้าคะรร.อื่นเขาแจกกันตั้งแต่เดือนที่แล้ว แล้วนี่ยังคิดGPAของแต่ละกลุ่มสาระไม่เสร็จทำไมถึงทำงานช้ากันแบบนี้คะถ้านร.
# กรอกแก้ไขข้อมูลไม่ทันทำให้มีผลไม่ติดมหาลัยล่ะคะจะรับผิดชอบยังไง ทำไมถึงประกาศในcpw classroomก่อนไม่ได้คะ ห่วยสิ้นดี , 0
# 8/8 [==============================] - 0s 9ms/step
# ควบคุมการผลิตให้ดี เพิ่มโปรตีนด้วยนะครับ ไม่ใช่มีแต่ผักกับผลไม้ พิจารณาด่วน , 0
# 3/3 [==============================] - 0s 8ms/step
# แกงเขียวหวานเด็กทานไม่ได้ ลูกต้องกินข้าวเปล่า , 0
# 2/2 [==============================] - 0s 8ms/step
# ขออนุญาตนะคะอาหารเด็กกลางวันป.1ถึงป.6อาหารเหมือนกันหมด ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ , 0
# 4/4 [==============================] - 0s 9ms/step
# ขออนุญาตนะคะอาหารเด็กกลางวันป.1ถึงป.6อาหารเหมือนกันหมด ควรแบ่งตามความเหมาะสมเด็กเล็กและเด็กโตค่ะควรปรับปรุงฝ่ายโภชนาการอาหารค่ะ , 0
# 4/4 [==============================] - 0s 10ms/step
# ได้รับข้อมูลแล้ว กรุณานำไปพิจารณาด้วยนะครับไม่ใช่ขอบคุณอย่างเดียวครับ , 0
# 3/3 [==============================] - 0s 7ms/step
# ได้รับข้อมูลแล้ว กรุณานำไปพิจารณาด้วยนะครับไม่ใช่ขอบคุณอย่างเดียวครับ , 0
# 3/3 [==============================] - 0s 8ms/step
# ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนมที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ , 0
# 4/4 [==============================] - 0s 10ms/step
# ขนมที่ขายในโรงเรียน ตอนนี้ส่วนใหญ่​มีแต่ของทอด ไส้กรอก ลูกชิ้น ซึ่งเป็นขนมที่เด็กไม่สมควรทานติดต่อกันเป็นเวลานานๆ , 0
# 4/4 [==============================] - 0s 10ms/step
# เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ , 0
# 7/7 [==============================] - 0s 8ms/step
# เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ , 0
# 7/7 [==============================] - 0s 9ms/step
# เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ , 0
# 7/7 [==============================] - 0s 8ms/step
# เรื่องความสะอาดของห้องน้ำ ยิ่งเด็กประถมความสามารถในการรักษาความสะอาดยังน้อย ห้องน้ำจึงค่อนข้างสกปรกและมีกลิ่น ทำให้เป็นแหล่งเชื้อโรค โดยเฉพาะห้องน้ำเด็กผู้หญิงยิ่งเสี่ยงต่อการติดเชื้อได้ง่ายค่ะ , 0
# 7/7 [==============================] - 0s 8ms/step
# อีกเรื่องห้องน้ำสกปรกมากๆๆครับ ร่วมถึงน้ำดื่มอีกก็ไม่เคยตรวจสอบเลยครับ จนเดียวนี้เด็กๆถึงไม่อยากเข้าห้องน้ำกับดื่มน้ำที่โรงเรียนแล้วครับ , 0
# 5/5 [==============================] - 0s 8ms/step
# อีกเรื่องห้องน้ำสกปรกมากๆๆครับ ร่วมถึงน้ำดื่มอีกก็ไม่เคยตรวจสอบเลยครับ จนเดียวนี้เด็กๆถึงไม่อยากเข้าห้องน้ำกับดื่มน้ำที่โรงเรียนแล้วครับ , 0
# 5/5 [==============================] - 0s 8ms/step
# ทางโรงเรียนเลือกตอบแค่บางคำถามหรอครับ เห็นคำถามไหนเกี่ยวกับโปรแกรม ซูม ทางโรงเรียนไม่เข้ามาตอบเลย แย่มากครับ , 0
# 4/4 [==============================] - 0s 8ms/step
# ทางโรงเรียนเลือกตอบแค่บางคำถามหรอครับ เห็นคำถามไหนเกี่ยวกับโปรแกรม ซูม ทางโรงเรียนไม่เข้ามาตอบเลย แย่มากครับ , 0
# 4/4 [==============================] - 0s 8ms/step
# สัญญาที่ไม่เป็นธรรมมากค่ะ จะเรียนต่อ ป.4 บังคับเซนไม่เซนไม่ได้เข้าเรียนต่อ  , 0
# 3/3 [==============================] - 0s 9ms/step
# ไม่คิดจะคืนค่าอาหารเลยหรอค่ะ , 0
# 1/1 [==============================] - 0s 26ms/step
# ดูไม่ได้ , 0
# 1/1 [==============================] - 0s 37ms/step
# ทางผู้ปกครองไม่สะดวกใจให้นักเรียนไปค่ายพุทธบุตรเเล้วค่ะ , 0
# 2/2 [==============================] - 0s 8ms/step
# เย็นไม่น่ามีเรียนเสริมเย็นช่วงนี้นะคะ จะได้ปล่อยให้เด็กๆ เชียร์ได้เต็มที , 0
# 3/3 [==============================] - 0s 9ms/step
# โรงเรียนคะ อยากให้แก้ชื่อให้หน่อยค่ะ โพสต์ล่าสุดอ่ะค่ะพิจารณาแก้ไขด้วย , 0
# 3/3 [==============================] - 0s 7ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​ , 0
# 2/2 [==============================] - 0s 7ms/step
# ที่จอดรถไม่น่าจะพอนะคะ​ ควรพิจารณาเรื่องการจอดรถอีกที​ ​ , 0
# 2/2 [==============================] - 0s 8ms/step
# ช่วยพิจารณาการขับรถไปเทียบส่งหน้าตึก แบบไม่จอด ด้วยค่ะ ตอนนี้แค่เรียนวัน
# เว้นวันก็ไม่ทันแล้ว ที่จอดไม่พอ  , 0
# 4/4 [==============================] - 0s 8ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ... , 0
# 2/2 [==============================] - 0s 11ms/step
# รร. ควรพิจารณาเรื่องการขับรถวนเข้าส่ง นร. ใน รร.ได้ นะคะ... , 0
# 2/2 [==============================] - 0s 9ms/step
# รบกวนออกมาชี้แจ้งด้วยค่ะ , 0
# 1/1 [==============================] - 0s 29ms/step
# ควรจัดสรรเรื่องที่จอดรถให้เป็นรูปแบบที่ชัดเจนและเพียงพอด้วยครับ​ , 0
# 2/2 [==============================] - 0s 11ms/step
# ตรงลานจอดที่ยังเป็นดิน เด็กเดินอยู่ ขับเบาๆหน่อยนะครับ ฝุ่นมันเยอะ , 0
# 3/3 [==============================] - 0s 7ms/step
# ทำ 3 รอบแล้ว ค้างตรงถัดไปของบิดา , 0
# 1/1 [==============================] - 0s 27ms/step
# เพิ่มปริมาณหน่อยนะคะ อาทิตย์ก่อน ลูกแจ้งว่าได้ทานหมูก้อน 1ก้อนกับซุป
# น้อยไปนะคะ ไม่ไหวๆ , 0
# 3/3 [==============================] - 0s 9ms/step
# รบกวนคุณครูปรับปรุงเรื่องการออกเสียง ร,ล ให้ชัดเจนด้วยนะคะ โดยเฉพาะ
# วิชาภาษาไทย ขอบคุณค่ะ , 0
# 3/3 [==============================] - 0s 8ms/step
# กระตุกมากค่ะ เล่นๆหยุดๆ ตลอดเลยค่ะ , 0
# 2/2 [==============================] - 0s 5ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 5ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 8ms/step
# กระตุก ค้าง คุณภาพเสียงไม่ดี ไม่ค่อยได้ยิน , 0
# 2/2 [==============================] - 0s 6ms/step
# กระตุกทุกlink. ห่วยคะ , 0
# 1/1 [==============================] - 0s 32ms/step
# กระตุกทุกlink. ห่วยคะ , 0
# 1/1 [==============================] - 0s 29ms/step
# แย่มากกกกกกค่ะ , 0
# 1/1 [==============================] - 0s 23ms/step
# รสชาติอาหารแย่มาก ไม่ไหวจะเคลียร์ , 0
# 2/2 [==============================] - 0s 7ms/step
# รสชาติอาหารแย่มาก ไม่ไหวจะเคลียร์ , 0
# 2/2 [==============================] - 0s 6ms/step
# เสียความรู้สึกอย่างมาก อาหารไม่เหมือนที่บอกเอาไว้ , 0
# 2/2 [==============================] - 0s 9ms/step
# ใช้เดือนเดียวพังแย่ๆมากๆ , 0
# 1/1 [==============================] - 0s 26ms/step
# เสียความรู้สึกมากกระเป๋าบางมากไม่ตรงกะแบบ , 0
# 2/2 [==============================] - 0s 11ms/step
# ปรับปรุงด่วน!!!!  , 0
# 1/1 [==============================] - 0s 23ms/step
# สินค้าไม่มีคุณภาพ ขากางเกงยาวไม่เท่ากัน , 0
# 2/2 [==============================] - 0s 4ms/step
# เสียเวลามากๆ กว่าจะทำเรื่องคืนเงินได้  , 0
# 2/2 [==============================] - 0s 5ms/step
# บบการทำงานแย่มาก , 0
# 1/1 [==============================] - 0s 32ms/step
# เสียความรู้สึกค่ะ , 0
# 1/1 [==============================] - 0s 21ms/step
# กระเป๋าลูกมีตำหนิ แย่มากๆ ไม่ไหวๆเลย ถ้ามีตำหนิก็บอกด้วยครับ , 0
# 2/2 [==============================] - 0s 11ms/step
# ไม่ไหวๆเลย , 0
# 1/1 [==============================] - 0s 22ms/step
# เพิ่มร้าน หรือปริมาณอาหารให้พอกับความต้องการด่วนเลยค่ะ ม.5 พักเที่ยงลงมา
# ไม่เหลืออาหารให้ทานตั้งแต่เปิดเทอม!! , 0
# 4/4 [==============================] - 0s 10ms/step
# ถ้าเพิ่มร้านอิสลามก็ดีนะครับ , 0
# 1/1 [==============================] - 0s 29ms/step
# เติมเงินผ่านแอพไม่ได้ , 0
# 1/1 [==============================] - 0s 22ms/step
# วันนี้ล่มอีกแล้วนะคะ เติมเงินผ่านแอพไม่ได้ค่ะ , 0
# 2/2 [==============================] - 0s 6ms/step
# ตอนนี้ก็ยังใช้ไม่ได้เลยค่ะ เติมเงินให้ลูกไปไม่ได้พกเงินสด ไม่ได้กินมื้อเช้าเลยค่ะ , 0
# 3/3 [==============================] - 0s 11ms/step
# ห้องปกติคืนนิดเดียว อย่าคืนเลยค่าเน็ตยังไม่พอเลย
# ช่วยเหลือ มันต้องทุกระดับชั้นทุกคน ไม่ใช่บางกรณี ห่วยมากค่ะ , 0
# 4/4 [==============================] - 0s 9ms/step
# มาตราการที่กล่าวมาข้างต้นไม่สามารถป้องกันได้ จริงๆทางโรงเรียนน่าจะรู้ดีว่า
# อยู่ในพื้นที่เสี่ยงนะคะ เด็กๆอันตรายเปล่า , 0
# 4/4 [==============================] - 0s 8ms/step
# จะใช้แค่มาตราการเบื้องต้น แล้วยะงเมื่อ วันอังคารที่ผ่านมาทางโรงเรียนยังจัด
# ให้มีงานปัจฉิมนิเทศ อีกซึ่งเพิ่มความเสี่ยงในการติดเชื้อขึ้นไปอีก ถ้าโควิท19
# ระบาดในเด็กน่ากลัวมากนะค่ะ อันตรายต่อเด็กๆ , 0
# 7/7 [==============================] - 0s 8ms/step
# เข้าใจว่าอยากให้เด็กรับสอบรีบปิดเทอม แต่สุดท้ายแล้วต้องมาเสี่ยงติดโควิท
# ทั้งโรงเรียน แถมเสี่ยงมาถึงผู้ปกครองและคนที่บ้านอีก “ตรรกะ”โรงเรียน ต่ำมาก
# แย่มาก , 0
# 5/5 [==============================] - 0s 9ms/step
# รร.ควรน่าจะป้องกันโดยการห้ามเด็ก นร.ที่มีบ้านอยู่ในเขตเสี่ยงงดการเรียน
# และให้เรียนออนไลน์เป็นกลุ่มพิเศษไปเพื่อเป็นการป้องกันตั้งแต่ต้น , 0
# 5/5 [==============================] - 0s 9ms/step
# ทำความสะอาดตู้กดน้ำด้วยนะคะ สกปรกมาก  , 0
# 2/2 [==============================] - 0s 5ms/step
# โรงอาหาร รร กินจนเบื่อละ , 0
# 1/1 [==============================] - 0s 26ms/step
# ควรมีดื่มน้ำสะอาดๆ ที่กินอยู๋ตอนนี้เด็กบอกรสชาติแปลกๆ ไม่ไหวนะคะแบบนี้ , 0
# 3/3 [==============================] - 0s 8ms/step
# ควรมีดื่มน้ำสะอาดๆ ที่กินอยู๋ตอนนี้เด็กบอกรสชาติแปลกๆ ไม่ไหวนะคะแบบนี้ , 0
# 3/3 [==============================] - 0s 7ms/step
# ถ้า ผอ.พูดคนเดียวไม่จำต้องเอาอาจารย์มายืนประกอบแบบนี้ก็ได้ครับ มันดูแปลกๆ , 0
# 3/3 [==============================] - 0s 8ms/step
# พอคนเยอะไป อาจารย์ที่อยู่ริมก็ตัวขาด เพราะ Greenscreen ไม่กว้างพอครับ , 0
# 3/3 [==============================] - 0s 8ms/step
# ภาพพื้นหลัง (ที่น่าจะเป็น Greenscreen ) รูปโรงเรียน ดีและสวยได้มากกว่านี้ครับ , 0
# 3/3 [==============================] - 0s 7ms/step
# ระยะภาพ มีผลต่อความรู้สึกของผู้ฟังนะครับ แนะนำใช้ Close up
# ตอน ผอ.พูดบางก็ดีครับ ตอนนี้มันกว้างและแช่เกินไป , 0
# 4/4 [==============================] - 0s 8ms/step
# Intro เกือบจะดีแล้วครับ แต่ไม่แน่ใจว่าตั้งใจให้โลโก้โรงเรียนดูแตก
# ...
# ปิดปลายภาควันที่เท่าไรค่ะ , 2
# 1/1 [==============================] - 0s 31ms/step
# ปิดปลายภาควันที่เท่าไรคับ , 2
# 1/1 [==============================] - 0s 40ms/step
# ปิดปลายภาควันที่เท่าไรคับ , 2
# 1/1 [==============================] - 0s 28ms/step
# ปิดปลายภาควันที่เท่าไรคับ , 2
# 1/1 [==============================] - 0s 29ms/step
# ฝนตกหนัก นำรถเข้ารับเด็กในร.ร. ได้ไหม , 2
# 2/2 [==============================] - 0s 6ms/step
# ฝนตกหนัก นำรถเข้ารับเด็กในร.ร. ได้ไหม , 2
# 2/2 [==============================] - 0s 6ms/step
# ฝนตกหนัก นำรถเข้ารับเด็กในร.ร. ได้ไหม , 2
# 2/2 [==============================] - 0s 5ms/step
# สอบถามครับ ศิษย์เก่าสามารถเข้าไปภายในโรงเรียนได้มั้ยครับ
#  , 2
# 2/2 [==============================] - 0s 10ms/step
# สอบถามครับ ศิษย์เก่าสามารถเข้าไปภายในโรงเรียนได้มั้ยครับ , 2
# 2/2 [==============================] - 0s 9ms/step
# สอบถามครับ ศิษย์เก่าสามารถเข้าไปภายในโรงเรียนได้มั้ยครับ , 2
# 2/2 [==============================] - 0s 10ms/step
# สอบถามครับ ศิษย์เก่าสามารถเข้าไปภายในโรงเรียนได้มั้ยครับ , 2
# 2/2 [==============================] - 0s 12ms/step
# ตารางเรียน จะแจกให้ใหม่ หรือ Download ได้วันไหนคะ
#  , 2
# 2/2 [==============================] - 0s 11ms/step
# ตารางเรียน จะแจกให้ใหม่ หรือ Download ได้วันไหนคะ
#  , 2
# 2/2 [==============================] - 0s 12ms/step
# ป.6 ค่าเทอม ประมาณเท่าไรค่ะ , 2
# 1/1 [==============================] - 0s 28ms/step
# ป.6 ค่าเทอม ประมาณเท่าไรค่ะ , 2
# 1/1 [==============================] - 0s 32ms/step
# จะมีการคืนค่าเทอมไหมคะ เหมือนจำได้ว่าเคยแจ้งไปในคอมเม้นว่าจะมี
# การคืนค่าเทอมปลายเทอมนี้ , 2
# 3/3 [==============================] - 0s 10ms/step
# จะมีการคืนค่าเทอมไหมคะ เหมือนจำได้ว่าเคยแจ้งไปในคอมเม้นว่าจะมี
# การคืนค่าเทอมปลายเทอมนี้ , 2
# 3/3 [==============================] - 0s 10ms/step
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
# มาเบิกค่ะ , 2
# 3/3 [==============================] - 0s 10ms/step
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
# มาเบิกค่ะ , 2
# 3/3 [==============================] - 0s 8ms/step
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
# มาเบิกค่ะ , 2
# 3/3 [==============================] - 0s 9ms/step
# รบกวนสอบถามค่ะ เข้าไปจ่ายที่โรงเรียนได้ไหมคะ เพราะต้องการใบเสร็จ
# มาเบิกค่ะ , 2
# 3/3 [==============================] - 0s 10ms/step
# ส่งเอกสารยืนยันไปแล้วยังไม่เห็นโอนคืนค่าเทอมมาเลยครับ , 2
# 2/2 [==============================] - 0s 14ms/step
# ชำระเกินไปแล้วต้องทำอย่างไรคะ , 2
# 1/1 [==============================] - 0s 52ms/step
# ชำระเกินไปแล้วต้องทำอย่างไรคะ , 2
# 1/1 [==============================] - 0s 33ms/step
# วันอาทิตย์โรงเรียนเปิดไหมครับ , 2
# 1/1 [==============================] - 0s 29ms/step
# วันอาทิตย์โรงเรียนเปิดไหมครับ , 2
# 1/1 [==============================] - 0s 28ms/step
# รับสมัคร อนุบาล 1 ต้องมีอายุเท่าไหร่คะ , 2
# 2/2 [==============================] - 0s 8ms/step
# รับสมัคร อนุบาล 1 ต้องมีอายุเท่าไหร่คะ , 2
# 2/2 [==============================] - 0s 5ms/step
# รับสมัคร อนุบาล 1 ต้องมีอายุเท่าไหร่คะ , 2
# 2/2 [==============================] - 0s 7ms/step
# ขอสอบถามค่ะ แผนก ITP เรียนตึกไหนคะ , 2
# 2/2 [==============================] - 0s 4ms/step
# ขอสอบถามค่ะ แผนก ITP เรียนตึกไหนคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# ขอสอบถามค่ะ แผนก ITP เรียนตึกไหนคะ , 2
# 2/2 [==============================] - 0s 5ms/step
# ยังมีตรวจสุขภาพประจำปีของนักเรียนอยู่มั้ยคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# ยังมีตรวจสุขภาพประจำปีของนักเรียนอยู่มั้ยคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# ผลการเรียนของน้องอนุบาลดูได้ที่ไหนหรอค่ะ , 2
# 2/2 [==============================] - 0s 9ms/step
# ผลการเรียนของน้องอนุบาลดูได้ที่ไหนหรอค่ะ , 2
# 2/2 [==============================] - 0s 7ms/step
# ผลการเรียนของน้องอนุบาลดูได้ที่ไหนหรอค่ะ , 2
# 2/2 [==============================] - 0s 6ms/step
# เกรดออกตอนไหนค่ะ เปิดเข้าไปไม่มีค่ะ , 2
# 2/2 [==============================] - 0s 6ms/step
# เกรดออกตอนไหนค่ะ เปิดเข้าไปไม่มีค่ะ , 2
# 2/2 [==============================] - 0s 4ms/step
# ชำระค่าเทอมของแอปโรงเรียนอยู่ไหนครับ , 2
# 2/2 [==============================] - 0s 4ms/step
# ชำระค่าเทอมของแอปโรงเรียนอยู่ไหนครับ , 2
# 2/2 [==============================] - 0s 7ms/step
# ชำระค่าเทอมของแอปโรงเรียนอยู่ไหนครับ , 2
# 2/2 [==============================] - 0s 6ms/step
# ดูเกรดเฉลี่ยยังไงค่ะ , 2
# 1/1 [==============================] - 0s 33ms/step
# ดูเกรดเฉลี่ยยังไงค่ะ , 2
# 1/1 [==============================] - 0s 29ms/step
# ถ้าของหายที่โรงเรียนนักเรียนต้องไปแจ้งของหายได้จากไหนคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# ถ้าของหายที่โรงเรียนนักเรียนต้องไปแจ้งของหายได้จากไหนคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# อยากทราบว่า รองเท้าพละต้องเป็นสีขาวเท่านั้นมั้ยครับ , 2
# 2/2 [==============================] - 0s 10ms/step
# อยากทราบว่า รองเท้าพละต้องเป็นสีขาวเท่านั้นมั้ยครับ , 2
# 2/2 [==============================] - 0s 7ms/step
# วันอาทิตย์สหกรณ์โรงเรียนเปิดไหมครับ , 2
# 2/2 [==============================] - 0s 6ms/step
# วันอาทิตย์สหกรณ์โรงเรียนเปิดไหมครับ , 2
# 2/2 [==============================] - 0s 6ms/step
# จะสอบถามเรื่องส่งน้องเข้าเรียน เตรียมอนุบาลอ่ะคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# จะสอบถามเรื่องส่งน้องเข้าเรียน เตรียมอนุบาลอ่ะคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# ภาษาจีนเริ่มเรียนชั้นไหนค่ะ , 2
# 1/1 [==============================] - 0s 24ms/step
# ภาษาจีนเริ่มเรียนชั้นไหนค่ะ , 2
# 1/1 [==============================] - 0s 26ms/step
# หลักสูตรการบินรับสมัครนักเรียนชั้นไหนคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# หลักสูตรการบินรับสมัครนักเรียนชั้นไหนคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# หลักสูตรการบินรับสมัครนักเรียนชั้นไหนคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# EP ป.1ค่าเทอมเท่าไหรค่ะ , 2
# 1/1 [==============================] - 0s 27ms/step
# EP ป.1ค่าเทอมเท่าไหรค่ะ , 2
# 1/1 [==============================] - 0s 28ms/step
# ใช้บัตรกสิกร ผ่อน 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# ใช้บัตรกสิกร ผ่อน 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 2
# 2/2 [==============================] - 0s 11ms/step
# ใช้บัตรกสิกร ผ่อน 3 เดือน อันนี้มีค่าธรรมเนียมในการใช้บัตรไหมคะ , 2
# 2/2 [==============================] - 0s 11ms/step
# ชำระค่าเทอมสามารถชำระโดยใช้บัตรเครดิต tmb ได้ไหมคะ
# แล้วไปชำระที่ไหนคะ , 2
# 3/3 [==============================] - 0s 8ms/step
# ชำระค่าเทอมสามารถชำระโดยใช้บัตรเครดิต tmb ได้ไหมคะ
# แล้วไปชำระที่ไหนคะ , 2
# 3/3 [==============================] - 0s 11ms/step
# ชำระค่าเทอมสามารถชำระโดยใช้บัตรเครดิต tmb ได้ไหมคะ
# แล้วไปชำระที่ไหนคะ , 2
# 3/3 [==============================] - 0s 7ms/step
# ถ้าไปจ่ายค่าเทอมต้องไปจ่ายตึกไหนค่ะ เปิดปิดถึงเวลากี่โมงค่ะ , 2
# 2/2 [==============================] - 0s 10ms/step
# ถ้าไปจ่ายค่าเทอมต้องไปจ่ายตึกไหนค่ะ เปิดปิดถึงเวลากี่โมงค่ะ , 2
# 2/2 [==============================] - 0s 9ms/step
# ถ้าไปจ่ายค่าเทอมต้องไปจ่ายตึกไหนค่ะ เปิดปิดถึงเวลากี่โมงค่ะ , 2
# 2/2 [==============================] - 0s 9ms/step
# ถ้าไปจ่ายค่าเทอมต้องไปจ่ายตึกไหนค่ะ เปิดปิดถึงเวลากี่โมงค่ะ , 2
# 2/2 [==============================] - 0s 17ms/step
# สามารถเข้าไปติดต่อเพื่อชำระค่าเทอมล่วงหน้าที่ห้องการเงินได้เลยใช่
# ไหมครับเปิดรับชำระได้เลยใช่นะครับ , 2
# 4/4 [==============================] - 0s 9ms/step
# เข้าไปจ่ายค่าเทอมก่อนได้มั้ยคะ​ ไม่ถนัดกับการโอน , 2
# 2/2 [==============================] - 0s 7ms/step
# เข้าไปจ่ายค่าเทอมก่อนได้มั้ยคะ​ ไม่ถนัดกับการโอน , 2
# 2/2 [==============================] - 0s 8ms/step
# เข้าไปจ่ายค่าเทอมก่อนได้มั้ยคะ​ ไม่ถนัดกับการโอน , 2
# 2/2 [==============================] - 0s 8ms/step
# ชำระผ่านโมบายแบงค์กิ้งไปแล้วจะได้รับใบเสร็จอย่างไรคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# ชำระผ่านโมบายแบงค์กิ้งไปแล้วจะได้รับใบเสร็จอย่างไรคะ , 2
# 2/2 [==============================] - 0s 14ms/step
# ชำระผ่านโมบายแบงค์กิ้งไปแล้วจะได้รับใบเสร็จอย่างไรคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# ชำระผ่านโมบายแบงค์กิ้งไปแล้วจะได้รับใบเสร็จอย่างไรคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# จ่ายบัตรเครดิตมีค่าธรรมเนียมไหมคะ , 2
# 2/2 [==============================] - 0s 5ms/step
# จ่ายบัตรเครดิตมีค่าธรรมเนียมไหมคะ , 2
# 2/2 [==============================] - 0s 4ms/step
# จ่ายบัตรเครดิตมีค่าธรรมเนียมไหมคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# ถ้าชำระผ่าน mobile banking จะได้รับใบเสร็จยังไงคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# ถ้าชำระผ่าน mobile banking จะได้รับใบเสร็จยังไงคะ , 2
# 2/2 [==============================] - 0s 9ms/step
# ถ้าชำระผ่าน mobile banking จะได้รับใบเสร็จยังไงคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# เตรียมอนุบาลรับสมัครกี่ขวบคะ , 2
# 1/1 [==============================] - 0s 36ms/step
# เตรียมอนุบาลรับสมัครกี่ขวบคะ , 2
# 1/1 [==============================] - 0s 25ms/step
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# เครื่องแบบอนุบาลตอนนี้หาซื้อได้ที่ไหนเหรอคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# สวัสดีค่ะ สมัครป.1 ไปแล้ว แต่ไม่สามารถโอนเงินค่าสมัครได้ค่ะ
# ต้องทำอย่างไรคะ , 2
# 3/3 [==============================] - 0s 9ms/step
# สวัสดีค่ะ สมัครป.1 ไปแล้ว แต่ไม่สามารถโอนเงินค่าสมัครได้ค่ะ
# ต้องทำอย่างไรคะ , 2
# 3/3 [==============================] - 0s 12ms/step
# สวัสดีค่ะ สมัครป.1 ไปแล้ว แต่ไม่สามารถโอนเงินค่าสมัครได้ค่ะ
# ต้องทำอย่างไรคะ , 2
# 3/3 [==============================] - 0s 12ms/step
# สมัครป1 ep ค่ะ ค่าเทอมเท่าไหร่ค่ะ , 2
# 2/2 [==============================] - 0s 4ms/step
# สมัครป1 ep ค่ะ ค่าเทอมเท่าไหร่ค่ะ , 2
# 2/2 [==============================] - 0s 4ms/step
# สมัครป1 ep ค่ะ ค่าเทอมเท่าไหร่ค่ะ , 2
# 2/2 [==============================] - 0s 7ms/step
# อ.1ค่าเทอมเท่ารัยคะ , 2
# 1/1 [==============================] - 0s 31ms/step
# อ.1ค่าเทอมเท่ารัยคะ , 2
# 1/1 [==============================] - 0s 26ms/step
# เข้าไปสมัครอนุบาลนี่ไปได้ทุกวันหรือเว้นวันหยุดราชการคะ , 2
# 2/2 [==============================] - 0s 9ms/step
# รบกวนแจ้งเอกสารที่ใช้สมัครด้วยค่ะ , 2
# 2/2 [==============================] - 0s 5ms/step
# รูปสมัครเรียนน้องอนุบาล 1 ก็ต้องใส่ชุดนักเรียนถ่ายรูปเหรอคะ , 2
# 2/2 [==============================] - 0s 11ms/step
# รูปสมัครเรียนน้องอนุบาล 1 ก็ต้องใส่ชุดนักเรียนถ่ายรูปเหรอคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# สมัครเตรียมเตรียมอนุบาลต้องเตรียมอะไรบ้างคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# ค่าเทอมเท่ารัยคะโปรแกรม EP , 2
# 1/1 [==============================] - 0s 30ms/step
# สหกรณ์โรงเรียนเปิดไหมค่ะในช่วงนี้ , 2
# 2/2 [==============================] - 0s 5ms/step
# สหกรณ์โรงเรียนเปิดไหมค่ะในช่วงนี้ , 2
# 2/2 [==============================] - 0s 4ms/step
# สหกรณ์โรงเรียนเปิดไหมค่ะในช่วงนี้ , 2
# 2/2 [==============================] - 0s 3ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี ต้องจ่ายอะไรเท่าไหร่บ้างคะ , 2
# 2/2 [==============================] - 0s 11ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี ต้องจ่ายอะไรเท่าไหร่บ้างคะ , 2
# 2/2 [==============================] - 0s 11ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี ต้องจ่ายอะไรเท่าไหร่บ้างคะ , 2
# 2/2 [==============================] - 0s 12ms/step
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 2
# 2/2 [==============================] - 0s 16ms/step
# ITP ม.4 ค่าเทอมเท่าไหร่คะ และต้องเตรียมอะไรไปบ้างคะ , 2
# 2/2 [==============================] - 0s 9ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี เท่าไหร่ครับ
# และต้องเตรียมอะไรไปบ้างครับ , 2
# 3/3 [==============================] - 0s 10ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี เท่าไหร่ครับ
# และต้องเตรียมอะไรไปบ้างครับ , 2
# 3/3 [==============================] - 0s 9ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี เท่าไหร่ครับ
# และต้องเตรียมอะไรไปบ้างครับ , 2
# 3/3 [==============================] - 0s 9ms/step
# ค่าเทอม ม.4 สายวิทย์ คณิต เทคโนโลยี เท่าไหร่ครับ
# และต้องเตรียมอะไรไปบ้างครับ , 2
# 3/3 [==============================] - 0s 7ms/step
# มอบตัวต้องไปตรงไหนของ รร.คะ , 2
# 1/1 [==============================] - 0s 26ms/step
# มอบตัวต้องไปตรงไหนของ รร.คะ , 2
# 1/1 [==============================] - 0s 26ms/step
# เอกสารการเขียนคําร้องมีอะไรบ้างคะ , 2
# 1/1 [==============================] - 0s 36ms/step
# เอกสารการเขียนคําร้องต้องใช้รูปถ่ายขนาดเท่าไหร่ครับ , 2
# 2/2 [==============================] - 0s 9ms/step
# เอกสารการเขียนคําร้องต้องใช้รูปถ่ายขนาดเท่าไหร่ครับ , 2
# 2/2 [==============================] - 0s 8ms/step
# สอบถามหน่อยค่ะ ECP ค่าเทอมเท่าไหร่คะ  , 2
# 2/2 [==============================] - 0s 6ms/step
# สอบถามหน่อยค่ะ ECP ค่าเทอมเท่าไหร่คะ  , 2
# 2/2 [==============================] - 0s 6ms/step
# สอบถามหน่อยค่ะ ECP ค่าเทอมเท่าไหร่คะ  , 2
# 2/2 [==============================] - 0s 7ms/step
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ  , 2
# 2/2 [==============================] - 0s 8ms/step
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ  , 2
# 2/2 [==============================] - 0s 10ms/step
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ  , 2
# 2/2 [==============================] - 0s 11ms/step
# ซื้อเครื่องแบบนักเรียน กับหนังสือเรียนได้จากที่ไหนคะ  , 2
# 2/2 [==============================] - 0s 6ms/step
# กรอกรายละเอียดใบมอบตัวได้จากที่ไหนครับ , 2
# 2/2 [==============================] - 0s 5ms/step
# กรอกรายละเอียดใบมอบตัวได้จากที่ไหนครับ , 2
# 2/2 [==============================] - 0s 6ms/step
# การทดสอบวัดระดับภาษาอังกฤษ CEFR มีค่าสมัครสอบไหมคะ , 2
# 2/2 [==============================] - 0s 8ms/step
# ชุดนักเรียน วันเสาร์-อาทิตย์ซื้อได้มั้ยครับ , 2
# 2/2 [==============================] - 0s 14ms/step
# ชุดนักเรียน วันเสาร์-อาทิตย์ซื้อได้มั้ยครับ , 2
# 2/2 [==============================] - 0s 6ms/step
# ชุดนักเรียน วันเสาร์-อาทิตย์ซื้อได้มั้ยครับ , 2
# 2/2 [==============================] - 0s 8ms/step
# ถ้าจะสั่งตัดชุด รด ติดต่อได้ที่ไหนคะ , 2
# 2/2 [==============================] - 0s 10ms/step
# ถ้าจะสั่งตัดชุด รด ติดต่อได้ที่ไหนคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# ถ้าจะสั่งตัดชุด รด ติดต่อได้ที่ไหนคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# เดือนหน้าจะมีการเปิดสอนว่ายน้ำแล้วใช่ไหมคะ , 2
# 2/2 [==============================] - 0s 7ms/step
# เดือนหน้าจะมีการเปิดสอนว่ายน้ำแล้วใช่ไหมคะ , 2
# 2/2 [==============================] - 0s 6ms/step
# ท้องฟ้าจำลองเปิดอีกทีเมื่อไหร่เหรอครับ , 2
# 2/2 [==============================] - 0s 5ms/step
# ท้องฟ้าจำลองเปิดอีกทีเมื่อไหร่เหรอครับ , 2
# 2/2 [==============================] - 0s 7ms/step
# มีรีวิวโครงการ ITP ไหมค่ะ , 2
# 1/1 [==============================] - 0s 26ms/step
# สอบถามเรื่องเรียนว่ายน้ำหน่อยค่ะ , 2
# 1/1 [==============================] - 0s 32ms/step
# ขอสอบถามรายละเอียดการรับสมัครครูหน่อยครับ  , 2
# 2/2 [==============================] - 0s 6ms/step
# ขอสอบถามรายละเอียดการรับสมัครครูหน่อยครับ  , 2
# 2/2 [==============================] - 0s 5ms/step
# ราคาใบสมัครสสวทกับepกี่บาทคะ , 2
# 1/1 [==============================] - 0s 27ms/step
# ราคาใบสมัครสสวทกับepกี่บาทคะ , 2
# 1/1 [==============================] - 0s 27ms/step
# รบกวนสอบถามค่ะ ป. English program กับ Gifted English
# ต่างกันอย่างไรคะ , 2
# 3/3 [==============================] - 0s 8ms/step
# รบกวนสอบถามค่ะ ป. English program กับ Gifted English
# ต่างกันอย่างไรคะ , 2
# 3/3 [==============================] - 0s 9ms/step
# รบกวนสอบถามค่ะ ป. English program กับ Gifted English
# ต่างกันอย่างไรคะ , 2
# 3/3 [==============================] - 0s 8ms/step
# ชุด นร. มีจำหน่ายไหมคะ ถ้ามีจำหน่ายวันไหน , 2
# 2/2 [==============================] - 0s 7ms/step
# รับสมัครถึงวันไหนค่ะ ยังสมัครทันมั้ย , 2
# 2/2 [==============================] - 0s 6ms/step
# อยากทราบค่าเทอม ม.3 ม.4 เท่าใหร่คะ , 2
# 1/1 [==============================] - 0s 30ms/step
# อยากรู้ว่าม1จะขอเข้าสมัครได้ใหม่คะ , 2
# 2/2 [==============================] - 0s 5ms/step
# เสียค่าสมัครสอบเท่าไหร่ค่ะ , 2
# 1/1 [==============================] - 0s 28ms/step
# ใบสมัครใช้อะไรบ้างคะ , 2
# 1/1 [==============================] - 0s 25ms/step
